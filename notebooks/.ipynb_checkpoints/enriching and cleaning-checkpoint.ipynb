# %% [markdown]
# # Libraries

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# # Amazon database 2009 - 2022

# %%
def importarCsv(path):
    return pd.read_csv(path)

# %%
df_amazon = importarCsv("../data/bestsellers_with_categories_2022_03_27.csv")

# %% [markdown]
# ## Explore table

# %%
df_amazon.sample()
# Out:
#                 Name        Author  User Rating  Reviews  Price  Year  \
# 463  First 100 Words  Roger Priddy          4.7    17323      4  2018
#
#            Genre
# 463  Non Fiction

# %%
df_amazon.shape
# Out:
# (700, 7)

# %%
df_amazon.columns
# Out:
# Index(['Name', 'Author', 'User Rating', 'Reviews', 'Price', 'Year', 'Genre'], dtype='object')

# %%
df_amazon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         700 non-null    object
#  1   Author       700 non-null    object
#  2   User Rating  700 non-null    float64
#  3   Reviews      700 non-null    int64
#  4   Price        700 non-null    int64
#  5   Year         700 non-null    int64
#  6   Genre        700 non-null    object
# dtypes: float64(1), int64(3), object(3)
# memory usage: 38.4+ KB

# %% [markdown]
# ## Explore data and its cohesiveness

# %%
df_amazon.duplicated().sum()
# Out:
# 0

# %%
df_amazon.duplicated(subset=['Name', 'Year']).sum()
# Out:
# 3

# %%
df_amazon.isna().sum()
# Out:
# Name           0
# Author         0
# User Rating    0
# Reviews        0
# Price          0
# Year           0
# Genre          0
# dtype: int64

# %%
df_amazon.dtypes
# Out:
# Name            object
# Author          object
# User Rating    float64
# Reviews          int64
# Price            int64
# Year             int64
# Genre           object
# dtype: object

# %%
df_amazon.describe()
# Out:
#        User Rating        Reviews       Price         Year
# count   700.000000     700.000000  700.000000   700.000000
# mean      4.639857   19255.195714   12.700000  2015.500000
# std       0.218586   23613.443875    9.915162     4.034011
# min       3.300000      37.000000    0.000000  2009.000000
# 25%       4.500000    4987.250000    7.000000  2012.000000
# 50%       4.700000   10284.000000   11.000000  2015.500000
# 75%       4.800000   23358.000000   15.000000  2019.000000
# max       4.900000  208917.000000  105.000000  2022.000000

# %% [markdown]
# ## Cleaning

# %%
amazon_csv = df_amazon
amazon_csv.columns = [i.lower() for i in amazon_csv.columns]

# %%
amazon_csv.rename({"name":"title"}, axis = 1, inplace = True)
amazon_csv.rename({"year":"year_bought"}, axis = 1, inplace = True)

# %%
amazon_csv.drop_duplicates(subset=['title', 'year_bought'], inplace = True)
# Some titles are, repeated, I guess because they were bestsellers in two different years.
# I think it's not the publication date, but the selling date

# %%
amazon_csv.drop(amazon_csv["year_bought"][amazon_csv["year_bought"]< 2020].index, axis = 0, inplace = True)
# Out:
# dtype('int64')

# %%
# We don't have the actual sales, and the order given is alphabetical by name.
# An approximation to order by number of sales would be the ammount of interactions/reviews
amazon_csv.sort_values(by = "reviews", ascending = False, inplace=True)

# %%
amazon_csv.reset_index(inplace = True)

# %%
amazon_csv.drop(["user rating", "reviews", "index"], axis = 1, inplace = True)

# %%
amazon_csv.to_csv("../data/amazon_projectII.csv", index=False)

# %%
amazon_csv
# Out:
#                                                  title           author  \
# 0                              Where the Crawdads Sing      Delia Owens
# 1                              Where the Crawdads Sing      Delia Owens
# 2                        The Midnight Library: A Novel        Matt Haig
# 3                        The Midnight Library: A Novel        Matt Haig
# 4                                      A Promised Land     Barack Obama
# ..                                                 ...              ...
# 145                       Call Us What We Carry: Poems    Amanda Gorman
# 146  Maus I: A Survivor's Tale: My Father Bleeds Hi...   Art Spiegelman
# 147  Principles for Dealing with the Changing World...        Ray Dalio
# 148  Life Force: How New Breakthroughs in Precision...     Tony Robbins
# 149  The Whole Body Reset: Your Weight-Loss Plan fo...  Stephen Perrine
#
#      price  year_bought        genre
# 0       10         2022      Fiction
# 1       12         2020      Fiction
# 2       13         2022      Fiction
# 3       13         2021      Fiction
# 4       16         2020  Non Fiction
# ..     ...          ...          ...
# 145     14         2021      Fiction
# 146     14         2022      Fiction
# 147     21         2022  Non Fiction
# 148     20         2022  Non Fiction
# 149     20         2022  Non Fiction
#
# [150 rows x 5 columns]

# %% [markdown]
# # Spanish indie database 2020
#
# Top Books in Spain: Ranking & Details, dataset from Kaggle (https://www.kaggle.com/datasets/thedevastator/top-books-in-spain-ranking-details)

# %%
df_spanish = importarCsv("../data/libros_mas_vendidos.csv")

# %% [markdown]
# ## Explore table

# %%
df_spanish.sample()
# Out:
#     Puesto                                                Url         Título  \
# 36       3  https://www.todostuslibros.com/libros/independ...  Independencia
#
#              Autor                         Materias          Editorial  \
# 36  Cercas, Javier  Ficción moderna y contemporanea  Tusquets Editores
#
#    Traductor Colección           Encuadernación País de publicación   \
# 36       NaN  Andanzas   Tapa blanda o Bolsillo               España
#
#    Idioma de publicación  Idioma original                 ISBN            EAN  \
# 36                Español          Español   978-84-9066-929-7  9788490669297
#
#        Dimensiones        Peso  Nº páginas Fecha publicación  Ilustrador
# 36   225 x 148 mm.  559 gramos         400         03-03-2021        NaN

# %%
df_spanish.shape
# Out:
# (100, 19)

# %%
df_spanish.columns
# Out:
# Index(['Puesto', 'Url', 'Título', 'Autor', 'Materias', 'Editorial',
#        'Traductor', 'Colección', 'Encuadernación', 'País de publicación ',
#        'Idioma de publicación ', 'Idioma original ', 'ISBN', 'EAN',
#        'Dimensiones', 'Peso', 'Nº páginas', 'Fecha publicación ',
#        'Ilustrador'],
#       dtype='object')

# %%
df_spanish.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Puesto                  100 non-null    int64
#  1   Url                     100 non-null    object
#  2   Título                  100 non-null    object
#  3   Autor                   100 non-null    object
#  4   Materias                100 non-null    object
#  5   Editorial               100 non-null    object
#  6   Traductor               32 non-null     object
#  7   Colección               98 non-null     object
#  8   Encuadernación          100 non-null    object
#  9   País de publicación     100 non-null    object
#  10  Idioma de publicación   100 non-null    object
#  11  Idioma original         100 non-null    object
#  12  ISBN                    100 non-null    object
#  13  EAN                     100 non-null    int64
#  14  Dimensiones             99 non-null     object
#  15  Peso                    79 non-null     object
#  16  Nº páginas              100 non-null    int64
#  17  Fecha publicación       100 non-null    object
#  18  Ilustrador              7 non-null      object
# dtypes: int64(3), object(16)
# memory usage: 15.0+ KB

# %% [markdown]
# ## Explore data and its cohesiveness

# %%
df_spanish.duplicated().sum()
# Out:
# 0

# %%
df_spanish.isna().sum()
# Out:
# Puesto                     0
# Url                        0
# Título                     0
# Autor                      0
# Materias                   0
# Editorial                  0
# Traductor                 68
# Colección                  2
# Encuadernación             0
# País de publicación        0
# Idioma de publicación      0
# Idioma original            0
# ISBN                       0
# EAN                        0
# Dimensiones                1
# Peso                      21
# Nº páginas                 0
# Fecha publicación          0
# Ilustrador                93
# dtype: int64

# %%
df_spanish.dtypes
# Out:
# Puesto                     int64
# Url                       object
# Título                    object
# Autor                     object
# Materias                  object
# Editorial                 object
# Traductor                 object
# Colección                 object
# Encuadernación            object
# País de publicación       object
# Idioma de publicación     object
# Idioma original           object
# ISBN                      object
# EAN                        int64
# Dimensiones               object
# Peso                      object
# Nº páginas                 int64
# Fecha publicación         object
# Ilustrador                object
# dtype: object

# %%
df_spanish.describe()
# Out:
#            Puesto           EAN  Nº páginas
# count  100.000000  1.000000e+02  100.000000
# mean    50.500000  9.788445e+12  335.540000
# std     29.011492  1.400690e+08  168.939617
# min      1.000000  9.788401e+12   24.000000
# 25%     25.750000  9.788417e+12  200.000000
# 50%     50.500000  9.788420e+12  312.000000
# 75%     75.250000  9.788434e+12  448.000000
# max    100.000000  9.789808e+12  936.000000

# %% [markdown]
# ## Cleaning

# %%
spanish_csv = df_spanish.drop(["Url", "Traductor", "Colección", "Encuadernación", "ISBN", "EAN", "Dimensiones", "Peso", "Ilustrador"], axis = 1)

# %%
spanish_csv.rename({"Puesto":"order"}, axis = 1, inplace = True)
spanish_csv.rename({"Título":"title"}, axis = 1, inplace = True)
spanish_csv.rename({"Autor":"author"}, axis = 1, inplace = True)
spanish_csv.rename({"Materias":"genre"}, axis = 1, inplace = True)
spanish_csv.rename({"Editorial":"editorial"}, axis = 1, inplace = True)
spanish_csv.rename({"País de publicación ":"country"}, axis = 1, inplace = True)
spanish_csv.rename({"Idioma de publicación ":"language"}, axis = 1, inplace = True)
spanish_csv.rename({"Idioma original ":"orig_language"}, axis = 1, inplace = True)
spanish_csv.rename({"Nº páginas":"pages"}, axis = 1, inplace = True)
spanish_csv.rename({"Fecha publicación ":"date"}, axis = 1, inplace = True)

# %%
spanish_csv["date"] = pd.to_datetime(spanish_csv["date"])
# Out:
# C:\Users\gdcma\AppData\Local\Temp\ipykernel_6680\1803001360.py:1: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   spanish_csv["date"] = pd.to_datetime(spanish_csv["date"])

# %%
spanish_csv["year_pub"] = pd.DatetimeIndex(spanish_csv["date"]).year

# %%
spanish_csv.to_csv("../data/spanish_projectII.csv", index=False)

# %% [markdown]
# # Web Scrapping

# %%
# Best sellers from this independent conglomerate https://www.todostuslibros.com/mas_vendidos
url = "https://www.todostuslibros.com/mas_vendidos"
res = requests.get(url)
html = res.content
soup = BeautifulSoup(html, 'html.parser')
body = soup.find("main", {"class": "main"})
body
# Out:
# <main class="main">
# <div class="container d-none d-sm-block">
# <div class="row justify-content-center">
# <ul class="breadcrumb">
# <li>
# <a href="/" title="Todos tus libros">Todos tus libros <i class="fas fa-angle-right"></i></a>
# </li>
# <li>
# <a href="" title="Más vendidos">
#                 Más vendidos            </a>
# </li>
# </ul>
# </div>
# </div>
# <div class="container">
# <div class="row justify-content-center">
# <div class="col" id="main-php-flash-errors">
# </div>
# </div>
# </div>
# <div class="container">
# <div class="row justify-content-center">
# <div class="col">
# <h1 class="page-title">Los 100 más vendidos</h1>
# <div class="header-list row">
# <div class="col-12 col-sm-9 text-center text-sm-left"></div>
# <div class="alter-view col-4 col-sm-3 text-right d-none d-md-block" id="alter-view">
# <a>
# <i class="fa fa-th"></i>
# </a>
# <a class="selected">
# <i class="fa fa-bars"></i>
# </a>
# </div>
# </div>
# <div class="row">
# <ul class="books col-12">
# <li class="book row" data-gtm-disponibilidad="" data-gtm-editorial="B" data-gtm-index="1" data-gtm-isbn="978-84-666-7568-0" data-gtm-precio="22.90" data-gtm-titulo="Todo vuelve (Todo arde 2)" id="book_978-84-666-7568-0">
# <div class="col-12 col-sm-12 col-md-9 book-content">
# <div class="row">
# <div class="book-image col-4 col-sm-3 col-md-3 col-lg-3">
# <a href="https://www.todostuslibros.com/libros/todo-vuelve-todo-arde-2_978-84-666-7568-0">
# <img alt="Todo vuelve (Todo arde 2)" height="150" src="https://static.cegal.es/imagenes/marcadas/9788466/978846667568.gif" title="Todo vuelve (Todo arde 2)" width="100"/>
# <span> 1 </span>
# </a>
# <!-- Solo Vista grid y móvil -->
# <a class="btn bookshelves-link" data-book-isbn="978-84-666-7568-0" data-book-title="Todo vuelve (Todo arde 2)" href="https://www.todostuslibros.com/login?_next=https://www.todostuslibros.com/libros/todo-vuelve-todo-arde-2_978-84-666-7568-0" title="Añadir a estantería">
# <i class="far fa-heart"></i>
# </a>
# <!-- //Solo  Vista grid y móvil -->
# </div>
# <div class="book-details col-8 col-sm-9 col-md-9 col-lg-9 mb-2">
# <h2 class="title">
# <a href="https://www.todostuslibros.com/libros/todo-vuelve-todo-arde-2_978-84-666-7568-0">
#                         Todo vuelve (Todo arde 2)
#                         </a>
# </h2>
# <h3 class="subtitle"><a href="https://www.todostuslibros.com/libros/todo-vuelve-todo-arde-2_978-84-666-7568-0"></a></h3>
# <h3 class="author">
# <a href="https://www.todostuslibros.com/autor/gomez-jurado-juan">Gómez-Jurado, Juan</a>
# </h3>
# <div class="data_isbn d-none d-md-block">978-84-666-7568-0 </div>
# <div class="ratings list-view mb-3">
# </div>
# <p class="synopsis d-none d-md-block d-lg-block d-xl-block">VUELVE EL AUTOR MÁS VENDIDO EN LENGUA ESPAÑOLA  Tras el enorme éxito de REINA ROJA y TODO ARDE, continúa la saga que ha conquistado al mundo.  «Me rindo a los pies del mejor escritor actual de thriller».ZENDA UN PLAN IMPOSIBLETodo lo que Aura Reyes necesita es continuar con vida diez minutos más. No...</p>
# <!--<p class="synopsis">VUELVE EL AUTOR MÁS VENDIDO EN LENGUA ESPAÑOLA  Tras el enorme éxito de REINA ROJA y TODO ARDE, cont...</p>-->
# <!-- <p class="data">B </p>-->
# <!-- Solo en móvil -->
# <div class="d-block d-block d-md-none">
# <div class="book-action__content--top d-flex d-md-none">
# <div class="book-price d-block d-md-none">
# <strong>
#                                                                 22.90€
#                             </strong>
#                             (22.02€ sin IVA)
#                                                     </div>
# </div>
# </div>
# <!-- Solo en móvil -->
# </div>
# </div>
# </div>
# <div class="col-12 col-sm-12 col-md-3 book-action">
# <div class="book-action__top d-felx justify-content-end">
# <a class="btn bookshelves-link" href="https://www.todostuslibros.com/login?_next=https://www.todostuslibros.com/libros/todo-vuelve-todo-arde-2_978-84-666-7568-0" title="Añadir a estantería">
# <i class="far fa-heart"></i>
# </a>
# </div>
# <div class="d-flex book-action__content">
# <div class="book-action__content--top d-none d-md-flex">
# <!-- Solo en desktop -->
# <div class="book-price">
# <strong>
#                                                         22.90€
#                         </strong>
#                         (22.02€ sin IVA)
#                                             </div>
# <div class="ratings grid-view">
# </div>
# <!-- //Solo en desktop -->
# </div>
# <div class="book-location">
# <form action="https://www.todostuslibros.com/b2c_add_to_cart" id="addToCart" method="POST">
# <input name="_token" type="hidden" value="v8ddx2xGXLupIiGdP5Eig9Tl59YhtDLwoUW1ILnd"/> <input name="isbn" type="hidden" value="978-84-666-7568-0"/>
# <button class="btn btn-add-to-cart b2c btn-block mb-2" type="submit">
# <!--<i class="fas fa-shopping-cart"></i> -->
#                 Añadir a la cesta
#                 </button>
# </form>
# <div class="availability-bookshops-pickup" data-allowres="1" data-isbn="978-84-666-7568-0">
# </div>
# </div>
# <div class="bookstores">
# <div class="availability-bookshops" data-allowres="1" data-isbn="978-84-666-7568-0"></div>
# <span class="availability availability-high">
# <i class="fas fa-check"></i> Disponibilidad alta
#     </span>
# </div>
# </div>
# </div>
# </li>
# <li class="book row" data-gtm-disponibilidad="" data-gtm-editorial="Editorial Planeta" data-gtm-index="2" data-gtm-isbn="978-84-08-27758-3" data-gtm-precio="22.90" data-gtm-titulo="El Infierno" id="book_978-84-08-27758-3">
# <div class="col-12 col-sm-12 col-md-9 book-content">
# <div class="row">
# <div class="book-image col-4 col-sm-3 col-md-3 col-lg-3">
# <a href="https://www.todostuslibros.com/libros/el-infierno_978-84-08-27758-3">
# <img alt="El Infierno" height="150" src="https://static.cegal.es/imagenes/marcadas/9788408/978840827758.gif" title="El Infierno" width="100"/>
# <span> 2 </span>
# </a>
# <!-- Solo Vista grid y móvil -->
# <a class="btn bookshelves-link" data-book-isbn="978-84-08-27758-3" data-book-title="El Infierno" href="https://www.todostuslibros.com/login?_next=https://www.todostuslibros.com/libros/el-infierno_978-84-08-27758-3" title="Añadir a estantería">
# <i class="far fa-heart"></i>
# </a>
# <!-- //Solo  Vista grid y móvil -->
# </div>
# <div class="book-details col-8 col-sm-9 col-md-9 col-lg-9 mb-2">
# <h2 class="title">
# <a href="https://www.todostuslibros.com/libros/el-infierno_978-84-08-27758-3">
#                         El Infierno
#                         </a>
# </h2>
# <h3 class="subtitle"><a href="https://www.todostuslibros.com/libros/el-infierno_978-84-08-27758-3"></a></h3>
# <h3 class="author">
# <a href="https://www.todostuslibros.com/autor/mola-carmen">Mola, Carmen</a>
# </h3>
# <div class="data_isbn d-none d-md-block">978-84-08-27758-3 </div>
# <div class="ratings list-view mb-3">
# </div>
# <p class="synopsis d-none d-md-block d-lg-block d-xl-block">Salvaje, perturbador, cruel.
# 	EL NUEVO Y BRUTAL THRILLER DE CARMEN MOLA QUE MÁS DE 2 MILLONES DE LECTORES ESTÁN ESPERANDO.
# 	Lo que parecía un paraíso se terminó convirtiendo en un infierno. Una novela negra impactante y perturbadora al más puro estilo Carmen Mola.
# 	Un terrible levantamiento del ejér...</p>
# <!--<p class="synopsis">Salvaje, perturbador, cruel.
# 	EL NUEVO Y BRUTAL THRILLER DE CARMEN MOLA QUE MÁS DE 2 MILLONES DE LEC...</p>-->
# <!-- <p class="data">Editorial Planeta </p>-->
# <!-- Solo en móvil -->
# <div class="d-block d-block d-md-none">
# <div class="book-action__content--top d-flex d-md-none">
# <div class="book-price d-block d-md-none">
# <strong>
#                                                                 22.90€
#                             </strong>
#                             (22.02€ sin IVA)
#                                                     </div>
# </div>
# </div>
# <!-- Solo en móvil -->
# </div>
# </div>
# </div>
# <div class="col-12 col-sm-12 col-md-3 book-action">
# <div class="book-action__top d-felx justify-content-end">
# <a class="btn bookshelves-link" href="https://www.todostuslibros.com/login?_next=https://www.todostuslibros.com/libros/el-infierno_978-84-08-27758-3" title="Añadir a estantería">
# <i class="far fa-heart"></i>
# </a>
# </div>
# <div class="d-flex book-action__content">
# <div class="book-action__content--top d-none d-md-flex">
# <!-- Solo en desktop -->
# <div class="book-price">
# <strong>
#                                                         22.90€
#                         </strong>
#                         (22.02€ sin IVA)
#                                             </div>
# <div class="ratings grid-view">
# </div>
# <!-- //Solo en desktop -->
# </div>
# <div class="book-location">
# <form action="https://www.todostuslibros.com/b2c_add_to_cart" id="addToCart" method="POST">
# <input name="_token" type="hidden" value="v8ddx2xGXLupIiGdP5Eig9Tl59YhtDLwoUW1ILnd"/> <input name="isbn" type="hidden" value="978-84-08-27758-3"/>
# <button class="btn btn-add-to-cart b2c btn-block mb-2" type="submit">
# <!--<i class="fas fa-shopping-cart"></i> -->
#                 Añadir a la cesta
#                 </button>
# </form>
# <div class="availability-bookshops-pickup" data-allowres="1" data-isbn="978-84-08-27758-3">
# </div>
# </div>
# <div class="bookstores">
# <div class="availability-bookshops" data-allowres="1" data-isbn="978-84-08-27758-3"></div>
# <span class="availability availability-high">
# <i class="fas fa-check"></i> Disponibilidad alta
#     </span>
# </div>
# </div>
# </div>
# </li>
# <li class="book row" data-gtm-disponibilidad="" data-gtm-editorial="PLAZA &amp; JANES" data-gtm-index="3" data-gtm-isbn="978-84-01-03013-0" data-gtm-precio="24.90" data-gtm-titulo="La armadura de la luz (Saga Los pilares de la Tierra 4)" id="book_978-84-01-03013-0">
# <div class="col-12 col-sm-12 col-md-9 book-content">
# <div class="row">
# <div class="book-image col-4 col-sm-3 col-md-3 col-lg-3">
# <a href="https://www.todostuslibros.com/libros/la-armadura-de-la-luz-saga-los-pilares-de-la-tierra-4_978-84-01-03013-0">
# <img alt="La armadura de la luz (Saga Los pilares de la Tierra 4)" height="150" src="https://static.cegal.es/imagenes/marcadas/9788401/978840103013.gif" title="La armadura de la luz (Saga Los pilares de la Tierra 4)" width="100"/>
# <span> 3 </span>
# </a>
# <!-- Solo Vista grid y móvil -->
# <a class="btn bookshelves-link" data-book-isbn="978-84-01-03013-0" data-book-title="La armadura de la luz (Saga Los pilares de la Tierra 4)" href="https://www.todostuslibros.com/login?_next=https://www.todostuslibros.com/libros/la-armadura-de-la-luz-saga-los-pilares-de-la-tierra-4_978-84-01-03013-0" title="Añadir a estantería">
# <i class="far fa-heart"></i>
# </a>
# <!-- //Solo  Vista grid y móvil -->
# </div>
# <div class="book-details col-8 col-sm-9 col-md-9 col-lg-9 mb-2">
# <h2 class="title">
# <a href="https://www.todostuslibros.com/libros/la-armadura-de-la-luz-saga-los-pilares-de-la-tierra-4_978-84-01-03013-0">
#                         La armadura de la luz (Saga Los pilares de la Tierra 4)
#                         </a>
# </h2>
# <h3 class="subtitle"><a href="https://www.todostuslibros.com/libros/la-armadura-de-la-luz-saga-los-pilares-de-la-tierra-4_978-84-01-03013-0"></a></h3>
# <h3 class="author">
# <a href="https://www.todostuslibros.com/autor/follett-ken">Follett, Ken</a>
# </h3>
# <div class="data_isbn d-none d-md-block">978-84-01-03013-0 </div>
# <div class="ratings list-view mb-3">
# </div>
# <p class="synopsis d-none d-md-block d-lg-block d-xl-block">Vuelve el mejor Follett con la emocionante quinta entrega de la saga «Los pilares de la Tierra». El choque de progreso y tradición y una guerra que amenaza con engullir toda Europa en la más ambiciosa y épica novela del maestro de la ficción histórica. La revolución está en el aire1792. Un gobierno...</p>
# <!--<p class="synopsis">Vuelve el mejor Follett con la emocionante quinta entrega de la saga «Los pilares de la Tierra». El...</p>-->
# <!-- <p class="data">PLAZA &amp; JANES </p>-->
# <!-- Solo en móvil -->
# <div class="d-block d-block d-md-none">
# <div class="book-action__content--top d-flex d-md-none">
# <div class="book-price d-block d-md-none">
# <strong>
#                                                                 24.90€
#                             </strong>
#                             (23.94€ sin IVA)
#                                                     </div>
# </div>
# </div>
# <!-- Solo en móvil -->
# </div>
# </div>
# </div>
# <div class="col-12 col-sm-12 col-md-3 book-action">
# <div class="book-action__top d-felx justify-content-end">
# <a class="btn bookshelves-link" href="https://www.todostuslibros.com/login?_next=https://www.todostuslibros.com/libros/la-armadura-de-la-luz-saga-los-pilares-de-la-tierra-4_978-84-01-03013-0" title="Añadir a estantería">
# <i class="far fa-heart"></i>
# </a>
# </div>
# <div class="d-flex book-action__content">
# <div class="book-action__content--top d-none d-md-flex">
# <!-- Solo en desktop -->
# <div class="book-price">
# <strong>
#                                                         24.90€
#                         </strong>
#                         (23.94€ sin IVA)
#                                             </div>
# <div class="ratings grid-view">
# </div>
# <!-- //Solo en desktop -->
# </div>
# <div class="book-location">
# <form action="https://www.todostuslibros.com/b2c_add_to_cart" id="addToCart" method="POST">
# <input name="_token" type="hidden" value="v8ddx2xGXLupIiGdP5Eig9Tl59YhtDLwoUW1ILnd"/> <input name="isbn" type="hidden" value="978-84-01-03013-0"/>
# <button class="btn btn-add-to-cart b2c btn-block mb-2" type="submit">
# <!--<i class="fas fa-shopping-cart"></i> -->
#                 Añadir a la cesta
#                 </button>
# </form>
# <div class="availability-bookshops-pickup" data-allowres="1" data-isbn="978-84-01-03013-0">
# </div>
# </div>
# <div class="bookstores">
# <div class="availability-bookshops" data-allowres="1" data-isbn="978-84-01-03013-0"></div>
# <span class="availability availability-high">
# <i class="fas fa-check"></i> Disponibilidad alta
#     </span>
# </div>
# </div>
# </div>
# </li>
# <li class="book row" data-gtm-disponibilidad="" data-gtm-editorial="Libros Cúpula" data-gtm-index="4" data-gtm-isbn="978-84-480-3897-7" data-gtm-precio="19.90" data-gtm-titulo="La chica del verano" id="book_978-84-480-3897-7">
# <div class="col-12 col-sm-12 col-md-9 book-content">
# <div class="row">
# <div class="book-image col-4 col-sm-3 col-md-3 col-lg-3">
# <a href="https://www.todostuslibros.com/libros/la-chica-del-verano_978-84-480-3897-7">
# <img alt="La chica del verano" height="150" src="https://static.cegal.es/imagenes/marcadas/9788448/978844803897.gif" title="La chica del verano" width="100"/>
# <span> 4 </span>
# </a>
# <!-- Solo Vista grid y móvil -->
# <a class="btn bookshelves-link" data-book-isbn="978-84-480-3897-7" data-book-title="La chica del verano" href="https://www.todostuslibros.com/login?_next=https://www.todostuslibros.com/libros/la-chica-del-verano_978-84-480-3897-7" title="Añadir a estantería">
# <i class="far fa-heart"></i>
# </a>
# <!-- //Solo  Vista grid y móvil -->
# </div>
# <div class="book-details col-8 col-sm-9 col-md-9 col-lg-9 mb-2">
# <h2 class="title">
# <a href="https://www.todostuslibros.com/libros/la-chica-del-verano_978-84-480-3897-7">
#                         La chica del verano
#                         </a>
# </h2>
# <h3 class="subtitle"><a href="https://www.todostuslibros.com/libros/la-chica-del-verano_978-84-480-3897-7">Los finales felices son para los valientes</a></h3>
# <h3 class="author">
# <a href="https://www.todostuslibros.com/autor/la-vecina-rubia">La Vecina Rubia</a>
# </h3>
# <div class="data_isbn d-none d-md-block">978-84-480-3897-7 </div>
# <div class="ratings list-view mb-3">
# </div>
# <p class="synopsis d-none d-md-block d-lg-block d-xl-block">La primera edición especial incluye una dedicatoria manuscrita impresa escrita por la autora.Así quería ser yo: anónima. Oculta, pero presente.
#
# 	La vida está llena de etapas, algunas preciosas e inolvidables, otras más difíciles y complicadas, lo importante es saber cuándo hay que cerrar cada una...</p>
# <!--<p class="synopsis">La primera edición especial incluye una dedicatoria manuscrita impresa escrita por la autora.Así que...</p>-->
# <!-- <p class="data">Libros Cúpula </p>-->
# <!-- Solo en móvil -->
# <div class="d-block d-block d-md-none">
# <div class="book-action__content--top d-flex d-md-none">
# <div class="book-price d-block d-md-none">
# <strong>
#                                                                 19.90€
#                             </strong>
#                             (19.13€ sin IVA)
#                                                     </div>
# </div>
# </div>
# <!-- Solo en móvil -->
# </div>
# </div>
# </div>
# <div class="col-12 col-sm-12 col-md-3 book-action">
# <div class="book-action__top d-felx justify-content-end">
# <a class="btn bookshelves-link" href="https://www.todostuslibros.com/login?_next=https://www.todostuslibros.com/libros/la-chica-del-verano_978-84-480-3897-7" title="Añadir a estantería">
# <i class="far fa-heart"></i>
# </a>
# </div>
# <div class="d-flex book-action__content">
# <div class="book-action__content--top d-none d-md-flex">
# <!-- Solo en desktop -->
# <div class="book-price">
# <strong>
#                                                         19.90€
#                         </strong>
#                         (19.13€ sin IVA)
#                                             </div>
# <div class="ratings grid-view">
# </div>
# <!-- //Solo en desktop -->
# </div>
# <div class="book-location">
# <form action="https://www.todostuslibros.com/b2c_add_to_cart" id="addToCart" method="POST">
# <input name="_token" type="hidden" value="v8ddx2xGXLupIiGdP5Eig9Tl59YhtDLwoUW1ILnd"/> <input name="isbn" type="hidden" value="978-84-480-3897-7"/>
# <button class="btn btn-add-to-cart b2c btn-block mb-2" type="submit">
# <!--<i class="fas fa-shopping-cart"></i> -->
#                 Añadir a la cesta
#                 </button>
# </form>
# <div class="availability-bookshops-pickup" data-allowres="1" data-isbn="978-84-480-3897-7">
# </div>
# </div>
# <div class="bookstores">
# <div class="availability-bookshops" data-allowres="1" data-isbn="978-84-480-3897-7"></div>
# <span class="availability availability-high">
# <i class="fas fa-check"></i> Disponibilidad alta
#     </span>
# </div>
# </div>
# </div>
# </li>
# <li class="book row" data-gtm-disponibilidad="" data-gtm-editorial="Editorial Bruño" data-gtm-index="5" data-gtm-isbn="978-84-696-4040-1" data-gtm-precio="10.50" data-gtm-titulo="El Lirio Blanco" id="book_978-84-696-4040-1">
# <div class="col-12 col-sm-12 col-md-9 book-content">
# <div class="row">
# <div class="book-image col-4 col-sm-3 col-md-3 col-lg-3">
# <a href="https://www.todostuslibros.com/libros/el-lirio-blanco_978-84-696-4040-1">
# <img alt="El Lirio Blanco" height="150" src="https://static.cegal.es/imagenes/marcadas/9788469/978846964040.gif" title="El Lirio Blanco" width="100"/>
# <span> 5 </span>
# </a>
# <!-- Solo Vista grid y móvil -->
# <a class="btn bookshelves-link" data-book-isbn="978-84-696-4040-1" data-book-title="El Lirio Blanco" href="https://www.todostuslibros.com/login?_next=https://www.todostuslibros.com/libros/el-lirio-blanco_978-84-696-4040-1" title="Añadir a estantería">
# <i class="far fa-heart"></i>
# </a>
# <!-- //Solo  Vista grid y móvil -->
# </div>
# <div class="book-details col-8 col-sm-9 col-md-9 col-lg-9 mb-2">
# <h2 class="title">
# <a href="https://www.todostuslibros.com/libros/el-lirio-blanco_978-84-696-4040-1">
#                         El Lirio Blanco
#                         </a>
# </h2>
# <h3 class="subtitle"><a href="https://www.todostuslibros.com/libros/el-lirio-blanco_978-84-696-4040-1"></a></h3>
# <h3 class="author">
# <a href="https://www.todostuslibros.com/autor/goscinny-rene-fabcaro">Goscinny, René / Fabcaro</a>
# </h3>
# <div class="data_isbn d-none d-md-block">978-84-696-4040-1 </div>
# <div class="ratings list-view mb-3">
# </div>
# <p class="synopsis d-none d-md-block d-lg-block d-xl-block">El 26 de octubre de 2023 Astérix y Obélix regresan de la mano de un nuevo guionista, Fabrice Caro, para disfrutar de su aventura número 40. El título de este cómic es El Lirio Blanco, el nombre de una nueva corriente de pensamiento positivo que recorre Roma y se extiende por todo el Imperio a la vel...</p>
# <!--<p class="synopsis">El 26 de octubre de 2023 Astérix y Obélix regresan de la mano de un nuevo guionista, Fabrice Caro, p...</p>-->
# <!-- <p class="data">Editorial Bruño </p>-->
# <!-- Solo en móvil -->
# <div class="d-block d-block d-md-none">
# <div class="book-action__content--top d-flex d-md-none">
# <div class="book-price d-block d-md-none">
# <strong>
#                                                                 10.50€
#                             </strong>
#                             (10.10€ sin IVA)
#                                                     </div>
# </div>
# </div>
# <!-- Solo en móvil -->
# </div>
# </div>
# </div>
# <div class="col-12 col-sm-12 col-md-3 book-action">
# <div class="book-action__top d-felx justify-content-end">
# <a class="btn bookshelves-link" href="https://www.todostuslibros.com/login?_next=https://www.todostuslibros.com/libros/el-lirio-blanco_978-84-696-4040-1" title="Añadir a estantería">
# <i class="far fa-heart"></i>
# </a>
# </div>
# <div class="d-flex book-action__content">
# <div class="book-action__content--top d-none d-md-flex">
# <!-- Solo en desktop -->
# <div class="book-price">
# <strong>
#                                                         10.50€
#                         </strong>
#                         (10.10€ sin IVA)
#                                             </div>
# <div class="ratings grid-view">
# </div>
# <!-- //Solo en desktop -->
# </div>
# <div class="book-location">
# <form action="https://www.todostuslibros.com/b2c_add_to_cart" id="addToCart" method="POST">
# <input name="_token" type="hidden" value="v8ddx2xGXLupIiGdP5Eig9Tl59YhtDLwoUW1ILnd"/> <input name="isbn" type="hidden" value="978-84-696-4040-1"/>
# <button class="btn btn-add-to-cart b2c btn-block mb-2" type="submit">
# <!--<i class="fas fa-shopping-cart"></i> -->
#                 Añadir a la cesta
#                 </button>
# </form>
# <div class="availability-bookshops-pickup" data-allowres="1" data-isbn="978-84-696-4040-1">
# </div>
# </div>
# <div class="bookstores">
# <div class="availability-bookshops" data-allowres="1" data-isbn="978-84-696-4040-1"></div>
# <span class="availability availability-high">
# <i class="fas fa-check"></i> Disponibilidad alta
#     </span>
# </div>
# </div>
# </div>
# </li>
# <li class="book row" data-gtm-disponibilidad="" data-gtm-editorial="EDIBESA" data-gtm-index="6" data-gtm-isbn="978-84-19640-00-0" data-gtm-precio="2.65" data-gtm-titulo="EVANGELIO 2024 LETRA PEQUEÑA BOLSILLO" id="book_978-84-19640-00-0">
# <div class="col-12 col-sm-12 col-md-9 book-content">
# <div class="row">
# <div class="book-image col-4 col-sm-3 col-md-3 col-lg-3">
# <a href="https://www.todostuslibros.com/libros/evangelio-2024-letra-pequena-bolsillo_978-84-19640-00-0">
# <img alt="EVANGELIO 2024 LETRA PEQUEÑA BOLSILLO" height="150" src="https://static.cegal.es/imagenes/marcadas/9788419/978841964000.gif" title="EVANGELIO 2024 LETRA PEQUEÑA BOLSILLO" width="100"/>
# <span> 6 </span>
# </a>
# <!-- Solo Vista grid y móvil -->
# <a class="btn bookshelves-link" data-book-isbn="978-84-19640-00-0" data-book-title="EVANGELIO 2024 LETRA PEQUEÑA BOLSILLO" href="https://www.todostuslibros.com/login?_next=https://www.todostuslibros.com/libros/evangelio-2024-letra-pequena-bolsillo_978-84-19640-00-0" title="Añadir a estantería">
# <i class="far fa-heart"></i>
# </a>
# <!-- //Solo  Vista grid y móvil -->
# </div>
# <div class="book-details col-8 col-sm-9 col-md-9 col-lg-9 mb-2">
# <h2 class="title">
# <a href="https://www.todostuslibros.com/libros/evangelio-2024-letra-pequena-bolsillo_978-84-19640-00-0">
#                         EVANGELIO 2024 LETRA PEQUEÑA BOLSILLO
#                         </a>
# </h2>
# <h3 class="subtitle"><a href="https://www.todostuslibros.com/libros/evangelio-2024-letra-pequena-bolsillo_978-84-19640-00-0"></a></h3>
# <h3 class="author">
# <a href="https://www.todostuslibros.com/autor/martinez-puche-alvarez-luis-del-cerro">MARTINEZ PUCHE/ ALVAREZ,LUIS/ DEL CERRO</a>
# </h3>
# <div class="data_isbn d-none d-md-block">978-84-19640-00-0 </div>
# <div class="ratings list-view mb-3">
# </div>
# <p class="synopsis d-none d-md-block d-lg-block d-xl-block">Evangelio con el Papa Francisco. Ciclo B.  Una página por día.  Cada día una reflexión del papa  Francisco sobre el Evangelio.  Incluye: imágenes de santos, calendario litúrgico, santoral, oraciones y vida cristiana.</p>
# <!--<p class="synopsis">Evangelio con el Papa Francisco. Ciclo B.  Una página por día.  Cada día una reflexión del papa  Fra...</p>-->
# <!-- <p class="data">EDIBESA </p>-->
# <!-- Solo en móvil -->
# <div class="d-block d-block d-md-none">
# <div class="book-action__content--top d-flex d-md-none">
# <div class="book-price d-block d-md-none">
# <strong>
#                                                                 2.65€
#                             </strong>
#                             (2.55€ sin IVA)
#                                                     </div>
# </div>
# </div>
# <!-- Solo en móvil -->
# </div>
# </div>
# </div>
# <div class="col-12 col-sm-12 col-md-3 book-action">
# <div class="book-action__top d-felx justify-content-end">
# <a class="btn bookshelves-link" href="https://www.todostuslibros.com/login?_next=https://www.todostuslibros.com/libros/evangelio-2024-letra-pequena-bolsillo_978-84-19640-00-0" title="Añadir a estantería">
# <i class="far fa-heart"></i>
# </a>
# </div>
# <div class="d-flex book-action__content">
# <div class="book-action__content--top d-none d-md-flex">
# <!-- Solo en desktop -->
# <div class="book-price">
# <strong>
#                                                         2.65€
#                         </strong>
#                         (2.55€ sin IVA)
#                                             </div>
# <div class="ratings grid-view">
# </div>
# <!-- //Solo en desktop -->
# </div>
# <div class="book-location">
# <form action="https://www.todostuslibros.com/b2c_add_to_cart" id="addToCart" method="POST">
# <input name="_token" type="hidden" value="v8ddx2xGXLupIiGdP5Eig9Tl59YhtDLwoUW1ILnd"/> <input name="isbn" type="hidden" value="978-84-19640-00-0"/>
# <button class="btn btn-add-to-cart b2c btn-block mb-2" type="submit">
# <!--<i class="fas fa-shopping-cart"></i> -->
#                 Añadir a la cesta
#                 </button>
# </form>
# <div class="availability-bookshops-pickup" data-allowres="1" data-isbn="978-84-19640-00-0">
# </div>
# </div>
# <div class="bookstores">
# <div class="availability-bookshops" data-allowres="1" data-isbn="978-84-19640-00-0"></div>
# <span class="availability availability-medium">
# <i class="fas fa-check"></i> Disponibilidad media
#     </span>
# </div>
# </div>
# </div>
# </li>
# <li class="book row" data-gtm-disponibilidad="" data-gtm-editorial="ALFAGUARA" data-gtm-index="7" data-gtm-isbn="978-84-204-7636-0" data-gtm-precio="21.90" data-gtm-titulo="El problema final" id="book_978-84-204-7636-0">
# <div class="col-12 col-sm-12 col-md-9 book-content">
# <div class="row">
# <div class="book-image col-4 col-sm-3 col-md-3 col-lg-3">
# <a href="https://www.todostuslibros.com/libros/el-problema-final_978-84-204-7636-0">
# <img alt="El problema final" height="150" src="https://static.cegal.es/imagenes/marcadas/9788420/978842047636.gif" title="El problema final" width="100"/>
# <span> 7 </span>
# </a>
# <!-- Solo Vista grid y móvil -->
# <a class="btn bookshelves-link" data-book-isbn="978-84-204-7636-0" data-book-title="El problema final" href="https://www.todostuslibros.com/login?_next=https://www.todostuslibros.com/libros/el-problema-final_978-84-204-7636-0" title="Añadir a estantería">
# <i class="far fa-heart"></i>
# </a>
# <!-- //Solo  Vista grid y móvil -->
# </div>
# <div class="book-details col-8 col-sm-9 col-md-9 col-lg-9 mb-2">
# <h2 class="title">
# <a href="https://www.todostuslibros.com/libros/el-problema-final_978-84-204-7636-0">
#                         El problema final
#                         </a>
# </h2>
# <h3 class="subtitle"><a href="https://www.todostuslibros.com/libros/el-problema-final_978-84-204-7636-0"></a></h3>
# <h3 class="author">
# <a href="https://www.todostuslibros.com/autor/perez-reverte-arturo">Pérez-Reverte, Arturo</a>
# </h3>
# <div class="data_isbn d-none d-md-block">978-84-204-7636-0 </div>
# <div class="ratings list-view mb-3">
# </div>
# <p class="synopsis d-none d-md-block d-lg-block d-xl-block">LA NUEVA NOVELA DE ARTURO PÉREZ-REVERTE  Un crimen imposible. Un detective insospechado.  No se trata de un desafío entre el asesino y el detective, sino de un duelo de inteligencia entre el autor y el lector. —Haría falta un policía—sugirió alguien—. Un detective. —Tenemos uno —dijo Foxá.—Todos sig...</p>
# <!--<p class="synopsis">LA NUEVA NOVELA DE ARTURO PÉREZ-REVERTE  Un crimen imposible. Un detective insospechado.  No se trat...</p>-->
# <!-- <p class="data">ALFAGUARA </p>-->
# <!-- Solo en móvil -->
# <div class="d-block d-block d-md-none">
# <div class="book-action__content--top d-flex d-md-none">
# <div class="book-price d-block d-md-none">
# <strong>
#                                                                 21.90€
#                             </strong>
#                             (21.06€ sin IVA)
#                                                     </div>
# </div>
# </div>
# <!-- Solo en móvil -->
# </div>
# </div>
# </div>
# <div class="col-12 col-sm-12 col-md-3 book-action">
# <div class="book-action__top d-felx justify-content-end">
# <a class="btn bookshelves-link" href="https://www.todostuslibros.com/login?_next=https://www.todostuslibros.com/libros/el-problema-final_978-84-204-7636-0" title="Añadir a estantería">
# <i class="far fa-heart"></i>
# </a>
# </div>
# <div class="d-flex book-action__content">
# <div class="book-action__content--top d-none d-md-flex">
# <!-- Solo en desktop -->
# <div class="book-price">
# <strong>
#                                                         21.90€
#                         </strong>
#                         (21.06€ sin IVA)
#                                             </div>
# <div class="ratings grid-view">
# </div>
# <!-- //Solo en desktop -->
# </div>
# <div class="book-location">
# <form action="https://www.todostuslibros.com/b2c_add_to_cart" id="addToCart" method="POST">
# <input name="_token" type="hidden" value="v8ddx2xGXLupIiGdP5Eig9Tl59YhtDLwoUW1ILnd"/> <input name="isbn" type="hidden" value="978-84-204-7636-0"/>
# <button class="btn btn-add-to-cart b2c btn-block mb-2" type="submit">
# <!--<i class="fas fa-shopping-cart"></i> -->
#                 Añadir a la cesta
#                 </button>
# </form>
# <div class="availability-bookshops-pickup" data-allowres="1" data-isbn="978-84-204-7636-0">
# </div>
# </div>
# <div class="bookstores">
# <div class="availability-bookshops" data-allowres="1" data-isbn="978-84-204-7636-0"></div>
# <span class="availability availability-high">
# <i class="fas fa-check"></i> Disponibilidad alta
#     </span>
# </div>
# </div>
# </div>
# </li>
# <li class="book row" data-gtm-disponibilidad="" data-gtm-editorial="Diana Editorial" data-gtm-index="8" data-gtm-isbn="978-84-18118-03-6" data-gtm-precio="19.90" data-gtm-titulo="Hábitos atómicos" id="book_978-84-18118-03-6">
# <div class="col-12 col-sm-12 col-md-9 book-content">
# <div class="row">
# <div class="book-image col-4 col-sm-3 col-md-3 col-lg-3">
# <a href="https://www.todostuslibros.com/libros/habitos-atomicos_978-84-18118-03-6">
# <img alt="Hábitos atómicos" height="150" src="https://static.cegal.es/imagenes/marcadas/9788418/978841811803.gif" title="Hábitos atómicos" width="100"/>
# <span> 8 </span>
# </a>
# <!-- Solo Vista grid y móvil -->
# <a class="btn bookshelves-link" data-book-isbn="978-84-18118-03-6" data-book-title="Hábitos atómicos" href="https://www.todostuslibros.com/login?_next=https://www.todostuslibros.com/libros/habitos-atomicos_978-84-18118-03-6" title="Añadir a estantería">
# <i class="far fa-heart"></i>
# </a>
# <!-- //Solo  Vista grid y móvil -->
# </div>
# <div class="book-details col-8 col-sm-9 col-md-9 col-lg-9 mb-2">
# <h2 class="title">
# <a href="https://www.todostuslibros.com/libros/habitos-atomicos_978-84-18118-03-6">
#                         Hábitos atómicos
#                         </a>
# </h2>
# <h3 class="subtitle"><a href="https://www.todostuslibros.com/libros/habitos-atomicos_978-84-18118-03-6">Cambios pequeños, resultados extraordinarios</a></h3>
# <h3 class="author">
# <a href="https://www.todostuslibros.com/autor/clear-james">Clear, James</a>
# </h3>
# <div class="data_isbn d-none d-md-block">978-84-18118-03-6 </div>
# <div class="ratings list-view mb-3">
# </div>
# <p class="synopsis d-none d-md-block d-lg-block d-xl-block">MÁS DE 200.000 EJEMPLARES VENDIDOS EN ESPAÑA.
# 	MÁS DE 15 MILLONES DE EJEMPLARES VENDIDOS EN TODO EL MUNDO.
# 	«Sumamente práctico y útil.» MARK MANSON, autor de El sutil arte de que (casi todo) te importe una mi*rda
# 	«Paso a paso, cambiará tu rutina.» Financial Times
#
# 	A menudo pensamos que para camb...</p>
# <!--<p class="synopsis">MÁS DE 200.000 EJEMPLARES VENDIDOS EN ESPAÑA.
# 	MÁS DE 15 MILLONES DE EJEMPLARES VENDIDOS EN TODO EL...</p>-->
# <!-- <p class="data">Diana Editorial </p>-->
# <!-- Solo en móvil -->
# <div class="d-block d-block d-md-none">
# <div class="book-action__content--top d-flex d-md-none">
# <div class="book-price d-block d-md-none">
# <strong>
#                                                                 19.90€
#                             </strong>
#                             (19.13€ sin IVA)
#                                                     </div>
# </div>
# </div>
# <!-- Solo en móvil -->
# </div>
# </div>
# </div>
# <div class="col-12 col-sm-12 col-md-3 book-action">
# <div class="book-action__top d-felx justify-content-end">
# <a class="btn bookshelves-link" href="https://www.todostuslibros.com/login?_next=https://www.todostuslibros.com/libros/habitos-atomicos_978-84-18118-03-6" title="Añadir a estantería">
# <i class="far fa-heart"></i>
# </a>
# </div>
# <div class="d-flex book-action__content">
# <div class="book-action__content--top d-none d-md-flex">
# <!-- Solo en desktop -->
# <div class="book-price">
# <strong>
#                                                         19.90€
#                         </strong>
#                         (19.13€ sin IVA)
#                                             </div>
# <div class="ratings grid-view">
# </div>
# <!-- //Solo en desktop -->
# </div>
# <div class="book-location">
# <form action="https://www.todostuslibros.com/b2c_add_to_cart" id="addToCart" method="POST">
# <input name="_token" type="hidden" value="v8ddx2xGXLupIiGdP5Eig9Tl59YhtDLwoUW1ILnd"/> <input name="isbn" type="hidden" value="978-84-18118-03-6"/>
# <button class="btn btn-add-to-cart b2c btn-block mb-2" type="submit">
# <!--<i class="fas fa-shopping-cart"></i> -->
#                 Añadir a la cesta
#                 </button>
# </form>
# <div class="availability-bookshops-pickup" data-allowres="1" data-isbn="978-84-18118-03-6">
# </div>
# </div>
# <div class="bookstores">
# <div class="availability-bookshops" data-allowres="1" data-isbn="978-84-18118-03-6"></div>
# <span class="availability availability-high">
# <i class="fas fa-check"></i> Disponibilidad alta
#     </span>
# </div>
# </div>
# </div>
# </li>
# <li class="book row" data-gtm-disponibilidad="" data-gtm-editorial="Seix Barral" data-gtm-index="9" data-gtm-isbn="978-84-322-4232-8" data-gtm-precio="19.90" data-gtm-titulo="No te veré morir" id="book_978-84-322-4232-8">
# <div class="col-12 col-sm-12 col-md-9 book-content">
# <div class="row">
# <div class="book-image col-4 col-sm-3 col-md-3 col-lg-3">
# <a href="https://www.todostuslibros.com/libros/no-te-vere-morir_978-84-322-4232-8">
# <img alt="No te veré morir" height="150" src="https://static.cegal.es/imagenes/marcadas/9788432/978843224232.gif" title="No te veré morir" width="100"/>
# <span> 9 </span>
# </a>
# <!-- Solo Vista grid y móvil -->
# <a class="btn bookshelves-link" data-book-isbn="978-84-322-4232-8" data-book-title="No te veré morir" href="https://www.todostuslibros.com/login?_next=https://www.todostuslibros.com/libros/no-te-vere-morir_978-84-322-4232-8" title="Añadir a estantería">
# <i class="far fa-heart"></i>
# </a>
# <!-- //Solo  Vista grid y móvil -->
# </div>
# <div class="book-details col-8 col-sm-9 col-md-9 col-lg-9 mb-2">
# <h2 class="title">
# <a href="https://www.todostuslibros.com/libros/no-te-vere-morir_978-84-322-4232-8">
#                         No te veré morir
#                         </a>
# </h2>
# <h3 class="subtitle"><a href="https://www.todostuslibros.com/libros/no-te-vere-morir_978-84-322-4232-8"></a></h3>
# <h3 class="author">
# <a href="https://www.todostuslibros.com/autor/munoz-molina-antonio">Muñoz Molina, Antonio</a>
# </h3>
# <div class="data_isbn d-none d-md-block">978-84-322-4232-8 </div>
# <div class="ratings list-view mb-3">
# </div>
# <p class="synopsis d-none d-md-block d-lg-block d-xl-block">Durante su juventud, Gabriel Aristu y Adriana Zuber protagonizaron una apasionada historia de amor que parecía destinada a durar para siempre. El futuro, sin embargo, tenía otros planes para ellos. Separados durante cincuenta años por un océano de incomunicación, ella atrapada en la España de la dic...</p>
# <!--<p class="synopsis">Durante su juventud, Gabriel Aristu y Adriana Zuber protagonizaron una apasionada historia de amor q...</p>-->
# <!-- <p class="data">Seix Barral </p>-->
# <!-- Solo en móvil -->
# <div class="d-block d-block d-md-none">
# <div class="book-action__content--top d-flex d-md-none">
# <div class="book-price d-block d-md-none">
# <strong>
#                                                                 19.90€
#                             </strong>
#                             (19.13€ sin IVA)
#                                                     </div>
# </div>
# </div>
# <!-- Solo en móvil -->
# </div>
# </div>
# </div>
# <div class="col-12 col-sm-12 col-md-3 book-action">
# <div class="book-action__top d-felx justify-content-end">
# <a class="btn bookshelves-link" href="https://www.todostuslibros.com/login?_next=https://www.todostuslibros.com/libros/no-te-vere-morir_978-84-322-4232-8" title="Añadir a estantería">
# <i class="far fa-heart"></i>
# </a>
# </div>
# <div class="d-flex book-action__content">
# <div class="book-action__content--top d-none d-md-flex">
# <!-- Solo en desktop -->
# <div class="book-price">
# <strong>
#                                                         19.90€
#                         </strong>
#                         (19.13€ sin IVA)
#                                             </div>
# <div class="ratings grid-view">
# </div>
# <!-- //Solo en desktop -->
# </div>
# <div class="book-location">
# <form action="https://www.todostuslibros.com/b2c_add_to_cart" id="addToCart" method="POST">
# <input name="_token" type="hidden" value="v8ddx2xGXLupIiGdP5Eig9Tl59YhtDLwoUW1ILnd"/> <input name="isbn" type="hidden" value="978-84-322-4232-8"/>
# <button class="btn btn-add-to-cart b2c btn-block mb-2" type="submit">
# <!--<i class="fas fa-shopping-cart"></i> -->
#                 Añadir a la cesta
#                 </button>
# </form>
# <div class="availability-bookshops-pickup" data-allowres="1" data-isbn="978-84-322-4232-8">
# </div>
# </div>
# <div class="bookstores">
# <div class="availability-bookshops" data-allowres="1" data-isbn="978-84-322-4232-8"></div>
# <span class="availability availability-high">
# <i class="fas fa-check"></i> Disponibilidad alta
#     </span>
# </div>
# </div>
# </div>
# </li>
# <li class="book row" data-gtm-disponibilidad="" data-gtm-editorial="ALFAGUARA" data-gtm-index="10" data-gtm-isbn="978-84-204-6143-4" data-gtm-precio="18.90" data-gtm-titulo="Mirafiori" id="book_978-84-204-6143-4">
# <div class="col-12 col-sm-12 col-md-9 book-content">
# <div class="row">
# <div class="book-image col-4 col-sm-3 col-md-3 col-lg-3">
# <a href="https://www.todostuslibros.com/libros/mirafiori_978-84-204-6143-4">
# <img alt="Mirafiori" height="150" src="https://static.cegal.es/imagenes/marcadas/9788420/978842046143.gif" title="Mirafiori" width="100"/>
# <span> 10 </span>
# </a>
# <!-- Solo Vista grid y móvil -->
# <a class="btn bookshelves-link" data-book-isbn="978-84-204-6143-4" data-book-title="Mirafiori" href="https://www.todostuslibros.com/login?_next=https://www.todostuslibros.com/libros/mirafiori_978-84-204-6143-4" title="Añadir a estantería">
# <i class="far fa-heart"></i>
# </a>
# <!-- //Solo  Vista grid y móvil -->
# </div>
# <div class="book-details col-8 col-sm-9 col-md-9 col-lg-9 mb-2">
# <h2 class="title">
# <a href="https://www.todostuslibros.com/libros/mirafiori_978-84-204-6143-4">
#                         Mirafiori
#                         </a>
# </h2>
# <h3 class="subtitle"><a href="https://www.todostuslibros.com/libros/mirafiori_978-84-204-6143-4"></a></h3>
# <h3 class="author">
# <a href="https://www.todostuslibros.com/autor/jabois-manuel">Jabois, Manuel</a>
# </h3>
# <div class="data_isbn d-none d-md-block">978-84-204-6143-4 </div>
# <div class="ratings list-view mb-3">
# </div>
# <p class="synopsis d-none d-md-block d-lg-block d-xl-block">VUELVE EL MEJOR JABOIS CON UNA HISTORIA DE AMOR  Una novela sobre la belleza de todo aquello que no tiene explicación  «Jabois escribe en estado de gracia».Laura Barrachina, El Ojo Crítico «Si uno está enamorado de verdad, hasta en las almas más libres y salvajes y modernas, más seguras de sí mismas...</p>
# <!--<p class="synopsis">VUELVE EL MEJOR JABOIS CON UNA HISTORIA DE AMOR  Una novela sobre la belleza de todo aquello que no...</p>-->
# <!-- <p class="data">ALFAGUARA </p>-->
# <!-- Solo en móvil -->
# <div class="d-block d-block d-md-none">
# <div class="book-action__content--top d-flex d-md-none">
# <div class="book-price d-block d-md-none">
# <strong>
#                                                                 18.90€
#                             </strong>
#                             (18.17€ sin IVA)
#                                                     </div>
# </div>
# </div>
# <!-- Solo en móvil -->
# </div>
# </div>
# </div>
# <div class="col-12 col-sm-12 col-md-3 book-action">
# <div class="book-action__top d-felx justify-content-end">
# <a class="btn bookshelves-link" href="https://www.todostuslibros.com/login?_next=https://www.todostuslibros.com/libros/mirafiori_978-84-204-6143-4" title="Añadir a estantería">
# <i class="far fa-heart"></i>
# </a>
# </div>
# <div class="d-flex book-action__content">
# <div class="book-action__content--top d-none d-md-flex">
# <!-- Solo en desktop -->
# <div class="book-price">
# <strong>
#                                                         18.90€
#                         </strong>
#                         (18.17€ sin IVA)
#                                             </div>
# <div class="ratings grid-view">
# </div>
# <!-- //Solo en desktop -->
# </div>
# <div class="book-location">
# <form action="https://www.todostuslibros.com/b2c_add_to_cart" id="addToCart" method="POST">
# <input name="_token" type="hidden" value="v8ddx2xGXLupIiGdP5Eig9Tl59YhtDLwoUW1ILnd"/> <input name="isbn" type="hidden" value="978-84-204-6143-4"/>
# <button class="btn btn-add-to-cart b2c btn-block mb-2" type="submit">
# <!--<i class="fas fa-shopping-cart"></i> -->
#                 Añadir a la cesta
#                 </button>
# </form>
# <div class="availability-bookshops-pickup" data-allowres="1" data-isbn="978-84-204-6143-4">
# </div>
# </div>
# <div class="bookstores">
# <div class="availability-bookshops" data-allowres="1" data-isbn="978-84-204-6143-4"></div>
# <span class="availability availability-high">
# <i class="fas fa-check"></i> Disponibilidad alta
#     </span>
# </div>
# </div>
# </div>
# </li>
# <li class="book row" data-gtm-disponibilidad="" data-gtm-editorial="Editorial Funambulista" data-gtm-index="11" data-gtm-isbn="978-84-126587-9-8" data-gtm-precio="24.90" data-gtm-titulo="Dios - La ciencia - Las pruebas" id="book_978-84-126587-9-8">
# <div class="col-12 col-sm-12 col-md-9 book-content">
# <div class="row">
# <div class="book-image col-4 col-sm-3 col-md-3 col-lg-3">
# <a href="https://www.todostuslibros.com/libros/dios-la-ciencia-las-pruebas_978-84-126587-9-8">
# <img alt="Dios - La ciencia - Las pruebas" height="150" src="https://static.cegal.es/imagenes/marcadas/9788412/978841265879.gif" title="Dios - La ciencia - Las pruebas" width="100"/>
# <span> 11 </span>
# </a>
# <!-- Solo Vista grid y móvil -->
# <a class="btn bookshelves-link" data-book-isbn="978-84-126587-9-8" data-book-title="Dios - La ciencia - Las pruebas" href="https://www.todostuslibros.com/login?_next=https://www.todostuslibros.com/libros/dios-la-ciencia-las-pruebas_978-84-126587-9-8" title="Añadir a estantería">
# <i class="far fa-heart"></i>
# </a>
# <!-- //Solo  Vista grid y móvil -->
# </div>
# <div class="book-details col-8 col-sm-9 col-md-9 col-lg-9 mb-2">
# <h2 class="title">
# <a href="https://www.todostuslibros.com/libros/dios-la-ciencia-las-pruebas_978-84-126587-9-8">
#                         Dios - La ciencia - Las pruebas
#                         </a>
# </h2>
# <h3 class="subtitle"><a href="https://www.todostuslibros.com/libros/dios-la-ciencia-las-pruebas_978-84-126587-9-8">El albor de una revolución</a></h3>
# <h3 class="author">
# <a href="https://www.todostuslibros.com/autor/bollore-michel-yves-bonnassies-olivier">Bolloré, Michel-Yves / Bonnassies, Olivier</a>
# </h3>
# <div class="data_isbn d-none d-md-block">978-84-126587-9-8 </div>
# <div class="ratings list-view mb-3">
# </div>
# <p class="synopsis d-none d-md-block d-lg-block d-xl-block">En este libro se revelan, al cabo de tres años de trabajo en colaboración con unos veinte científicos y especialistas de alto nivel, las pruebas modernas de la existencia de Dios. Durante cerca de cuatro siglos, de Copérnico a Freud, pasando por Galileo y Darwin, los descubrimientos científicos se a...</p>
# <!--<p class="synopsis">En este libro se revelan, al cabo de tres años de trabajo en colaboración con unos veinte científico...</p>-->
# <!-- <p class="data">Editorial Funambulista </p>-->
# <!-- Solo en móvil -->
# <div class="d-block d-block d-md-none">
# <div class="book-action__content--top d-flex d-md-none">
# <div class="book-price d-block d-md-none">
# <strong>
#                                                                 24.90€
#                             </strong>
#                             (23.94€ sin IVA)
#                                                     </div>
# </div>
# </div>
# <!-- Solo en móvil -->
# </div>
# </div>
# </div>
# <div class="col-12 col-sm-12 col-md-3 book-action">
# <div class="book-action__top d-felx justify-content-end">
# <a class="btn bookshelves-link" href="https://www.todostuslibros.com/login?_next=https://www.todostuslibros.com/libros/dios-la-ciencia-las-pruebas_978-84-126587-9-8" title="Añadir a estantería">
# <i class="far fa-heart"></i>
# </a>
# </div>
# <div class="d-flex book-action__content">
# <div class="book-action__content--top d-none d-md-flex">
# <!-- Solo en desktop -->
# <div class="book-price">
# <strong>
#                                                         24.90€
#                         </strong>
#                         (23.94€ sin IVA)
#                                             </div>
# <div class="ratings grid-view">
# </div>
# <!-- //Solo en desktop -->
# </div>
# <div class="book-location">
# <form action="https://www.todostuslibros.com/b2c_add_to_cart" id="addToCart" method="POST">
# <input name="_token" type="hidden" value="v8ddx2xGXLupIiGdP5Eig9Tl59YhtDLwoUW1ILnd"/> <input name="isbn" type="hidden" value="978-84-126587-9-8"/>
# <button class="btn btn-add-to-cart b2c btn-block mb-2" type="submit">
# <!--<i class="fas fa-shopping-cart"></i> -->
#                 Añadir a la cesta
#                 </button>
# </form>
# <div class="availability-bookshops-pickup" data-allowres="1" data-isbn="978-84-126587-9-8">
# </div>
# </div>
# <div class="bookstores">
# <div class="availability-bookshops" data-allowres="1" data-isbn="978-84-126587-9-8"></div>
# <span class="availability availability-high">
# <i class="fas fa-check"></i> Disponibilidad alta
#     </span>
# </div>
# </div>
# </div>
# </li>
# <li class="book row" data-gtm-disponibilidad="" data-gtm-editorial="EDIBESA" data-gtm-index="12" data-gtm-isbn="978-84-19640-01-7" data-gtm-precio="4.60" data-gtm-titulo="EVANGELIO 2024 LETRA GRANDE" id="book_978-84-19640-01-7">
# <div class="col-12 col-sm-12 col-md-9 book-content">
# <div class="row">
# <div class="book-image col-4 col-sm-3 col-md-3 col-lg-3">
# <a href="https://www.todostuslibros.com/libros/evangelio-2024-letra-grande_978-84-19640-01-7">
# <img alt="EVANGELIO 2024 LETRA GRANDE" height="150" src="https://static.cegal.es/imagenes/marcadas/9788419/978841964001.gif" title="EVANGELIO 2024 LETRA GRANDE" width="100"/>
# <span> 12 </span>
# </a>
# <!-- Solo Vista grid y móvil -->
# <a class="btn bookshelves-link" data-book-isbn="978-84-19640-01-7" data-book-title="EVANGELIO 2024 LETRA GRANDE" href="https://www.todostuslibros.com/login?_next=https://www.todostuslibros.com/libros/evangelio-2024-letra-grande_978-84-19640-01-7" title="Añadir a estantería">
# <i class="far fa-heart"></i>
# </a>
# <!-- //Solo  Vista grid y móvil -->
# </div>
# <div class="book-details col-8 col-sm-9 col-md-9 col-lg-9 mb-2">
# <h2 class="title">
# <a href="https://www.todostuslibros.com/libros/evangelio-2024-letra-grande_978-84-19640-01-7">
#                         EVANGELIO 2024 LETRA GRANDE
#                         </a>
# </h2>
# <h3 class="subtitle"><a href="https://www.todostuslibros.com/libros/evangelio-2024-letra-grande_978-84-19640-01-7"></a></h3>
# <h3 class="author">
# <a href="https://www.todostuslibros.com/autor/martinez-puche-alvarez-luis-del-cerro">MARTINEZ PUCHE/ ALVAREZ,LUIS/ DEL CERRO</a>
# </h3>
# <div class="data_isbn d-none d-md-block">978-84-19640-01-7 </div>
# <div class="ratings list-view mb-3">
# </div>
# <p class="synopsis d-none d-md-block d-lg-block d-xl-block">Evangelio con el Papa Francisco. Ciclo B.  Una página por día.  Cada día una reflexión del papa  Francisco sobre el Evangelio.  Incluye: imágenes de santos, calendario litúrgico, santoral, oraciones y vida cristiana.</p>
# <!--<p class="synopsis">Evangelio con el Papa Francisco. Ciclo B.  Una página por día.  Cada día una reflexión del papa  Fra...</p>-->
# <!-- <p class="data">EDIBESA </p>-->
# <!-- Solo en móvil -->
# <div class="d-block d-block d-md-none">
# <div class="book-action__content--top d-flex d-md-none">
# <div class="book-price d-block d-md-none">
# <strong>
#                                                                 4.60€
#                             </strong>
#                             (4.42€ sin IVA)
#                                                     </div>
# </div>
# </div>
# <!-- Solo en móvil -->
# </div>
# </div>
# </div>
# <div class="col-12 col-sm-12 col-md-3 book-action">
# <div class="book-action__top d-felx justify-content-end">
# <a class="btn bookshelves-link" href="https://www.todostuslibros.com/login?_next=https://www.todostuslibros.com/libros/evangelio-2024-letra-grande_978-84-19640-01-7" title="Añadir a estantería">
# <i class="far fa-heart"></i>
# </a>
# </div>
# <div class="d-flex book-action__content">
# <div class="book-action__content--top d-none d-md-flex">
# <!-- Solo en desktop -->
# <div class="book-price">
# <strong>
#                                                         4.60€
#                         </strong>
#                         (4.42€ sin IVA)
#                                             </div>
# <div class="ratings grid-view">
# </div>
# <!-- //Solo en desktop -->
# </div>
# <div class="book-location">
# <form action="https://www.todostuslibros.com/b2c_add_to_cart" id="addToCart" method="POST">
# <input name="_token" type="hidden" value="v8ddx2xGXLupIiGdP5Eig9Tl59YhtDLwoUW1ILnd"/> <input name="isbn" type="hidden" value="978-84-19640-01-7"/>
# <button class="btn btn-add-to-cart b2c btn-block mb-2" type="submit">
# <!--<i class="fas fa-shopping-cart"></i> -->
#                 Añadir a la cesta
#                 </button>
# </form>
# <div class="availability-bookshops-pickup" data-allowres="1" data-isbn="978-84-19640-01-7">
# </div>
# </div>
# <div class="bookstores">
# <div class="availability-bookshops" data-allowres="1" data-isbn="978-84-19640-01-7"></div>
# <span class="availability availability-medium">
# <i class="fas fa-check"></i> Disponibilidad media
#     </span>
# </div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <nav>
# <ul class="pagination">
# <li aria-disabled="true" aria-label="« Anterior" class="page-item disabled">
# <span aria-hidden="true" class="page-link">‹</span>
# </li>
# <li aria-current="page" class="page-item active"><span class="page-link">1</span></li>
# <li class="page-item"><a class="page-link" href="http://www.todostuslibros.com/mas_vendidos?page=2">2</a></li>
# <li class="page-item"><a class="page-link" href="http://www.todostuslibros.com/mas_vendidos?page=3">3</a></li>
# <li class="page-item"><a class="page-link" href="http://www.todostuslibros.com/mas_vendidos?page=4">4</a></li>
# <li class="page-item"><a class="page-link" href="http://www.todostuslibros.com/mas_vendidos?page=5">5</a></li>
# <li class="page-item"><a class="page-link" href="http://www.todostuslibros.com/mas_vendidos?page=6">6</a></li>
# <li class="page-item"><a class="page-link" href="http://www.todostuslibros.com/mas_vendidos?page=7">7</a></li>
# <li class="page-item"><a class="page-link" href="http://www.todostuslibros.com/mas_vendidos?page=8">8</a></li>
# <li class="page-item"><a class="page-link" href="http://www.todostuslibros.com/mas_vendidos?page=9">9</a></li>
# <li class="page-item">
# <a aria-label="Siguiente »" class="page-link" href="http://www.todostuslibros.com/mas_vendidos?page=2" rel="next">›</a>
# </li>
# </ul>
# </nav>
# </div>
# </div>
# </div>
# </main>

# %% [markdown]
# ## Get titles

# %%
titles_info = body.find_all("li", {"class":"book row"})
titles_info
# Out:
# [<li class="book row" data-gtm-disponibilidad="" data-gtm-editorial="B" data-gtm-index="1" data-gtm-isbn="978-84-666-7568-0" data-gtm-precio="22.90" data-gtm-titulo="Todo vuelve (Todo arde 2)" id="book_978-84-666-7568-0">
#  <div class="col-12 col-sm-12 col-md-9 book-content">
#  <div class="row">
#  <div class="book-image col-4 col-sm-3 col-md-3 col-lg-3">
#  <a href="https://www.todostuslibros.com/libros/todo-vuelve-todo-arde-2_978-84-666-7568-0">
#  <img alt="Todo vuelve (Todo arde 2)" height="150" src="https://static.cegal.es/imagenes/marcadas/9788466/978846667568.gif" title="Todo vuelve (Todo arde 2)" width="100"/>
#  <span> 1 </span>
#  </a>
#  <!-- Solo Vista grid y móvil -->
#  <a class="btn bookshelves-link" data-book-isbn="978-84-666-7568-0" data-book-title="Todo vuelve (Todo arde 2)" href="https://www.todostuslibros.com/login?_next=https://www.todostuslibros.com/libros/todo-vuelve-todo-arde-2_978-84-666-7568-0" title="Añadir a estantería">
#  <i class="far fa-heart"></i>
#  </a>
#  <!-- //Solo  Vista grid y móvil -->
#  </div>
#  <div class="book-details col-8 col-sm-9 col-md-9 col-lg-9 mb-2">
#  <h2 class="title">
#  <a href="https://www.todostuslibros.com/libros/todo-vuelve-todo-arde-2_978-84-666-7568-0">
#                          Todo vuelve (Todo arde 2)
#                          </a>
#  </h2>
#  <h3 class="subtitle"><a href="https://www.todostuslibros.com/libros/todo-vuelve-todo-arde-2_978-84-666-7568-0"></a></h3>
#  <h3 class="author">
#  <a href="https://www.todostuslibros.com/autor/gomez-jurado-juan">Gómez-Jurado, Juan</a>
#  </h3>
#  <div class="data_isbn d-none d-md-block">978-84-666-7568-0 </div>
#  <div class="ratings list-view mb-3">
#  </div>
#  <p class="synopsis d-none d-md-block d-lg-block d-xl-block">VUELVE EL AUTOR MÁS VENDIDO EN LENGUA ESPAÑOLA  Tras el enorme éxito de REINA ROJA y TODO ARDE, continúa la saga que ha conquistado al mundo.  «Me rindo a los pies del mejor escritor actual de thriller».ZENDA UN PLAN IMPOSIBLETodo lo que Aura Reyes necesita es continuar con vida diez minutos más. No...</p>
#  <!--<p class="synopsis">VUELVE EL AUTOR MÁS VENDIDO EN LENGUA ESPAÑOLA  Tras el enorme éxito de REINA ROJA y TODO ARDE, cont...</p>-->
#  <!-- <p class="data">B </p>-->
#  <!-- Solo en móvil -->
#  <div class="d-block d-block d-md-none">
#  <div class="book-action__content--top d-flex d-md-none">
#  <div class="book-price d-block d-md-none">
#  <strong>
#                                                                  22.90€
#                              </strong>
#                              (22.02€ sin IVA)
#                                                      </div>
#  </div>
#  </div>
#  <!-- Solo en móvil -->
#  </div>
#  </div>
#  </div>
#  <div class="col-12 col-sm-12 col-md-3 book-action">
#  <div class="book-action__top d-felx justify-content-end">
#  <a class="btn bookshelves-link" href="https://www.todostuslibros.com/login?_next=https://www.todostuslibros.com/libros/todo-vuelve-todo-arde-2_978-84-666-7568-0" title="Añadir a estantería">
#  <i class="far fa-heart"></i>
#  </a>
#  </div>
#  <div class="d-flex book-action__content">
#  <div class="book-action__content--top d-none d-md-flex">
#  <!-- Solo en desktop -->
#  <div class="book-price">
#  <strong>
#                                                          22.90€
#                          </strong>
#                          (22.02€ sin IVA)
#                                              </div>
#  <div class="ratings grid-view">
#  </div>
#  <!-- //Solo en desktop -->
#  </div>
#  <div class="book-location">
#  <form action="https://www.todostuslibros.com/b2c_add_to_cart" id="addToCart" method="POST">
#  <input name="_token" type="hidden" value="v8ddx2xGXLupIiGdP5Eig9Tl59YhtDLwoUW1ILnd"/> <input name="isbn" type="hidden" value="978-84-666-7568-0"/>
#  <button class="btn btn-add-to-cart b2c btn-block mb-2" type="submit">
#  <!--<i class="fas fa-shopping-cart"></i> -->
#                  Añadir a la cesta
#                  </button>
#  </form>
#  <div class="availability-bookshops-pickup" data-allowres="1" data-isbn="978-84-666-7568-0">
#  </div>
#  </div>
#  <div class="bookstores">
#  <div class="availability-bookshops" data-allowres="1" data-isbn="978-84-666-7568-0"></div>
#  <span class="availability availability-high">
#  <i class="fas fa-check"></i> Disponibilidad alta
#      </span>
#  </div>
#  </div>
#  </div>
#  </li>,
#  <li class="book row" data-gtm-disponibilidad="" data-gtm-editorial="Editorial Planeta" data-gtm-index="2" data-gtm-isbn="978-84-08-27758-3" data-gtm-precio="22.90" data-gtm-titulo="El Infierno" id="book_978-84-08-27758-3">
#  <div class="col-12 col-sm-12 col-md-9 book-content">
#  <div class="row">
#  <div class="book-image col-4 col-sm-3 col-md-3 col-lg-3">
#  <a href="https://www.todostuslibros.com/libros/el-infierno_978-84-08-27758-3">
#  <img alt="El Infierno" height="150" src="https://static.cegal.es/imagenes/marcadas/9788408/978840827758.gif" title="El Infierno" width="100"/>
#  <span> 2 </span>
#  </a>
#  <!-- Solo Vista grid y móvil -->
#  <a class="btn bookshelves-link" data-book-isbn="978-84-08-27758-3" data-book-title="El Infierno" href="https://www.todostuslibros.com/login?_next=https://www.todostuslibros.com/libros/el-infierno_978-84-08-27758-3" title="Añadir a estantería">
#  <i class="far fa-heart"></i>
#  </a>
#  <!-- //Solo  Vista grid y móvil -->
#  </div>
#  <div class="book-details col-8 col-sm-9 col-md-9 col-lg-9 mb-2">
#  <h2 class="title">
#  <a href="https://www.todostuslibros.com/libros/el-infierno_978-84-08-27758-3">
#                          El Infierno
#                          </a>
#  </h2>
#  <h3 class="subtitle"><a href="https://www.todostuslibros.com/libros/el-infierno_978-84-08-27758-3"></a></h3>
#  <h3 class="author">
#  <a href="https://www.todostuslibros.com/autor/mola-carmen">Mola, Carmen</a>
#  </h3>
#  <div class="data_isbn d-none d-md-block">978-84-08-27758-3 </div>
#  <div class="ratings list-view mb-3">
#  </div>
#  <p class="synopsis d-none d-md-block d-lg-block d-xl-block">Salvaje, perturbador, cruel.
#  	EL NUEVO Y BRUTAL THRILLER DE CARMEN MOLA QUE MÁS DE 2 MILLONES DE LECTORES ESTÁN ESPERANDO.
#  	Lo que parecía un paraíso se terminó convirtiendo en un infierno. Una novela negra impactante y perturbadora al más puro estilo Carmen Mola.
#  	Un terrible levantamiento del ejér...</p>
#  <!--<p class="synopsis">Salvaje, perturbador, cruel.
#  	EL NUEVO Y BRUTAL THRILLER DE CARMEN MOLA QUE MÁS DE 2 MILLONES DE LEC...</p>-->
#  <!-- <p class="data">Editorial Planeta </p>-->
#  <!-- Solo en móvil -->
#  <div class="d-block d-block d-md-none">
#  <div class="book-action__content--top d-flex d-md-none">
#  <div class="book-price d-block d-md-none">
#  <strong>
#                                                                  22.90€
#                              </strong>
#                              (22.02€ sin IVA)
#                                                      </div>
#  </div>
#  </div>
#  <!-- Solo en móvil -->
#  </div>
#  </div>
#  </div>
#  <div class="col-12 col-sm-12 col-md-3 book-action">
#  <div class="book-action__top d-felx justify-content-end">
#  <a class="btn bookshelves-link" href="https://www.todostuslibros.com/login?_next=https://www.todostuslibros.com/libros/el-infierno_978-84-08-27758-3" title="Añadir a estantería">
#  <i class="far fa-heart"></i>
#  </a>
#  </div>
#  <div class="d-flex book-action__content">
#  <div class="book-action__content--top d-none d-md-flex">
#  <!-- Solo en desktop -->
#  <div class="book-price">
#  <strong>
#                                                          22.90€
#                          </strong>
#                          (22.02€ sin IVA)
#                                              </div>
#  <div class="ratings grid-view">
#  </div>
#  <!-- //Solo en desktop -->
#  </div>
#  <div class="book-location">
#  <form action="https://www.todostuslibros.com/b2c_add_to_cart" id="addToCart" method="POST">
#  <input name="_token" type="hidden" value="v8ddx2xGXLupIiGdP5Eig9Tl59YhtDLwoUW1ILnd"/> <input name="isbn" type="hidden" value="978-84-08-27758-3"/>
#  <button class="btn btn-add-to-cart b2c btn-block mb-2" type="submit">
#  <!--<i class="fas fa-shopping-cart"></i> -->
#                  Añadir a la cesta
#                  </button>
#  </form>
#  <div class="availability-bookshops-pickup" data-allowres="1" data-isbn="978-84-08-27758-3">
#  </div>
#  </div>
#  <div class="bookstores">
#  <div class="availability-bookshops" data-allowres="1" data-isbn="978-84-08-27758-3"></div>
#  <span class="availability availability-high">
#  <i class="fas fa-check"></i> Disponibilidad alta
#      </span>
#  </div>
#  </div>
#  </div>
#  </li>,
#  <li class="book row" data-gtm-disponibilidad="" data-gtm-editorial="PLAZA &amp; JANES" data-gtm-index="3" data-gtm-isbn="978-84-01-03013-0" data-gtm-precio="24.90" data-gtm-titulo="La armadura de la luz (Saga Los pilares de la Tierra 4)" id="book_978-84-01-03013-0">
#  <div class="col-12 col-sm-12 col-md-9 book-content">
#  <div class="row">
#  <div class="book-image col-4 col-sm-3 col-md-3 col-lg-3">
#  <a href="https://www.todostuslibros.com/libros/la-armadura-de-la-luz-saga-los-pilares-de-la-tierra-4_978-84-01-03013-0">
#  <img alt="La armadura de la luz (Saga Los pilares de la Tierra 4)" height="150" src="https://static.cegal.es/imagenes/marcadas/9788401/978840103013.gif" title="La armadura de la luz (Saga Los pilares de la Tierra 4)" width="100"/>
#  <span> 3 </span>
#  </a>
#  <!-- Solo Vista grid y móvil -->
#  <a class="btn bookshelves-link" data-book-isbn="978-84-01-03013-0" data-book-title="La armadura de la luz (Saga Los pilares de la Tierra 4)" href="https://www.todostuslibros.com/login?_next=https://www.todostuslibros.com/libros/la-armadura-de-la-luz-saga-los-pilares-de-la-tierra-4_978-84-01-03013-0" title="Añadir a estantería">
#  <i class="far fa-heart"></i>
#  </a>
#  <!-- //Solo  Vista grid y móvil -->
#  </div>
#  <div class="book-details col-8 col-sm-9 col-md-9 col-lg-9 mb-2">
#  <h2 class="title">
#  <a href="https://www.todostuslibros.com/libros/la-armadura-de-la-luz-saga-los-pilares-de-la-tierra-4_978-84-01-03013-0">
#                          La armadura de la luz (Saga Los pilares de la Tierra 4)
#                          </a>
#  </h2>
#  <h3 class="subtitle"><a href="https://www.todostuslibros.com/libros/la-armadura-de-la-luz-saga-los-pilares-de-la-tierra-4_978-84-01-03013-0"></a></h3>
#  <h3 class="author">
#  <a href="https://www.todostuslibros.com/autor/follett-ken">Follett, Ken</a>
#  </h3>
#  <div class="data_isbn d-none d-md-block">978-84-01-03013-0 </div>
#  <div class="ratings list-view mb-3">
#  </div>
#  <p class="synopsis d-none d-md-block d-lg-block d-xl-block">Vuelve el mejor Follett con la emocionante quinta entrega de la saga «Los pilares de la Tierra». El choque de progreso y tradición y una guerra que amenaza con engullir toda Europa en la más ambiciosa y épica novela del maestro de la ficción histórica. La revolución está en el aire1792. Un gobierno...</p>
#  <!--<p class="synopsis">Vuelve el mejor Follett con la emocionante quinta entrega de la saga «Los pilares de la Tierra». El...</p>-->
#  <!-- <p class="data">PLAZA &amp; JANES </p>-->
#  <!-- Solo en móvil -->
#  <div class="d-block d-block d-md-none">
#  <div class="book-action__content--top d-flex d-md-none">
#  <div class="book-price d-block d-md-none">
#  <strong>
#                                                                  24.90€
#                              </strong>
#                              (23.94€ sin IVA)
#                                                      </div>
#  </div>
#  </div>
#  <!-- Solo en móvil -->
#  </div>
#  </div>
#  </div>
#  <div class="col-12 col-sm-12 col-md-3 book-action">
#  <div class="book-action__top d-felx justify-content-end">
#  <a class="btn bookshelves-link" href="https://www.todostuslibros.com/login?_next=https://www.todostuslibros.com/libros/la-armadura-de-la-luz-saga-los-pilares-de-la-tierra-4_978-84-01-03013-0" title="Añadir a estantería">
#  <i class="far fa-heart"></i>
#  </a>
#  </div>
#  <div class="d-flex book-action__content">
#  <div class="book-action__content--top d-none d-md-flex">
#  <!-- Solo en desktop -->
#  <div class="book-price">
#  <strong>
#                                                          24.90€
#                          </strong>
#                          (23.94€ sin IVA)
#                                              </div>
#  <div class="ratings grid-view">
#  </div>
#  <!-- //Solo en desktop -->
#  </div>
#  <div class="book-location">
#  <form action="https://www.todostuslibros.com/b2c_add_to_cart" id="addToCart" method="POST">
#  <input name="_token" type="hidden" value="v8ddx2xGXLupIiGdP5Eig9Tl59YhtDLwoUW1ILnd"/> <input name="isbn" type="hidden" value="978-84-01-03013-0"/>
#  <button class="btn btn-add-to-cart b2c btn-block mb-2" type="submit">
#  <!--<i class="fas fa-shopping-cart"></i> -->
#                  Añadir a la cesta
#                  </button>
#  </form>
#  <div class="availability-bookshops-pickup" data-allowres="1" data-isbn="978-84-01-03013-0">
#  </div>
#  </div>
#  <div class="bookstores">
#  <div class="availability-bookshops" data-allowres="1" data-isbn="978-84-01-03013-0"></div>
#  <span class="availability availability-high">
#  <i class="fas fa-check"></i> Disponibilidad alta
#      </span>
#  </div>
#  </div>
#  </div>
#  </li>,
#  <li class="book row" data-gtm-disponibilidad="" data-gtm-editorial="Libros Cúpula" data-gtm-index="4" data-gtm-isbn="978-84-480-3897-7" data-gtm-precio="19.90" data-gtm-titulo="La chica del verano" id="book_978-84-480-3897-7">
#  <div class="col-12 col-sm-12 col-md-9 book-content">
#  <div class="row">
#  <div class="book-image col-4 col-sm-3 col-md-3 col-lg-3">
#  <a href="https://www.todostuslibros.com/libros/la-chica-del-verano_978-84-480-3897-7">
#  <img alt="La chica del verano" height="150" src="https://static.cegal.es/imagenes/marcadas/9788448/978844803897.gif" title="La chica del verano" width="100"/>
#  <span> 4 </span>
#  </a>
#  <!-- Solo Vista grid y móvil -->
#  <a class="btn bookshelves-link" data-book-isbn="978-84-480-3897-7" data-book-title="La chica del verano" href="https://www.todostuslibros.com/login?_next=https://www.todostuslibros.com/libros/la-chica-del-verano_978-84-480-3897-7" title="Añadir a estantería">
#  <i class="far fa-heart"></i>
#  </a>
#  <!-- //Solo  Vista grid y móvil -->
#  </div>
#  <div class="book-details col-8 col-sm-9 col-md-9 col-lg-9 mb-2">
#  <h2 class="title">
#  <a href="https://www.todostuslibros.com/libros/la-chica-del-verano_978-84-480-3897-7">
#                          La chica del verano
#                          </a>
#  </h2>
#  <h3 class="subtitle"><a href="https://www.todostuslibros.com/libros/la-chica-del-verano_978-84-480-3897-7">Los finales felices son para los valientes</a></h3>
#  <h3 class="author">
#  <a href="https://www.todostuslibros.com/autor/la-vecina-rubia">La Vecina Rubia</a>
#  </h3>
#  <div class="data_isbn d-none d-md-block">978-84-480-3897-7 </div>
#  <div class="ratings list-view mb-3">
#  </div>
#  <p class="synopsis d-none d-md-block d-lg-block d-xl-block">La primera edición especial incluye una dedicatoria manuscrita impresa escrita por la autora.Así quería ser yo: anónima. Oculta, pero presente.
#
#  	La vida está llena de etapas, algunas preciosas e inolvidables, otras más difíciles y complicadas, lo importante es saber cuándo hay que cerrar cada una...</p>
#  <!--<p class="synopsis">La primera edición especial incluye una dedicatoria manuscrita impresa escrita por la autora.Así que...</p>-->
#  <!-- <p class="data">Libros Cúpula </p>-->
#  <!-- Solo en móvil -->
#  <div class="d-block d-block d-md-none">
#  <div class="book-action__content--top d-flex d-md-none">
#  <div class="book-price d-block d-md-none">
#  <strong>
#                                                                  19.90€
#                              </strong>
#                              (19.13€ sin IVA)
#                                                      </div>
#  </div>
#  </div>
#  <!-- Solo en móvil -->
#  </div>
#  </div>
#  </div>
#  <div class="col-12 col-sm-12 col-md-3 book-action">
#  <div class="book-action__top d-felx justify-content-end">
#  <a class="btn bookshelves-link" href="https://www.todostuslibros.com/login?_next=https://www.todostuslibros.com/libros/la-chica-del-verano_978-84-480-3897-7" title="Añadir a estantería">
#  <i class="far fa-heart"></i>
#  </a>
#  </div>
#  <div class="d-flex book-action__content">
#  <div class="book-action__content--top d-none d-md-flex">
#  <!-- Solo en desktop -->
#  <div class="book-price">
#  <strong>
#                                                          19.90€
#                          </strong>
#                          (19.13€ sin IVA)
#                                              </div>
#  <div class="ratings grid-view">
#  </div>
#  <!-- //Solo en desktop -->
#  </div>
#  <div class="book-location">
#  <form action="https://www.todostuslibros.com/b2c_add_to_cart" id="addToCart" method="POST">
#  <input name="_token" type="hidden" value="v8ddx2xGXLupIiGdP5Eig9Tl59YhtDLwoUW1ILnd"/> <input name="isbn" type="hidden" value="978-84-480-3897-7"/>
#  <button class="btn btn-add-to-cart b2c btn-block mb-2" type="submit">
#  <!--<i class="fas fa-shopping-cart"></i> -->
#                  Añadir a la cesta
#                  </button>
#  </form>
#  <div class="availability-bookshops-pickup" data-allowres="1" data-isbn="978-84-480-3897-7">
#  </div>
#  </div>
#  <div class="bookstores">
#  <div class="availability-bookshops" data-allowres="1" data-isbn="978-84-480-3897-7"></div>
#  <span class="availability availability-high">
#  <i class="fas fa-check"></i> Disponibilidad alta
#      </span>
#  </div>
#  </div>
#  </div>
#  </li>,
#  <li class="book row" data-gtm-disponibilidad="" data-gtm-editorial="Editorial Bruño" data-gtm-index="5" data-gtm-isbn="978-84-696-4040-1" data-gtm-precio="10.50" data-gtm-titulo="El Lirio Blanco" id="book_978-84-696-4040-1">
#  <div class="col-12 col-sm-12 col-md-9 book-content">
#  <div class="row">
#  <div class="book-image col-4 col-sm-3 col-md-3 col-lg-3">
#  <a href="https://www.todostuslibros.com/libros/el-lirio-blanco_978-84-696-4040-1">
#  <img alt="El Lirio Blanco" height="150" src="https://static.cegal.es/imagenes/marcadas/9788469/978846964040.gif" title="El Lirio Blanco" width="100"/>
#  <span> 5 </span>
#  </a>
#  <!-- Solo Vista grid y móvil -->
#  <a class="btn bookshelves-link" data-book-isbn="978-84-696-4040-1" data-book-title="El Lirio Blanco" href="https://www.todostuslibros.com/login?_next=https://www.todostuslibros.com/libros/el-lirio-blanco_978-84-696-4040-1" title="Añadir a estantería">
#  <i class="far fa-heart"></i>
#  </a>
#  <!-- //Solo  Vista grid y móvil -->
#  </div>
#  <div class="book-details col-8 col-sm-9 col-md-9 col-lg-9 mb-2">
#  <h2 class="title">
#  <a href="https://www.todostuslibros.com/libros/el-lirio-blanco_978-84-696-4040-1">
#                          El Lirio Blanco
#                          </a>
#  </h2>
#  <h3 class="subtitle"><a href="https://www.todostuslibros.com/libros/el-lirio-blanco_978-84-696-4040-1"></a></h3>
#  <h3 class="author">
#  <a href="https://www.todostuslibros.com/autor/goscinny-rene-fabcaro">Goscinny, René / Fabcaro</a>
#  </h3>
#  <div class="data_isbn d-none d-md-block">978-84-696-4040-1 </div>
#  <div class="ratings list-view mb-3">
#  </div>
#  <p class="synopsis d-none d-md-block d-lg-block d-xl-block">El 26 de octubre de 2023 Astérix y Obélix regresan de la mano de un nuevo guionista, Fabrice Caro, para disfrutar de su aventura número 40. El título de este cómic es El Lirio Blanco, el nombre de una nueva corriente de pensamiento positivo que recorre Roma y se extiende por todo el Imperio a la vel...</p>
#  <!--<p class="synopsis">El 26 de octubre de 2023 Astérix y Obélix regresan de la mano de un nuevo guionista, Fabrice Caro, p...</p>-->
#  <!-- <p class="data">Editorial Bruño </p>-->
#  <!-- Solo en móvil -->
#  <div class="d-block d-block d-md-none">
#  <div class="book-action__content--top d-flex d-md-none">
#  <div class="book-price d-block d-md-none">
#  <strong>
#                                                                  10.50€
#                              </strong>
#                              (10.10€ sin IVA)
#                                                      </div>
#  </div>
#  </div>
#  <!-- Solo en móvil -->
#  </div>
#  </div>
#  </div>
#  <div class="col-12 col-sm-12 col-md-3 book-action">
#  <div class="book-action__top d-felx justify-content-end">
#  <a class="btn bookshelves-link" href="https://www.todostuslibros.com/login?_next=https://www.todostuslibros.com/libros/el-lirio-blanco_978-84-696-4040-1" title="Añadir a estantería">
#  <i class="far fa-heart"></i>
#  </a>
#  </div>
#  <div class="d-flex book-action__content">
#  <div class="book-action__content--top d-none d-md-flex">
#  <!-- Solo en desktop -->
#  <div class="book-price">
#  <strong>
#                                                          10.50€
#                          </strong>
#                          (10.10€ sin IVA)
#                                              </div>
#  <div class="ratings grid-view">
#  </div>
#  <!-- //Solo en desktop -->
#  </div>
#  <div class="book-location">
#  <form action="https://www.todostuslibros.com/b2c_add_to_cart" id="addToCart" method="POST">
#  <input name="_token" type="hidden" value="v8ddx2xGXLupIiGdP5Eig9Tl59YhtDLwoUW1ILnd"/> <input name="isbn" type="hidden" value="978-84-696-4040-1"/>
#  <button class="btn btn-add-to-cart b2c btn-block mb-2" type="submit">
#  <!--<i class="fas fa-shopping-cart"></i> -->
#                  Añadir a la cesta
#                  </button>
#  </form>
#  <div class="availability-bookshops-pickup" data-allowres="1" data-isbn="978-84-696-4040-1">
#  </div>
#  </div>
#  <div class="bookstores">
#  <div class="availability-bookshops" data-allowres="1" data-isbn="978-84-696-4040-1"></div>
#  <span class="availability availability-high">
#  <i class="fas fa-check"></i> Disponibilidad alta
#      </span>
#  </div>
#  </div>
#  </div>
#  </li>,
#  <li class="book row" data-gtm-disponibilidad="" data-gtm-editorial="EDIBESA" data-gtm-index="6" data-gtm-isbn="978-84-19640-00-0" data-gtm-precio="2.65" data-gtm-titulo="EVANGELIO 2024 LETRA PEQUEÑA BOLSILLO" id="book_978-84-19640-00-0">
#  <div class="col-12 col-sm-12 col-md-9 book-content">
#  <div class="row">
#  <div class="book-image col-4 col-sm-3 col-md-3 col-lg-3">
#  <a href="https://www.todostuslibros.com/libros/evangelio-2024-letra-pequena-bolsillo_978-84-19640-00-0">
#  <img alt="EVANGELIO 2024 LETRA PEQUEÑA BOLSILLO" height="150" src="https://static.cegal.es/imagenes/marcadas/9788419/978841964000.gif" title="EVANGELIO 2024 LETRA PEQUEÑA BOLSILLO" width="100"/>
#  <span> 6 </span>
#  </a>
#  <!-- Solo Vista grid y móvil -->
#  <a class="btn bookshelves-link" data-book-isbn="978-84-19640-00-0" data-book-title="EVANGELIO 2024 LETRA PEQUEÑA BOLSILLO" href="https://www.todostuslibros.com/login?_next=https://www.todostuslibros.com/libros/evangelio-2024-letra-pequena-bolsillo_978-84-19640-00-0" title="Añadir a estantería">
#  <i class="far fa-heart"></i>
#  </a>
#  <!-- //Solo  Vista grid y móvil -->
#  </div>
#  <div class="book-details col-8 col-sm-9 col-md-9 col-lg-9 mb-2">
#  <h2 class="title">
#  <a href="https://www.todostuslibros.com/libros/evangelio-2024-letra-pequena-bolsillo_978-84-19640-00-0">
#                          EVANGELIO 2024 LETRA PEQUEÑA BOLSILLO
#                          </a>
#  </h2>
#  <h3 class="subtitle"><a href="https://www.todostuslibros.com/libros/evangelio-2024-letra-pequena-bolsillo_978-84-19640-00-0"></a></h3>
#  <h3 class="author">
#  <a href="https://www.todostuslibros.com/autor/martinez-puche-alvarez-luis-del-cerro">MARTINEZ PUCHE/ ALVAREZ,LUIS/ DEL CERRO</a>
#  </h3>
#  <div class="data_isbn d-none d-md-block">978-84-19640-00-0 </div>
#  <div class="ratings list-view mb-3">
#  </div>
#  <p class="synopsis d-none d-md-block d-lg-block d-xl-block">Evangelio con el Papa Francisco. Ciclo B.  Una página por día.  Cada día una reflexión del papa  Francisco sobre el Evangelio.  Incluye: imágenes de santos, calendario litúrgico, santoral, oraciones y vida cristiana.</p>
#  <!--<p class="synopsis">Evangelio con el Papa Francisco. Ciclo B.  Una página por día.  Cada día una reflexión del papa  Fra...</p>-->
#  <!-- <p class="data">EDIBESA </p>-->
#  <!-- Solo en móvil -->
#  <div class="d-block d-block d-md-none">
#  <div class="book-action__content--top d-flex d-md-none">
#  <div class="book-price d-block d-md-none">
#  <strong>
#                                                                  2.65€
#                              </strong>
#                              (2.55€ sin IVA)
#                                                      </div>
#  </div>
#  </div>
#  <!-- Solo en móvil -->
#  </div>
#  </div>
#  </div>
#  <div class="col-12 col-sm-12 col-md-3 book-action">
#  <div class="book-action__top d-felx justify-content-end">
#  <a class="btn bookshelves-link" href="https://www.todostuslibros.com/login?_next=https://www.todostuslibros.com/libros/evangelio-2024-letra-pequena-bolsillo_978-84-19640-00-0" title="Añadir a estantería">
#  <i class="far fa-heart"></i>
#  </a>
#  </div>
#  <div class="d-flex book-action__content">
#  <div class="book-action__content--top d-none d-md-flex">
#  <!-- Solo en desktop -->
#  <div class="book-price">
#  <strong>
#                                                          2.65€
#                          </strong>
#                          (2.55€ sin IVA)
#                                              </div>
#  <div class="ratings grid-view">
#  </div>
#  <!-- //Solo en desktop -->
#  </div>
#  <div class="book-location">
#  <form action="https://www.todostuslibros.com/b2c_add_to_cart" id="addToCart" method="POST">
#  <input name="_token" type="hidden" value="v8ddx2xGXLupIiGdP5Eig9Tl59YhtDLwoUW1ILnd"/> <input name="isbn" type="hidden" value="978-84-19640-00-0"/>
#  <button class="btn btn-add-to-cart b2c btn-block mb-2" type="submit">
#  <!--<i class="fas fa-shopping-cart"></i> -->
#                  Añadir a la cesta
#                  </button>
#  </form>
#  <div class="availability-bookshops-pickup" data-allowres="1" data-isbn="978-84-19640-00-0">
#  </div>
#  </div>
#  <div class="bookstores">
#  <div class="availability-bookshops" data-allowres="1" data-isbn="978-84-19640-00-0"></div>
#  <span class="availability availability-medium">
#  <i class="fas fa-check"></i> Disponibilidad media
#      </span>
#  </div>
#  </div>
#  </div>
#  </li>,
#  <li class="book row" data-gtm-disponibilidad="" data-gtm-editorial="ALFAGUARA" data-gtm-index="7" data-gtm-isbn="978-84-204-7636-0" data-gtm-precio="21.90" data-gtm-titulo="El problema final" id="book_978-84-204-7636-0">
#  <div class="col-12 col-sm-12 col-md-9 book-content">
#  <div class="row">
#  <div class="book-image col-4 col-sm-3 col-md-3 col-lg-3">
#  <a href="https://www.todostuslibros.com/libros/el-problema-final_978-84-204-7636-0">
#  <img alt="El problema final" height="150" src="https://static.cegal.es/imagenes/marcadas/9788420/978842047636.gif" title="El problema final" width="100"/>
#  <span> 7 </span>
#  </a>
#  <!-- Solo Vista grid y móvil -->
#  <a class="btn bookshelves-link" data-book-isbn="978-84-204-7636-0" data-book-title="El problema final" href="https://www.todostuslibros.com/login?_next=https://www.todostuslibros.com/libros/el-problema-final_978-84-204-7636-0" title="Añadir a estantería">
#  <i class="far fa-heart"></i>
#  </a>
#  <!-- //Solo  Vista grid y móvil -->
#  </div>
#  <div class="book-details col-8 col-sm-9 col-md-9 col-lg-9 mb-2">
#  <h2 class="title">
#  <a href="https://www.todostuslibros.com/libros/el-problema-final_978-84-204-7636-0">
#                          El problema final
#                          </a>
#  </h2>
#  <h3 class="subtitle"><a href="https://www.todostuslibros.com/libros/el-problema-final_978-84-204-7636-0"></a></h3>
#  <h3 class="author">
#  <a href="https://www.todostuslibros.com/autor/perez-reverte-arturo">Pérez-Reverte, Arturo</a>
#  </h3>
#  <div class="data_isbn d-none d-md-block">978-84-204-7636-0 </div>
#  <div class="ratings list-view mb-3">
#  </div>
#  <p class="synopsis d-none d-md-block d-lg-block d-xl-block">LA NUEVA NOVELA DE ARTURO PÉREZ-REVERTE  Un crimen imposible. Un detective insospechado.  No se trata de un desafío entre el asesino y el detective, sino de un duelo de inteligencia entre el autor y el lector. —Haría falta un policía—sugirió alguien—. Un detective. —Tenemos uno —dijo Foxá.—Todos sig...</p>
#  <!--<p class="synopsis">LA NUEVA NOVELA DE ARTURO PÉREZ-REVERTE  Un crimen imposible. Un detective insospechado.  No se trat...</p>-->
#  <!-- <p class="data">ALFAGUARA </p>-->
#  <!-- Solo en móvil -->
#  <div class="d-block d-block d-md-none">
#  <div class="book-action__content--top d-flex d-md-none">
#  <div class="book-price d-block d-md-none">
#  <strong>
#                                                                  21.90€
#                              </strong>
#                              (21.06€ sin IVA)
#                                                      </div>
#  </div>
#  </div>
#  <!-- Solo en móvil -->
#  </div>
#  </div>
#  </div>
#  <div class="col-12 col-sm-12 col-md-3 book-action">
#  <div class="book-action__top d-felx justify-content-end">
#  <a class="btn bookshelves-link" href="https://www.todostuslibros.com/login?_next=https://www.todostuslibros.com/libros/el-problema-final_978-84-204-7636-0" title="Añadir a estantería">
#  <i class="far fa-heart"></i>
#  </a>
#  </div>
#  <div class="d-flex book-action__content">
#  <div class="book-action__content--top d-none d-md-flex">
#  <!-- Solo en desktop -->
#  <div class="book-price">
#  <strong>
#                                                          21.90€
#                          </strong>
#                          (21.06€ sin IVA)
#                                              </div>
#  <div class="ratings grid-view">
#  </div>
#  <!-- //Solo en desktop -->
#  </div>
#  <div class="book-location">
#  <form action="https://www.todostuslibros.com/b2c_add_to_cart" id="addToCart" method="POST">
#  <input name="_token" type="hidden" value="v8ddx2xGXLupIiGdP5Eig9Tl59YhtDLwoUW1ILnd"/> <input name="isbn" type="hidden" value="978-84-204-7636-0"/>
#  <button class="btn btn-add-to-cart b2c btn-block mb-2" type="submit">
#  <!--<i class="fas fa-shopping-cart"></i> -->
#                  Añadir a la cesta
#                  </button>
#  </form>
#  <div class="availability-bookshops-pickup" data-allowres="1" data-isbn="978-84-204-7636-0">
#  </div>
#  </div>
#  <div class="bookstores">
#  <div class="availability-bookshops" data-allowres="1" data-isbn="978-84-204-7636-0"></div>
#  <span class="availability availability-high">
#  <i class="fas fa-check"></i> Disponibilidad alta
#      </span>
#  </div>
#  </div>
#  </div>
#  </li>,
#  <li class="book row" data-gtm-disponibilidad="" data-gtm-editorial="Diana Editorial" data-gtm-index="8" data-gtm-isbn="978-84-18118-03-6" data-gtm-precio="19.90" data-gtm-titulo="Hábitos atómicos" id="book_978-84-18118-03-6">
#  <div class="col-12 col-sm-12 col-md-9 book-content">
#  <div class="row">
#  <div class="book-image col-4 col-sm-3 col-md-3 col-lg-3">
#  <a href="https://www.todostuslibros.com/libros/habitos-atomicos_978-84-18118-03-6">
#  <img alt="Hábitos atómicos" height="150" src="https://static.cegal.es/imagenes/marcadas/9788418/978841811803.gif" title="Hábitos atómicos" width="100"/>
#  <span> 8 </span>
#  </a>
#  <!-- Solo Vista grid y móvil -->
#  <a class="btn bookshelves-link" data-book-isbn="978-84-18118-03-6" data-book-title="Hábitos atómicos" href="https://www.todostuslibros.com/login?_next=https://www.todostuslibros.com/libros/habitos-atomicos_978-84-18118-03-6" title="Añadir a estantería">
#  <i class="far fa-heart"></i>
#  </a>
#  <!-- //Solo  Vista grid y móvil -->
#  </div>
#  <div class="book-details col-8 col-sm-9 col-md-9 col-lg-9 mb-2">
#  <h2 class="title">
#  <a href="https://www.todostuslibros.com/libros/habitos-atomicos_978-84-18118-03-6">
#                          Hábitos atómicos
#                          </a>
#  </h2>
#  <h3 class="subtitle"><a href="https://www.todostuslibros.com/libros/habitos-atomicos_978-84-18118-03-6">Cambios pequeños, resultados extraordinarios</a></h3>
#  <h3 class="author">
#  <a href="https://www.todostuslibros.com/autor/clear-james">Clear, James</a>
#  </h3>
#  <div class="data_isbn d-none d-md-block">978-84-18118-03-6 </div>
#  <div class="ratings list-view mb-3">
#  </div>
#  <p class="synopsis d-none d-md-block d-lg-block d-xl-block">MÁS DE 200.000 EJEMPLARES VENDIDOS EN ESPAÑA.
#  	MÁS DE 15 MILLONES DE EJEMPLARES VENDIDOS EN TODO EL MUNDO.
#  	«Sumamente práctico y útil.» MARK MANSON, autor de El sutil arte de que (casi todo) te importe una mi*rda
#  	«Paso a paso, cambiará tu rutina.» Financial Times
#
#  	A menudo pensamos que para camb...</p>
#  <!--<p class="synopsis">MÁS DE 200.000 EJEMPLARES VENDIDOS EN ESPAÑA.
#  	MÁS DE 15 MILLONES DE EJEMPLARES VENDIDOS EN TODO EL...</p>-->
#  <!-- <p class="data">Diana Editorial </p>-->
#  <!-- Solo en móvil -->
#  <div class="d-block d-block d-md-none">
#  <div class="book-action__content--top d-flex d-md-none">
#  <div class="book-price d-block d-md-none">
#  <strong>
#                                                                  19.90€
#                              </strong>
#                              (19.13€ sin IVA)
#                                                      </div>
#  </div>
#  </div>
#  <!-- Solo en móvil -->
#  </div>
#  </div>
#  </div>
#  <div class="col-12 col-sm-12 col-md-3 book-action">
#  <div class="book-action__top d-felx justify-content-end">
#  <a class="btn bookshelves-link" href="https://www.todostuslibros.com/login?_next=https://www.todostuslibros.com/libros/habitos-atomicos_978-84-18118-03-6" title="Añadir a estantería">
#  <i class="far fa-heart"></i>
#  </a>
#  </div>
#  <div class="d-flex book-action__content">
#  <div class="book-action__content--top d-none d-md-flex">
#  <!-- Solo en desktop -->
#  <div class="book-price">
#  <strong>
#                                                          19.90€
#                          </strong>
#                          (19.13€ sin IVA)
#                                              </div>
#  <div class="ratings grid-view">
#  </div>
#  <!-- //Solo en desktop -->
#  </div>
#  <div class="book-location">
#  <form action="https://www.todostuslibros.com/b2c_add_to_cart" id="addToCart" method="POST">
#  <input name="_token" type="hidden" value="v8ddx2xGXLupIiGdP5Eig9Tl59YhtDLwoUW1ILnd"/> <input name="isbn" type="hidden" value="978-84-18118-03-6"/>
#  <button class="btn btn-add-to-cart b2c btn-block mb-2" type="submit">
#  <!--<i class="fas fa-shopping-cart"></i> -->
#                  Añadir a la cesta
#                  </button>
#  </form>
#  <div class="availability-bookshops-pickup" data-allowres="1" data-isbn="978-84-18118-03-6">
#  </div>
#  </div>
#  <div class="bookstores">
#  <div class="availability-bookshops" data-allowres="1" data-isbn="978-84-18118-03-6"></div>
#  <span class="availability availability-high">
#  <i class="fas fa-check"></i> Disponibilidad alta
#      </span>
#  </div>
#  </div>
#  </div>
#  </li>,
#  <li class="book row" data-gtm-disponibilidad="" data-gtm-editorial="Seix Barral" data-gtm-index="9" data-gtm-isbn="978-84-322-4232-8" data-gtm-precio="19.90" data-gtm-titulo="No te veré morir" id="book_978-84-322-4232-8">
#  <div class="col-12 col-sm-12 col-md-9 book-content">
#  <div class="row">
#  <div class="book-image col-4 col-sm-3 col-md-3 col-lg-3">
#  <a href="https://www.todostuslibros.com/libros/no-te-vere-morir_978-84-322-4232-8">
#  <img alt="No te veré morir" height="150" src="https://static.cegal.es/imagenes/marcadas/9788432/978843224232.gif" title="No te veré morir" width="100"/>
#  <span> 9 </span>
#  </a>
#  <!-- Solo Vista grid y móvil -->
#  <a class="btn bookshelves-link" data-book-isbn="978-84-322-4232-8" data-book-title="No te veré morir" href="https://www.todostuslibros.com/login?_next=https://www.todostuslibros.com/libros/no-te-vere-morir_978-84-322-4232-8" title="Añadir a estantería">
#  <i class="far fa-heart"></i>
#  </a>
#  <!-- //Solo  Vista grid y móvil -->
#  </div>
#  <div class="book-details col-8 col-sm-9 col-md-9 col-lg-9 mb-2">
#  <h2 class="title">
#  <a href="https://www.todostuslibros.com/libros/no-te-vere-morir_978-84-322-4232-8">
#                          No te veré morir
#                          </a>
#  </h2>
#  <h3 class="subtitle"><a href="https://www.todostuslibros.com/libros/no-te-vere-morir_978-84-322-4232-8"></a></h3>
#  <h3 class="author">
#  <a href="https://www.todostuslibros.com/autor/munoz-molina-antonio">Muñoz Molina, Antonio</a>
#  </h3>
#  <div class="data_isbn d-none d-md-block">978-84-322-4232-8 </div>
#  <div class="ratings list-view mb-3">
#  </div>
#  <p class="synopsis d-none d-md-block d-lg-block d-xl-block">Durante su juventud, Gabriel Aristu y Adriana Zuber protagonizaron una apasionada historia de amor que parecía destinada a durar para siempre. El futuro, sin embargo, tenía otros planes para ellos. Separados durante cincuenta años por un océano de incomunicación, ella atrapada en la España de la dic...</p>
#  <!--<p class="synopsis">Durante su juventud, Gabriel Aristu y Adriana Zuber protagonizaron una apasionada historia de amor q...</p>-->
#  <!-- <p class="data">Seix Barral </p>-->
#  <!-- Solo en móvil -->
#  <div class="d-block d-block d-md-none">
#  <div class="book-action__content--top d-flex d-md-none">
#  <div class="book-price d-block d-md-none">
#  <strong>
#                                                                  19.90€
#                              </strong>
#                              (19.13€ sin IVA)
#                                                      </div>
#  </div>
#  </div>
#  <!-- Solo en móvil -->
#  </div>
#  </div>
#  </div>
#  <div class="col-12 col-sm-12 col-md-3 book-action">
#  <div class="book-action__top d-felx justify-content-end">
#  <a class="btn bookshelves-link" href="https://www.todostuslibros.com/login?_next=https://www.todostuslibros.com/libros/no-te-vere-morir_978-84-322-4232-8" title="Añadir a estantería">
#  <i class="far fa-heart"></i>
#  </a>
#  </div>
#  <div class="d-flex book-action__content">
#  <div class="book-action__content--top d-none d-md-flex">
#  <!-- Solo en desktop -->
#  <div class="book-price">
#  <strong>
#                                                          19.90€
#                          </strong>
#                          (19.13€ sin IVA)
#                                              </div>
#  <div class="ratings grid-view">
#  </div>
#  <!-- //Solo en desktop -->
#  </div>
#  <div class="book-location">
#  <form action="https://www.todostuslibros.com/b2c_add_to_cart" id="addToCart" method="POST">
#  <input name="_token" type="hidden" value="v8ddx2xGXLupIiGdP5Eig9Tl59YhtDLwoUW1ILnd"/> <input name="isbn" type="hidden" value="978-84-322-4232-8"/>
#  <button class="btn btn-add-to-cart b2c btn-block mb-2" type="submit">
#  <!--<i class="fas fa-shopping-cart"></i> -->
#                  Añadir a la cesta
#                  </button>
#  </form>
#  <div class="availability-bookshops-pickup" data-allowres="1" data-isbn="978-84-322-4232-8">
#  </div>
#  </div>
#  <div class="bookstores">
#  <div class="availability-bookshops" data-allowres="1" data-isbn="978-84-322-4232-8"></div>
#  <span class="availability availability-high">
#  <i class="fas fa-check"></i> Disponibilidad alta
#      </span>
#  </div>
#  </div>
#  </div>
#  </li>,
#  <li class="book row" data-gtm-disponibilidad="" data-gtm-editorial="ALFAGUARA" data-gtm-index="10" data-gtm-isbn="978-84-204-6143-4" data-gtm-precio="18.90" data-gtm-titulo="Mirafiori" id="book_978-84-204-6143-4">
#  <div class="col-12 col-sm-12 col-md-9 book-content">
#  <div class="row">
#  <div class="book-image col-4 col-sm-3 col-md-3 col-lg-3">
#  <a href="https://www.todostuslibros.com/libros/mirafiori_978-84-204-6143-4">
#  <img alt="Mirafiori" height="150" src="https://static.cegal.es/imagenes/marcadas/9788420/978842046143.gif" title="Mirafiori" width="100"/>
#  <span> 10 </span>
#  </a>
#  <!-- Solo Vista grid y móvil -->
#  <a class="btn bookshelves-link" data-book-isbn="978-84-204-6143-4" data-book-title="Mirafiori" href="https://www.todostuslibros.com/login?_next=https://www.todostuslibros.com/libros/mirafiori_978-84-204-6143-4" title="Añadir a estantería">
#  <i class="far fa-heart"></i>
#  </a>
#  <!-- //Solo  Vista grid y móvil -->
#  </div>
#  <div class="book-details col-8 col-sm-9 col-md-9 col-lg-9 mb-2">
#  <h2 class="title">
#  <a href="https://www.todostuslibros.com/libros/mirafiori_978-84-204-6143-4">
#                          Mirafiori
#                          </a>
#  </h2>
#  <h3 class="subtitle"><a href="https://www.todostuslibros.com/libros/mirafiori_978-84-204-6143-4"></a></h3>
#  <h3 class="author">
#  <a href="https://www.todostuslibros.com/autor/jabois-manuel">Jabois, Manuel</a>
#  </h3>
#  <div class="data_isbn d-none d-md-block">978-84-204-6143-4 </div>
#  <div class="ratings list-view mb-3">
#  </div>
#  <p class="synopsis d-none d-md-block d-lg-block d-xl-block">VUELVE EL MEJOR JABOIS CON UNA HISTORIA DE AMOR  Una novela sobre la belleza de todo aquello que no tiene explicación  «Jabois escribe en estado de gracia».Laura Barrachina, El Ojo Crítico «Si uno está enamorado de verdad, hasta en las almas más libres y salvajes y modernas, más seguras de sí mismas...</p>
#  <!--<p class="synopsis">VUELVE EL MEJOR JABOIS CON UNA HISTORIA DE AMOR  Una novela sobre la belleza de todo aquello que no...</p>-->
#  <!-- <p class="data">ALFAGUARA </p>-->
#  <!-- Solo en móvil -->
#  <div class="d-block d-block d-md-none">
#  <div class="book-action__content--top d-flex d-md-none">
#  <div class="book-price d-block d-md-none">
#  <strong>
#                                                                  18.90€
#                              </strong>
#                              (18.17€ sin IVA)
#                                                      </div>
#  </div>
#  </div>
#  <!-- Solo en móvil -->
#  </div>
#  </div>
#  </div>
#  <div class="col-12 col-sm-12 col-md-3 book-action">
#  <div class="book-action__top d-felx justify-content-end">
#  <a class="btn bookshelves-link" href="https://www.todostuslibros.com/login?_next=https://www.todostuslibros.com/libros/mirafiori_978-84-204-6143-4" title="Añadir a estantería">
#  <i class="far fa-heart"></i>
#  </a>
#  </div>
#  <div class="d-flex book-action__content">
#  <div class="book-action__content--top d-none d-md-flex">
#  <!-- Solo en desktop -->
#  <div class="book-price">
#  <strong>
#                                                          18.90€
#                          </strong>
#                          (18.17€ sin IVA)
#                                              </div>
#  <div class="ratings grid-view">
#  </div>
#  <!-- //Solo en desktop -->
#  </div>
#  <div class="book-location">
#  <form action="https://www.todostuslibros.com/b2c_add_to_cart" id="addToCart" method="POST">
#  <input name="_token" type="hidden" value="v8ddx2xGXLupIiGdP5Eig9Tl59YhtDLwoUW1ILnd"/> <input name="isbn" type="hidden" value="978-84-204-6143-4"/>
#  <button class="btn btn-add-to-cart b2c btn-block mb-2" type="submit">
#  <!--<i class="fas fa-shopping-cart"></i> -->
#                  Añadir a la cesta
#                  </button>
#  </form>
#  <div class="availability-bookshops-pickup" data-allowres="1" data-isbn="978-84-204-6143-4">
#  </div>
#  </div>
#  <div class="bookstores">
#  <div class="availability-bookshops" data-allowres="1" data-isbn="978-84-204-6143-4"></div>
#  <span class="availability availability-high">
#  <i class="fas fa-check"></i> Disponibilidad alta
#      </span>
#  </div>
#  </div>
#  </div>
#  </li>,
#  <li class="book row" data-gtm-disponibilidad="" data-gtm-editorial="Editorial Funambulista" data-gtm-index="11" data-gtm-isbn="978-84-126587-9-8" data-gtm-precio="24.90" data-gtm-titulo="Dios - La ciencia - Las pruebas" id="book_978-84-126587-9-8">
#  <div class="col-12 col-sm-12 col-md-9 book-content">
#  <div class="row">
#  <div class="book-image col-4 col-sm-3 col-md-3 col-lg-3">
#  <a href="https://www.todostuslibros.com/libros/dios-la-ciencia-las-pruebas_978-84-126587-9-8">
#  <img alt="Dios - La ciencia - Las pruebas" height="150" src="https://static.cegal.es/imagenes/marcadas/9788412/978841265879.gif" title="Dios - La ciencia - Las pruebas" width="100"/>
#  <span> 11 </span>
#  </a>
#  <!-- Solo Vista grid y móvil -->
#  <a class="btn bookshelves-link" data-book-isbn="978-84-126587-9-8" data-book-title="Dios - La ciencia - Las pruebas" href="https://www.todostuslibros.com/login?_next=https://www.todostuslibros.com/libros/dios-la-ciencia-las-pruebas_978-84-126587-9-8" title="Añadir a estantería">
#  <i class="far fa-heart"></i>
#  </a>
#  <!-- //Solo  Vista grid y móvil -->
#  </div>
#  <div class="book-details col-8 col-sm-9 col-md-9 col-lg-9 mb-2">
#  <h2 class="title">
#  <a href="https://www.todostuslibros.com/libros/dios-la-ciencia-las-pruebas_978-84-126587-9-8">
#                          Dios - La ciencia - Las pruebas
#                          </a>
#  </h2>
#  <h3 class="subtitle"><a href="https://www.todostuslibros.com/libros/dios-la-ciencia-las-pruebas_978-84-126587-9-8">El albor de una revolución</a></h3>
#  <h3 class="author">
#  <a href="https://www.todostuslibros.com/autor/bollore-michel-yves-bonnassies-olivier">Bolloré, Michel-Yves / Bonnassies, Olivier</a>
#  </h3>
#  <div class="data_isbn d-none d-md-block">978-84-126587-9-8 </div>
#  <div class="ratings list-view mb-3">
#  </div>
#  <p class="synopsis d-none d-md-block d-lg-block d-xl-block">En este libro se revelan, al cabo de tres años de trabajo en colaboración con unos veinte científicos y especialistas de alto nivel, las pruebas modernas de la existencia de Dios. Durante cerca de cuatro siglos, de Copérnico a Freud, pasando por Galileo y Darwin, los descubrimientos científicos se a...</p>
#  <!--<p class="synopsis">En este libro se revelan, al cabo de tres años de trabajo en colaboración con unos veinte científico...</p>-->
#  <!-- <p class="data">Editorial Funambulista </p>-->
#  <!-- Solo en móvil -->
#  <div class="d-block d-block d-md-none">
#  <div class="book-action__content--top d-flex d-md-none">
#  <div class="book-price d-block d-md-none">
#  <strong>
#                                                                  24.90€
#                              </strong>
#                              (23.94€ sin IVA)
#                                                      </div>
#  </div>
#  </div>
#  <!-- Solo en móvil -->
#  </div>
#  </div>
#  </div>
#  <div class="col-12 col-sm-12 col-md-3 book-action">
#  <div class="book-action__top d-felx justify-content-end">
#  <a class="btn bookshelves-link" href="https://www.todostuslibros.com/login?_next=https://www.todostuslibros.com/libros/dios-la-ciencia-las-pruebas_978-84-126587-9-8" title="Añadir a estantería">
#  <i class="far fa-heart"></i>
#  </a>
#  </div>
#  <div class="d-flex book-action__content">
#  <div class="book-action__content--top d-none d-md-flex">
#  <!-- Solo en desktop -->
#  <div class="book-price">
#  <strong>
#                                                          24.90€
#                          </strong>
#                          (23.94€ sin IVA)
#                                              </div>
#  <div class="ratings grid-view">
#  </div>
#  <!-- //Solo en desktop -->
#  </div>
#  <div class="book-location">
#  <form action="https://www.todostuslibros.com/b2c_add_to_cart" id="addToCart" method="POST">
#  <input name="_token" type="hidden" value="v8ddx2xGXLupIiGdP5Eig9Tl59YhtDLwoUW1ILnd"/> <input name="isbn" type="hidden" value="978-84-126587-9-8"/>
#  <button class="btn btn-add-to-cart b2c btn-block mb-2" type="submit">
#  <!--<i class="fas fa-shopping-cart"></i> -->
#                  Añadir a la cesta
#                  </button>
#  </form>
#  <div class="availability-bookshops-pickup" data-allowres="1" data-isbn="978-84-126587-9-8">
#  </div>
#  </div>
#  <div class="bookstores">
#  <div class="availability-bookshops" data-allowres="1" data-isbn="978-84-126587-9-8"></div>
#  <span class="availability availability-high">
#  <i class="fas fa-check"></i> Disponibilidad alta
#      </span>
#  </div>
#  </div>
#  </div>
#  </li>,
#  <li class="book row" data-gtm-disponibilidad="" data-gtm-editorial="EDIBESA" data-gtm-index="12" data-gtm-isbn="978-84-19640-01-7" data-gtm-precio="4.60" data-gtm-titulo="EVANGELIO 2024 LETRA GRANDE" id="book_978-84-19640-01-7">
#  <div class="col-12 col-sm-12 col-md-9 book-content">
#  <div class="row">
#  <div class="book-image col-4 col-sm-3 col-md-3 col-lg-3">
#  <a href="https://www.todostuslibros.com/libros/evangelio-2024-letra-grande_978-84-19640-01-7">
#  <img alt="EVANGELIO 2024 LETRA GRANDE" height="150" src="https://static.cegal.es/imagenes/marcadas/9788419/978841964001.gif" title="EVANGELIO 2024 LETRA GRANDE" width="100"/>
#  <span> 12 </span>
#  </a>
#  <!-- Solo Vista grid y móvil -->
#  <a class="btn bookshelves-link" data-book-isbn="978-84-19640-01-7" data-book-title="EVANGELIO 2024 LETRA GRANDE" href="https://www.todostuslibros.com/login?_next=https://www.todostuslibros.com/libros/evangelio-2024-letra-grande_978-84-19640-01-7" title="Añadir a estantería">
#  <i class="far fa-heart"></i>
#  </a>
#  <!-- //Solo  Vista grid y móvil -->
#  </div>
#  <div class="book-details col-8 col-sm-9 col-md-9 col-lg-9 mb-2">
#  <h2 class="title">
#  <a href="https://www.todostuslibros.com/libros/evangelio-2024-letra-grande_978-84-19640-01-7">
#                          EVANGELIO 2024 LETRA GRANDE
#                          </a>
#  </h2>
#  <h3 class="subtitle"><a href="https://www.todostuslibros.com/libros/evangelio-2024-letra-grande_978-84-19640-01-7"></a></h3>
#  <h3 class="author">
#  <a href="https://www.todostuslibros.com/autor/martinez-puche-alvarez-luis-del-cerro">MARTINEZ PUCHE/ ALVAREZ,LUIS/ DEL CERRO</a>
#  </h3>
#  <div class="data_isbn d-none d-md-block">978-84-19640-01-7 </div>
#  <div class="ratings list-view mb-3">
#  </div>
#  <p class="synopsis d-none d-md-block d-lg-block d-xl-block">Evangelio con el Papa Francisco. Ciclo B.  Una página por día.  Cada día una reflexión del papa  Francisco sobre el Evangelio.  Incluye: imágenes de santos, calendario litúrgico, santoral, oraciones y vida cristiana.</p>
#  <!--<p class="synopsis">Evangelio con el Papa Francisco. Ciclo B.  Una página por día.  Cada día una reflexión del papa  Fra...</p>-->
#  <!-- <p class="data">EDIBESA </p>-->
#  <!-- Solo en móvil -->
#  <div class="d-block d-block d-md-none">
#  <div class="book-action__content--top d-flex d-md-none">
#  <div class="book-price d-block d-md-none">
#  <strong>
#                                                                  4.60€
#                              </strong>
#                              (4.42€ sin IVA)
#                                                      </div>
#  </div>
#  </div>
#  <!-- Solo en móvil -->
#  </div>
#  </div>
#  </div>
#  <div class="col-12 col-sm-12 col-md-3 book-action">
#  <div class="book-action__top d-felx justify-content-end">
#  <a class="btn bookshelves-link" href="https://www.todostuslibros.com/login?_next=https://www.todostuslibros.com/libros/evangelio-2024-letra-grande_978-84-19640-01-7" title="Añadir a estantería">
#  <i class="far fa-heart"></i>
#  </a>
#  </div>
#  <div class="d-flex book-action__content">
#  <div class="book-action__content--top d-none d-md-flex">
#  <!-- Solo en desktop -->
#  <div class="book-price">
#  <strong>
#                                                          4.60€
#                          </strong>
#                          (4.42€ sin IVA)
#                                              </div>
#  <div class="ratings grid-view">
#  </div>
#  <!-- //Solo en desktop -->
#  </div>
#  <div class="book-location">
#  <form action="https://www.todostuslibros.com/b2c_add_to_cart" id="addToCart" method="POST">
#  <input name="_token" type="hidden" value="v8ddx2xGXLupIiGdP5Eig9Tl59YhtDLwoUW1ILnd"/> <input name="isbn" type="hidden" value="978-84-19640-01-7"/>
#  <button class="btn btn-add-to-cart b2c btn-block mb-2" type="submit">
#  <!--<i class="fas fa-shopping-cart"></i> -->
#                  Añadir a la cesta
#                  </button>
#  </form>
#  <div class="availability-bookshops-pickup" data-allowres="1" data-isbn="978-84-19640-01-7">
#  </div>
#  </div>
#  <div class="bookstores">
#  <div class="availability-bookshops" data-allowres="1" data-isbn="978-84-19640-01-7"></div>
#  <span class="availability availability-medium">
#  <i class="fas fa-check"></i> Disponibilidad media
#      </span>
#  </div>
#  </div>
#  </div>
#  </li>]

# %%
titles = [titles_info[i].get("data-gtm-titulo") for i in range(len(titles_info))]

# %% [markdown]
# ## Get authors

# %%
authors_info = body.find_all("li", {"class":"book row"})
authors_info
# Out:
# [<li class="book row" data-gtm-disponibilidad="" data-gtm-editorial="B" data-gtm-index="1" data-gtm-isbn="978-84-666-7568-0" data-gtm-precio="22.90" data-gtm-titulo="Todo vuelve (Todo arde 2)" id="book_978-84-666-7568-0">
#  <div class="col-12 col-sm-12 col-md-9 book-content">
#  <div class="row">
#  <div class="book-image col-4 col-sm-3 col-md-3 col-lg-3">
#  <a href="https://www.todostuslibros.com/libros/todo-vuelve-todo-arde-2_978-84-666-7568-0">
#  <img alt="Todo vuelve (Todo arde 2)" height="150" src="https://static.cegal.es/imagenes/marcadas/9788466/978846667568.gif" title="Todo vuelve (Todo arde 2)" width="100"/>
#  <span> 1 </span>
#  </a>
#  <!-- Solo Vista grid y móvil -->
#  <a class="btn bookshelves-link" data-book-isbn="978-84-666-7568-0" data-book-title="Todo vuelve (Todo arde 2)" href="https://www.todostuslibros.com/login?_next=https://www.todostuslibros.com/libros/todo-vuelve-todo-arde-2_978-84-666-7568-0" title="Añadir a estantería">
#  <i class="far fa-heart"></i>
#  </a>
#  <!-- //Solo  Vista grid y móvil -->
#  </div>
#  <div class="book-details col-8 col-sm-9 col-md-9 col-lg-9 mb-2">
#  <h2 class="title">
#  <a href="https://www.todostuslibros.com/libros/todo-vuelve-todo-arde-2_978-84-666-7568-0">
#                          Todo vuelve (Todo arde 2)
#                          </a>
#  </h2>
#  <h3 class="subtitle"><a href="https://www.todostuslibros.com/libros/todo-vuelve-todo-arde-2_978-84-666-7568-0"></a></h3>
#  <h3 class="author">
#  <a href="https://www.todostuslibros.com/autor/gomez-jurado-juan">Gómez-Jurado, Juan</a>
#  </h3>
#  <div class="data_isbn d-none d-md-block">978-84-666-7568-0 </div>
#  <div class="ratings list-view mb-3">
#  </div>
#  <p class="synopsis d-none d-md-block d-lg-block d-xl-block">VUELVE EL AUTOR MÁS VENDIDO EN LENGUA ESPAÑOLA  Tras el enorme éxito de REINA ROJA y TODO ARDE, continúa la saga que ha conquistado al mundo.  «Me rindo a los pies del mejor escritor actual de thriller».ZENDA UN PLAN IMPOSIBLETodo lo que Aura Reyes necesita es continuar con vida diez minutos más. No...</p>
#  <!--<p class="synopsis">VUELVE EL AUTOR MÁS VENDIDO EN LENGUA ESPAÑOLA  Tras el enorme éxito de REINA ROJA y TODO ARDE, cont...</p>-->
#  <!-- <p class="data">B </p>-->
#  <!-- Solo en móvil -->
#  <div class="d-block d-block d-md-none">
#  <div class="book-action__content--top d-flex d-md-none">
#  <div class="book-price d-block d-md-none">
#  <strong>
#                                                                  22.90€
#                              </strong>
#                              (22.02€ sin IVA)
#                                                      </div>
#  </div>
#  </div>
#  <!-- Solo en móvil -->
#  </div>
#  </div>
#  </div>
#  <div class="col-12 col-sm-12 col-md-3 book-action">
#  <div class="book-action__top d-felx justify-content-end">
#  <a class="btn bookshelves-link" href="https://www.todostuslibros.com/login?_next=https://www.todostuslibros.com/libros/todo-vuelve-todo-arde-2_978-84-666-7568-0" title="Añadir a estantería">
#  <i class="far fa-heart"></i>
#  </a>
#  </div>
#  <div class="d-flex book-action__content">
#  <div class="book-action__content--top d-none d-md-flex">
#  <!-- Solo en desktop -->
#  <div class="book-price">
#  <strong>
#                                                          22.90€
#                          </strong>
#                          (22.02€ sin IVA)
#                                              </div>
#  <div class="ratings grid-view">
#  </div>
#  <!-- //Solo en desktop -->
#  </div>
#  <div class="book-location">
#  <form action="https://www.todostuslibros.com/b2c_add_to_cart" id="addToCart" method="POST">
#  <input name="_token" type="hidden" value="v8ddx2xGXLupIiGdP5Eig9Tl59YhtDLwoUW1ILnd"/> <input name="isbn" type="hidden" value="978-84-666-7568-0"/>
#  <button class="btn btn-add-to-cart b2c btn-block mb-2" type="submit">
#  <!--<i class="fas fa-shopping-cart"></i> -->
#                  Añadir a la cesta
#                  </button>
#  </form>
#  <div class="availability-bookshops-pickup" data-allowres="1" data-isbn="978-84-666-7568-0">
#  </div>
#  </div>
#  <div class="bookstores">
#  <div class="availability-bookshops" data-allowres="1" data-isbn="978-84-666-7568-0"></div>
#  <span class="availability availability-high">
#  <i class="fas fa-check"></i> Disponibilidad alta
#      </span>
#  </div>
#  </div>
#  </div>
#  </li>,
#  <li class="book row" data-gtm-disponibilidad="" data-gtm-editorial="Editorial Planeta" data-gtm-index="2" data-gtm-isbn="978-84-08-27758-3" data-gtm-precio="22.90" data-gtm-titulo="El Infierno" id="book_978-84-08-27758-3">
#  <div class="col-12 col-sm-12 col-md-9 book-content">
#  <div class="row">
#  <div class="book-image col-4 col-sm-3 col-md-3 col-lg-3">
#  <a href="https://www.todostuslibros.com/libros/el-infierno_978-84-08-27758-3">
#  <img alt="El Infierno" height="150" src="https://static.cegal.es/imagenes/marcadas/9788408/978840827758.gif" title="El Infierno" width="100"/>
#  <span> 2 </span>
#  </a>
#  <!-- Solo Vista grid y móvil -->
#  <a class="btn bookshelves-link" data-book-isbn="978-84-08-27758-3" data-book-title="El Infierno" href="https://www.todostuslibros.com/login?_next=https://www.todostuslibros.com/libros/el-infierno_978-84-08-27758-3" title="Añadir a estantería">
#  <i class="far fa-heart"></i>
#  </a>
#  <!-- //Solo  Vista grid y móvil -->
#  </div>
#  <div class="book-details col-8 col-sm-9 col-md-9 col-lg-9 mb-2">
#  <h2 class="title">
#  <a href="https://www.todostuslibros.com/libros/el-infierno_978-84-08-27758-3">
#                          El Infierno
#                          </a>
#  </h2>
#  <h3 class="subtitle"><a href="https://www.todostuslibros.com/libros/el-infierno_978-84-08-27758-3"></a></h3>
#  <h3 class="author">
#  <a href="https://www.todostuslibros.com/autor/mola-carmen">Mola, Carmen</a>
#  </h3>
#  <div class="data_isbn d-none d-md-block">978-84-08-27758-3 </div>
#  <div class="ratings list-view mb-3">
#  </div>
#  <p class="synopsis d-none d-md-block d-lg-block d-xl-block">Salvaje, perturbador, cruel.
#  	EL NUEVO Y BRUTAL THRILLER DE CARMEN MOLA QUE MÁS DE 2 MILLONES DE LECTORES ESTÁN ESPERANDO.
#  	Lo que parecía un paraíso se terminó convirtiendo en un infierno. Una novela negra impactante y perturbadora al más puro estilo Carmen Mola.
#  	Un terrible levantamiento del ejér...</p>
#  <!--<p class="synopsis">Salvaje, perturbador, cruel.
#  	EL NUEVO Y BRUTAL THRILLER DE CARMEN MOLA QUE MÁS DE 2 MILLONES DE LEC...</p>-->
#  <!-- <p class="data">Editorial Planeta </p>-->
#  <!-- Solo en móvil -->
#  <div class="d-block d-block d-md-none">
#  <div class="book-action__content--top d-flex d-md-none">
#  <div class="book-price d-block d-md-none">
#  <strong>
#                                                                  22.90€
#                              </strong>
#                              (22.02€ sin IVA)
#                                                      </div>
#  </div>
#  </div>
#  <!-- Solo en móvil -->
#  </div>
#  </div>
#  </div>
#  <div class="col-12 col-sm-12 col-md-3 book-action">
#  <div class="book-action__top d-felx justify-content-end">
#  <a class="btn bookshelves-link" href="https://www.todostuslibros.com/login?_next=https://www.todostuslibros.com/libros/el-infierno_978-84-08-27758-3" title="Añadir a estantería">
#  <i class="far fa-heart"></i>
#  </a>
#  </div>
#  <div class="d-flex book-action__content">
#  <div class="book-action__content--top d-none d-md-flex">
#  <!-- Solo en desktop -->
#  <div class="book-price">
#  <strong>
#                                                          22.90€
#                          </strong>
#                          (22.02€ sin IVA)
#                                              </div>
#  <div class="ratings grid-view">
#  </div>
#  <!-- //Solo en desktop -->
#  </div>
#  <div class="book-location">
#  <form action="https://www.todostuslibros.com/b2c_add_to_cart" id="addToCart" method="POST">
#  <input name="_token" type="hidden" value="v8ddx2xGXLupIiGdP5Eig9Tl59YhtDLwoUW1ILnd"/> <input name="isbn" type="hidden" value="978-84-08-27758-3"/>
#  <button class="btn btn-add-to-cart b2c btn-block mb-2" type="submit">
#  <!--<i class="fas fa-shopping-cart"></i> -->
#                  Añadir a la cesta
#                  </button>
#  </form>
#  <div class="availability-bookshops-pickup" data-allowres="1" data-isbn="978-84-08-27758-3">
#  </div>
#  </div>
#  <div class="bookstores">
#  <div class="availability-bookshops" data-allowres="1" data-isbn="978-84-08-27758-3"></div>
#  <span class="availability availability-high">
#  <i class="fas fa-check"></i> Disponibilidad alta
#      </span>
#  </div>
#  </div>
#  </div>
#  </li>,
#  <li class="book row" data-gtm-disponibilidad="" data-gtm-editorial="PLAZA &amp; JANES" data-gtm-index="3" data-gtm-isbn="978-84-01-03013-0" data-gtm-precio="24.90" data-gtm-titulo="La armadura de la luz (Saga Los pilares de la Tierra 4)" id="book_978-84-01-03013-0">
#  <div class="col-12 col-sm-12 col-md-9 book-content">
#  <div class="row">
#  <div class="book-image col-4 col-sm-3 col-md-3 col-lg-3">
#  <a href="https://www.todostuslibros.com/libros/la-armadura-de-la-luz-saga-los-pilares-de-la-tierra-4_978-84-01-03013-0">
#  <img alt="La armadura de la luz (Saga Los pilares de la Tierra 4)" height="150" src="https://static.cegal.es/imagenes/marcadas/9788401/978840103013.gif" title="La armadura de la luz (Saga Los pilares de la Tierra 4)" width="100"/>
#  <span> 3 </span>
#  </a>
#  <!-- Solo Vista grid y móvil -->
#  <a class="btn bookshelves-link" data-book-isbn="978-84-01-03013-0" data-book-title="La armadura de la luz (Saga Los pilares de la Tierra 4)" href="https://www.todostuslibros.com/login?_next=https://www.todostuslibros.com/libros/la-armadura-de-la-luz-saga-los-pilares-de-la-tierra-4_978-84-01-03013-0" title="Añadir a estantería">
#  <i class="far fa-heart"></i>
#  </a>
#  <!-- //Solo  Vista grid y móvil -->
#  </div>
#  <div class="book-details col-8 col-sm-9 col-md-9 col-lg-9 mb-2">
#  <h2 class="title">
#  <a href="https://www.todostuslibros.com/libros/la-armadura-de-la-luz-saga-los-pilares-de-la-tierra-4_978-84-01-03013-0">
#                          La armadura de la luz (Saga Los pilares de la Tierra 4)
#                          </a>
#  </h2>
#  <h3 class="subtitle"><a href="https://www.todostuslibros.com/libros/la-armadura-de-la-luz-saga-los-pilares-de-la-tierra-4_978-84-01-03013-0"></a></h3>
#  <h3 class="author">
#  <a href="https://www.todostuslibros.com/autor/follett-ken">Follett, Ken</a>
#  </h3>
#  <div class="data_isbn d-none d-md-block">978-84-01-03013-0 </div>
#  <div class="ratings list-view mb-3">
#  </div>
#  <p class="synopsis d-none d-md-block d-lg-block d-xl-block">Vuelve el mejor Follett con la emocionante quinta entrega de la saga «Los pilares de la Tierra». El choque de progreso y tradición y una guerra que amenaza con engullir toda Europa en la más ambiciosa y épica novela del maestro de la ficción histórica. La revolución está en el aire1792. Un gobierno...</p>
#  <!--<p class="synopsis">Vuelve el mejor Follett con la emocionante quinta entrega de la saga «Los pilares de la Tierra». El...</p>-->
#  <!-- <p class="data">PLAZA &amp; JANES </p>-->
#  <!-- Solo en móvil -->
#  <div class="d-block d-block d-md-none">
#  <div class="book-action__content--top d-flex d-md-none">
#  <div class="book-price d-block d-md-none">
#  <strong>
#                                                                  24.90€
#                              </strong>
#                              (23.94€ sin IVA)
#                                                      </div>
#  </div>
#  </div>
#  <!-- Solo en móvil -->
#  </div>
#  </div>
#  </div>
#  <div class="col-12 col-sm-12 col-md-3 book-action">
#  <div class="book-action__top d-felx justify-content-end">
#  <a class="btn bookshelves-link" href="https://www.todostuslibros.com/login?_next=https://www.todostuslibros.com/libros/la-armadura-de-la-luz-saga-los-pilares-de-la-tierra-4_978-84-01-03013-0" title="Añadir a estantería">
#  <i class="far fa-heart"></i>
#  </a>
#  </div>
#  <div class="d-flex book-action__content">
#  <div class="book-action__content--top d-none d-md-flex">
#  <!-- Solo en desktop -->
#  <div class="book-price">
#  <strong>
#                                                          24.90€
#                          </strong>
#                          (23.94€ sin IVA)
#                                              </div>
#  <div class="ratings grid-view">
#  </div>
#  <!-- //Solo en desktop -->
#  </div>
#  <div class="book-location">
#  <form action="https://www.todostuslibros.com/b2c_add_to_cart" id="addToCart" method="POST">
#  <input name="_token" type="hidden" value="v8ddx2xGXLupIiGdP5Eig9Tl59YhtDLwoUW1ILnd"/> <input name="isbn" type="hidden" value="978-84-01-03013-0"/>
#  <button class="btn btn-add-to-cart b2c btn-block mb-2" type="submit">
#  <!--<i class="fas fa-shopping-cart"></i> -->
#                  Añadir a la cesta
#                  </button>
#  </form>
#  <div class="availability-bookshops-pickup" data-allowres="1" data-isbn="978-84-01-03013-0">
#  </div>
#  </div>
#  <div class="bookstores">
#  <div class="availability-bookshops" data-allowres="1" data-isbn="978-84-01-03013-0"></div>
#  <span class="availability availability-high">
#  <i class="fas fa-check"></i> Disponibilidad alta
#      </span>
#  </div>
#  </div>
#  </div>
#  </li>,
#  <li class="book row" data-gtm-disponibilidad="" data-gtm-editorial="Libros Cúpula" data-gtm-index="4" data-gtm-isbn="978-84-480-3897-7" data-gtm-precio="19.90" data-gtm-titulo="La chica del verano" id="book_978-84-480-3897-7">
#  <div class="col-12 col-sm-12 col-md-9 book-content">
#  <div class="row">
#  <div class="book-image col-4 col-sm-3 col-md-3 col-lg-3">
#  <a href="https://www.todostuslibros.com/libros/la-chica-del-verano_978-84-480-3897-7">
#  <img alt="La chica del verano" height="150" src="https://static.cegal.es/imagenes/marcadas/9788448/978844803897.gif" title="La chica del verano" width="100"/>
#  <span> 4 </span>
#  </a>
#  <!-- Solo Vista grid y móvil -->
#  <a class="btn bookshelves-link" data-book-isbn="978-84-480-3897-7" data-book-title="La chica del verano" href="https://www.todostuslibros.com/login?_next=https://www.todostuslibros.com/libros/la-chica-del-verano_978-84-480-3897-7" title="Añadir a estantería">
#  <i class="far fa-heart"></i>
#  </a>
#  <!-- //Solo  Vista grid y móvil -->
#  </div>
#  <div class="book-details col-8 col-sm-9 col-md-9 col-lg-9 mb-2">
#  <h2 class="title">
#  <a href="https://www.todostuslibros.com/libros/la-chica-del-verano_978-84-480-3897-7">
#                          La chica del verano
#                          </a>
#  </h2>
#  <h3 class="subtitle"><a href="https://www.todostuslibros.com/libros/la-chica-del-verano_978-84-480-3897-7">Los finales felices son para los valientes</a></h3>
#  <h3 class="author">
#  <a href="https://www.todostuslibros.com/autor/la-vecina-rubia">La Vecina Rubia</a>
#  </h3>
#  <div class="data_isbn d-none d-md-block">978-84-480-3897-7 </div>
#  <div class="ratings list-view mb-3">
#  </div>
#  <p class="synopsis d-none d-md-block d-lg-block d-xl-block">La primera edición especial incluye una dedicatoria manuscrita impresa escrita por la autora.Así quería ser yo: anónima. Oculta, pero presente.
#
#  	La vida está llena de etapas, algunas preciosas e inolvidables, otras más difíciles y complicadas, lo importante es saber cuándo hay que cerrar cada una...</p>
#  <!--<p class="synopsis">La primera edición especial incluye una dedicatoria manuscrita impresa escrita por la autora.Así que...</p>-->
#  <!-- <p class="data">Libros Cúpula </p>-->
#  <!-- Solo en móvil -->
#  <div class="d-block d-block d-md-none">
#  <div class="book-action__content--top d-flex d-md-none">
#  <div class="book-price d-block d-md-none">
#  <strong>
#                                                                  19.90€
#                              </strong>
#                              (19.13€ sin IVA)
#                                                      </div>
#  </div>
#  </div>
#  <!-- Solo en móvil -->
#  </div>
#  </div>
#  </div>
#  <div class="col-12 col-sm-12 col-md-3 book-action">
#  <div class="book-action__top d-felx justify-content-end">
#  <a class="btn bookshelves-link" href="https://www.todostuslibros.com/login?_next=https://www.todostuslibros.com/libros/la-chica-del-verano_978-84-480-3897-7" title="Añadir a estantería">
#  <i class="far fa-heart"></i>
#  </a>
#  </div>
#  <div class="d-flex book-action__content">
#  <div class="book-action__content--top d-none d-md-flex">
#  <!-- Solo en desktop -->
#  <div class="book-price">
#  <strong>
#                                                          19.90€
#                          </strong>
#                          (19.13€ sin IVA)
#                                              </div>
#  <div class="ratings grid-view">
#  </div>
#  <!-- //Solo en desktop -->
#  </div>
#  <div class="book-location">
#  <form action="https://www.todostuslibros.com/b2c_add_to_cart" id="addToCart" method="POST">
#  <input name="_token" type="hidden" value="v8ddx2xGXLupIiGdP5Eig9Tl59YhtDLwoUW1ILnd"/> <input name="isbn" type="hidden" value="978-84-480-3897-7"/>
#  <button class="btn btn-add-to-cart b2c btn-block mb-2" type="submit">
#  <!--<i class="fas fa-shopping-cart"></i> -->
#                  Añadir a la cesta
#                  </button>
#  </form>
#  <div class="availability-bookshops-pickup" data-allowres="1" data-isbn="978-84-480-3897-7">
#  </div>
#  </div>
#  <div class="bookstores">
#  <div class="availability-bookshops" data-allowres="1" data-isbn="978-84-480-3897-7"></div>
#  <span class="availability availability-high">
#  <i class="fas fa-check"></i> Disponibilidad alta
#      </span>
#  </div>
#  </div>
#  </div>
#  </li>,
#  <li class="book row" data-gtm-disponibilidad="" data-gtm-editorial="Editorial Bruño" data-gtm-index="5" data-gtm-isbn="978-84-696-4040-1" data-gtm-precio="10.50" data-gtm-titulo="El Lirio Blanco" id="book_978-84-696-4040-1">
#  <div class="col-12 col-sm-12 col-md-9 book-content">
#  <div class="row">
#  <div class="book-image col-4 col-sm-3 col-md-3 col-lg-3">
#  <a href="https://www.todostuslibros.com/libros/el-lirio-blanco_978-84-696-4040-1">
#  <img alt="El Lirio Blanco" height="150" src="https://static.cegal.es/imagenes/marcadas/9788469/978846964040.gif" title="El Lirio Blanco" width="100"/>
#  <span> 5 </span>
#  </a>
#  <!-- Solo Vista grid y móvil -->
#  <a class="btn bookshelves-link" data-book-isbn="978-84-696-4040-1" data-book-title="El Lirio Blanco" href="https://www.todostuslibros.com/login?_next=https://www.todostuslibros.com/libros/el-lirio-blanco_978-84-696-4040-1" title="Añadir a estantería">
#  <i class="far fa-heart"></i>
#  </a>
#  <!-- //Solo  Vista grid y móvil -->
#  </div>
#  <div class="book-details col-8 col-sm-9 col-md-9 col-lg-9 mb-2">
#  <h2 class="title">
#  <a href="https://www.todostuslibros.com/libros/el-lirio-blanco_978-84-696-4040-1">
#                          El Lirio Blanco
#                          </a>
#  </h2>
#  <h3 class="subtitle"><a href="https://www.todostuslibros.com/libros/el-lirio-blanco_978-84-696-4040-1"></a></h3>
#  <h3 class="author">
#  <a href="https://www.todostuslibros.com/autor/goscinny-rene-fabcaro">Goscinny, René / Fabcaro</a>
#  </h3>
#  <div class="data_isbn d-none d-md-block">978-84-696-4040-1 </div>
#  <div class="ratings list-view mb-3">
#  </div>
#  <p class="synopsis d-none d-md-block d-lg-block d-xl-block">El 26 de octubre de 2023 Astérix y Obélix regresan de la mano de un nuevo guionista, Fabrice Caro, para disfrutar de su aventura número 40. El título de este cómic es El Lirio Blanco, el nombre de una nueva corriente de pensamiento positivo que recorre Roma y se extiende por todo el Imperio a la vel...</p>
#  <!--<p class="synopsis">El 26 de octubre de 2023 Astérix y Obélix regresan de la mano de un nuevo guionista, Fabrice Caro, p...</p>-->
#  <!-- <p class="data">Editorial Bruño </p>-->
#  <!-- Solo en móvil -->
#  <div class="d-block d-block d-md-none">
#  <div class="book-action__content--top d-flex d-md-none">
#  <div class="book-price d-block d-md-none">
#  <strong>
#                                                                  10.50€
#                              </strong>
#                              (10.10€ sin IVA)
#                                                      </div>
#  </div>
#  </div>
#  <!-- Solo en móvil -->
#  </div>
#  </div>
#  </div>
#  <div class="col-12 col-sm-12 col-md-3 book-action">
#  <div class="book-action__top d-felx justify-content-end">
#  <a class="btn bookshelves-link" href="https://www.todostuslibros.com/login?_next=https://www.todostuslibros.com/libros/el-lirio-blanco_978-84-696-4040-1" title="Añadir a estantería">
#  <i class="far fa-heart"></i>
#  </a>
#  </div>
#  <div class="d-flex book-action__content">
#  <div class="book-action__content--top d-none d-md-flex">
#  <!-- Solo en desktop -->
#  <div class="book-price">
#  <strong>
#                                                          10.50€
#                          </strong>
#                          (10.10€ sin IVA)
#                                              </div>
#  <div class="ratings grid-view">
#  </div>
#  <!-- //Solo en desktop -->
#  </div>
#  <div class="book-location">
#  <form action="https://www.todostuslibros.com/b2c_add_to_cart" id="addToCart" method="POST">
#  <input name="_token" type="hidden" value="v8ddx2xGXLupIiGdP5Eig9Tl59YhtDLwoUW1ILnd"/> <input name="isbn" type="hidden" value="978-84-696-4040-1"/>
#  <button class="btn btn-add-to-cart b2c btn-block mb-2" type="submit">
#  <!--<i class="fas fa-shopping-cart"></i> -->
#                  Añadir a la cesta
#                  </button>
#  </form>
#  <div class="availability-bookshops-pickup" data-allowres="1" data-isbn="978-84-696-4040-1">
#  </div>
#  </div>
#  <div class="bookstores">
#  <div class="availability-bookshops" data-allowres="1" data-isbn="978-84-696-4040-1"></div>
#  <span class="availability availability-high">
#  <i class="fas fa-check"></i> Disponibilidad alta
#      </span>
#  </div>
#  </div>
#  </div>
#  </li>,
#  <li class="book row" data-gtm-disponibilidad="" data-gtm-editorial="EDIBESA" data-gtm-index="6" data-gtm-isbn="978-84-19640-00-0" data-gtm-precio="2.65" data-gtm-titulo="EVANGELIO 2024 LETRA PEQUEÑA BOLSILLO" id="book_978-84-19640-00-0">
#  <div class="col-12 col-sm-12 col-md-9 book-content">
#  <div class="row">
#  <div class="book-image col-4 col-sm-3 col-md-3 col-lg-3">
#  <a href="https://www.todostuslibros.com/libros/evangelio-2024-letra-pequena-bolsillo_978-84-19640-00-0">
#  <img alt="EVANGELIO 2024 LETRA PEQUEÑA BOLSILLO" height="150" src="https://static.cegal.es/imagenes/marcadas/9788419/978841964000.gif" title="EVANGELIO 2024 LETRA PEQUEÑA BOLSILLO" width="100"/>
#  <span> 6 </span>
#  </a>
#  <!-- Solo Vista grid y móvil -->
#  <a class="btn bookshelves-link" data-book-isbn="978-84-19640-00-0" data-book-title="EVANGELIO 2024 LETRA PEQUEÑA BOLSILLO" href="https://www.todostuslibros.com/login?_next=https://www.todostuslibros.com/libros/evangelio-2024-letra-pequena-bolsillo_978-84-19640-00-0" title="Añadir a estantería">
#  <i class="far fa-heart"></i>
#  </a>
#  <!-- //Solo  Vista grid y móvil -->
#  </div>
#  <div class="book-details col-8 col-sm-9 col-md-9 col-lg-9 mb-2">
#  <h2 class="title">
#  <a href="https://www.todostuslibros.com/libros/evangelio-2024-letra-pequena-bolsillo_978-84-19640-00-0">
#                          EVANGELIO 2024 LETRA PEQUEÑA BOLSILLO
#                          </a>
#  </h2>
#  <h3 class="subtitle"><a href="https://www.todostuslibros.com/libros/evangelio-2024-letra-pequena-bolsillo_978-84-19640-00-0"></a></h3>
#  <h3 class="author">
#  <a href="https://www.todostuslibros.com/autor/martinez-puche-alvarez-luis-del-cerro">MARTINEZ PUCHE/ ALVAREZ,LUIS/ DEL CERRO</a>
#  </h3>
#  <div class="data_isbn d-none d-md-block">978-84-19640-00-0 </div>
#  <div class="ratings list-view mb-3">
#  </div>
#  <p class="synopsis d-none d-md-block d-lg-block d-xl-block">Evangelio con el Papa Francisco. Ciclo B.  Una página por día.  Cada día una reflexión del papa  Francisco sobre el Evangelio.  Incluye: imágenes de santos, calendario litúrgico, santoral, oraciones y vida cristiana.</p>
#  <!--<p class="synopsis">Evangelio con el Papa Francisco. Ciclo B.  Una página por día.  Cada día una reflexión del papa  Fra...</p>-->
#  <!-- <p class="data">EDIBESA </p>-->
#  <!-- Solo en móvil -->
#  <div class="d-block d-block d-md-none">
#  <div class="book-action__content--top d-flex d-md-none">
#  <div class="book-price d-block d-md-none">
#  <strong>
#                                                                  2.65€
#                              </strong>
#                              (2.55€ sin IVA)
#                                                      </div>
#  </div>
#  </div>
#  <!-- Solo en móvil -->
#  </div>
#  </div>
#  </div>
#  <div class="col-12 col-sm-12 col-md-3 book-action">
#  <div class="book-action__top d-felx justify-content-end">
#  <a class="btn bookshelves-link" href="https://www.todostuslibros.com/login?_next=https://www.todostuslibros.com/libros/evangelio-2024-letra-pequena-bolsillo_978-84-19640-00-0" title="Añadir a estantería">
#  <i class="far fa-heart"></i>
#  </a>
#  </div>
#  <div class="d-flex book-action__content">
#  <div class="book-action__content--top d-none d-md-flex">
#  <!-- Solo en desktop -->
#  <div class="book-price">
#  <strong>
#                                                          2.65€
#                          </strong>
#                          (2.55€ sin IVA)
#                                              </div>
#  <div class="ratings grid-view">
#  </div>
#  <!-- //Solo en desktop -->
#  </div>
#  <div class="book-location">
#  <form action="https://www.todostuslibros.com/b2c_add_to_cart" id="addToCart" method="POST">
#  <input name="_token" type="hidden" value="v8ddx2xGXLupIiGdP5Eig9Tl59YhtDLwoUW1ILnd"/> <input name="isbn" type="hidden" value="978-84-19640-00-0"/>
#  <button class="btn btn-add-to-cart b2c btn-block mb-2" type="submit">
#  <!--<i class="fas fa-shopping-cart"></i> -->
#                  Añadir a la cesta
#                  </button>
#  </form>
#  <div class="availability-bookshops-pickup" data-allowres="1" data-isbn="978-84-19640-00-0">
#  </div>
#  </div>
#  <div class="bookstores">
#  <div class="availability-bookshops" data-allowres="1" data-isbn="978-84-19640-00-0"></div>
#  <span class="availability availability-medium">
#  <i class="fas fa-check"></i> Disponibilidad media
#      </span>
#  </div>
#  </div>
#  </div>
#  </li>,
#  <li class="book row" data-gtm-disponibilidad="" data-gtm-editorial="ALFAGUARA" data-gtm-index="7" data-gtm-isbn="978-84-204-7636-0" data-gtm-precio="21.90" data-gtm-titulo="El problema final" id="book_978-84-204-7636-0">
#  <div class="col-12 col-sm-12 col-md-9 book-content">
#  <div class="row">
#  <div class="book-image col-4 col-sm-3 col-md-3 col-lg-3">
#  <a href="https://www.todostuslibros.com/libros/el-problema-final_978-84-204-7636-0">
#  <img alt="El problema final" height="150" src="https://static.cegal.es/imagenes/marcadas/9788420/978842047636.gif" title="El problema final" width="100"/>
#  <span> 7 </span>
#  </a>
#  <!-- Solo Vista grid y móvil -->
#  <a class="btn bookshelves-link" data-book-isbn="978-84-204-7636-0" data-book-title="El problema final" href="https://www.todostuslibros.com/login?_next=https://www.todostuslibros.com/libros/el-problema-final_978-84-204-7636-0" title="Añadir a estantería">
#  <i class="far fa-heart"></i>
#  </a>
#  <!-- //Solo  Vista grid y móvil -->
#  </div>
#  <div class="book-details col-8 col-sm-9 col-md-9 col-lg-9 mb-2">
#  <h2 class="title">
#  <a href="https://www.todostuslibros.com/libros/el-problema-final_978-84-204-7636-0">
#                          El problema final
#                          </a>
#  </h2>
#  <h3 class="subtitle"><a href="https://www.todostuslibros.com/libros/el-problema-final_978-84-204-7636-0"></a></h3>
#  <h3 class="author">
#  <a href="https://www.todostuslibros.com/autor/perez-reverte-arturo">Pérez-Reverte, Arturo</a>
#  </h3>
#  <div class="data_isbn d-none d-md-block">978-84-204-7636-0 </div>
#  <div class="ratings list-view mb-3">
#  </div>
#  <p class="synopsis d-none d-md-block d-lg-block d-xl-block">LA NUEVA NOVELA DE ARTURO PÉREZ-REVERTE  Un crimen imposible. Un detective insospechado.  No se trata de un desafío entre el asesino y el detective, sino de un duelo de inteligencia entre el autor y el lector. —Haría falta un policía—sugirió alguien—. Un detective. —Tenemos uno —dijo Foxá.—Todos sig...</p>
#  <!--<p class="synopsis">LA NUEVA NOVELA DE ARTURO PÉREZ-REVERTE  Un crimen imposible. Un detective insospechado.  No se trat...</p>-->
#  <!-- <p class="data">ALFAGUARA </p>-->
#  <!-- Solo en móvil -->
#  <div class="d-block d-block d-md-none">
#  <div class="book-action__content--top d-flex d-md-none">
#  <div class="book-price d-block d-md-none">
#  <strong>
#                                                                  21.90€
#                              </strong>
#                              (21.06€ sin IVA)
#                                                      </div>
#  </div>
#  </div>
#  <!-- Solo en móvil -->
#  </div>
#  </div>
#  </div>
#  <div class="col-12 col-sm-12 col-md-3 book-action">
#  <div class="book-action__top d-felx justify-content-end">
#  <a class="btn bookshelves-link" href="https://www.todostuslibros.com/login?_next=https://www.todostuslibros.com/libros/el-problema-final_978-84-204-7636-0" title="Añadir a estantería">
#  <i class="far fa-heart"></i>
#  </a>
#  </div>
#  <div class="d-flex book-action__content">
#  <div class="book-action__content--top d-none d-md-flex">
#  <!-- Solo en desktop -->
#  <div class="book-price">
#  <strong>
#                                                          21.90€
#                          </strong>
#                          (21.06€ sin IVA)
#                                              </div>
#  <div class="ratings grid-view">
#  </div>
#  <!-- //Solo en desktop -->
#  </div>
#  <div class="book-location">
#  <form action="https://www.todostuslibros.com/b2c_add_to_cart" id="addToCart" method="POST">
#  <input name="_token" type="hidden" value="v8ddx2xGXLupIiGdP5Eig9Tl59YhtDLwoUW1ILnd"/> <input name="isbn" type="hidden" value="978-84-204-7636-0"/>
#  <button class="btn btn-add-to-cart b2c btn-block mb-2" type="submit">
#  <!--<i class="fas fa-shopping-cart"></i> -->
#                  Añadir a la cesta
#                  </button>
#  </form>
#  <div class="availability-bookshops-pickup" data-allowres="1" data-isbn="978-84-204-7636-0">
#  </div>
#  </div>
#  <div class="bookstores">
#  <div class="availability-bookshops" data-allowres="1" data-isbn="978-84-204-7636-0"></div>
#  <span class="availability availability-high">
#  <i class="fas fa-check"></i> Disponibilidad alta
#      </span>
#  </div>
#  </div>
#  </div>
#  </li>,
#  <li class="book row" data-gtm-disponibilidad="" data-gtm-editorial="Diana Editorial" data-gtm-index="8" data-gtm-isbn="978-84-18118-03-6" data-gtm-precio="19.90" data-gtm-titulo="Hábitos atómicos" id="book_978-84-18118-03-6">
#  <div class="col-12 col-sm-12 col-md-9 book-content">
#  <div class="row">
#  <div class="book-image col-4 col-sm-3 col-md-3 col-lg-3">
#  <a href="https://www.todostuslibros.com/libros/habitos-atomicos_978-84-18118-03-6">
#  <img alt="Hábitos atómicos" height="150" src="https://static.cegal.es/imagenes/marcadas/9788418/978841811803.gif" title="Hábitos atómicos" width="100"/>
#  <span> 8 </span>
#  </a>
#  <!-- Solo Vista grid y móvil -->
#  <a class="btn bookshelves-link" data-book-isbn="978-84-18118-03-6" data-book-title="Hábitos atómicos" href="https://www.todostuslibros.com/login?_next=https://www.todostuslibros.com/libros/habitos-atomicos_978-84-18118-03-6" title="Añadir a estantería">
#  <i class="far fa-heart"></i>
#  </a>
#  <!-- //Solo  Vista grid y móvil -->
#  </div>
#  <div class="book-details col-8 col-sm-9 col-md-9 col-lg-9 mb-2">
#  <h2 class="title">
#  <a href="https://www.todostuslibros.com/libros/habitos-atomicos_978-84-18118-03-6">
#                          Hábitos atómicos
#                          </a>
#  </h2>
#  <h3 class="subtitle"><a href="https://www.todostuslibros.com/libros/habitos-atomicos_978-84-18118-03-6">Cambios pequeños, resultados extraordinarios</a></h3>
#  <h3 class="author">
#  <a href="https://www.todostuslibros.com/autor/clear-james">Clear, James</a>
#  </h3>
#  <div class="data_isbn d-none d-md-block">978-84-18118-03-6 </div>
#  <div class="ratings list-view mb-3">
#  </div>
#  <p class="synopsis d-none d-md-block d-lg-block d-xl-block">MÁS DE 200.000 EJEMPLARES VENDIDOS EN ESPAÑA.
#  	MÁS DE 15 MILLONES DE EJEMPLARES VENDIDOS EN TODO EL MUNDO.
#  	«Sumamente práctico y útil.» MARK MANSON, autor de El sutil arte de que (casi todo) te importe una mi*rda
#  	«Paso a paso, cambiará tu rutina.» Financial Times
#
#  	A menudo pensamos que para camb...</p>
#  <!--<p class="synopsis">MÁS DE 200.000 EJEMPLARES VENDIDOS EN ESPAÑA.
#  	MÁS DE 15 MILLONES DE EJEMPLARES VENDIDOS EN TODO EL...</p>-->
#  <!-- <p class="data">Diana Editorial </p>-->
#  <!-- Solo en móvil -->
#  <div class="d-block d-block d-md-none">
#  <div class="book-action__content--top d-flex d-md-none">
#  <div class="book-price d-block d-md-none">
#  <strong>
#                                                                  19.90€
#                              </strong>
#                              (19.13€ sin IVA)
#                                                      </div>
#  </div>
#  </div>
#  <!-- Solo en móvil -->
#  </div>
#  </div>
#  </div>
#  <div class="col-12 col-sm-12 col-md-3 book-action">
#  <div class="book-action__top d-felx justify-content-end">
#  <a class="btn bookshelves-link" href="https://www.todostuslibros.com/login?_next=https://www.todostuslibros.com/libros/habitos-atomicos_978-84-18118-03-6" title="Añadir a estantería">
#  <i class="far fa-heart"></i>
#  </a>
#  </div>
#  <div class="d-flex book-action__content">
#  <div class="book-action__content--top d-none d-md-flex">
#  <!-- Solo en desktop -->
#  <div class="book-price">
#  <strong>
#                                                          19.90€
#                          </strong>
#                          (19.13€ sin IVA)
#                                              </div>
#  <div class="ratings grid-view">
#  </div>
#  <!-- //Solo en desktop -->
#  </div>
#  <div class="book-location">
#  <form action="https://www.todostuslibros.com/b2c_add_to_cart" id="addToCart" method="POST">
#  <input name="_token" type="hidden" value="v8ddx2xGXLupIiGdP5Eig9Tl59YhtDLwoUW1ILnd"/> <input name="isbn" type="hidden" value="978-84-18118-03-6"/>
#  <button class="btn btn-add-to-cart b2c btn-block mb-2" type="submit">
#  <!--<i class="fas fa-shopping-cart"></i> -->
#                  Añadir a la cesta
#                  </button>
#  </form>
#  <div class="availability-bookshops-pickup" data-allowres="1" data-isbn="978-84-18118-03-6">
#  </div>
#  </div>
#  <div class="bookstores">
#  <div class="availability-bookshops" data-allowres="1" data-isbn="978-84-18118-03-6"></div>
#  <span class="availability availability-high">
#  <i class="fas fa-check"></i> Disponibilidad alta
#      </span>
#  </div>
#  </div>
#  </div>
#  </li>,
#  <li class="book row" data-gtm-disponibilidad="" data-gtm-editorial="Seix Barral" data-gtm-index="9" data-gtm-isbn="978-84-322-4232-8" data-gtm-precio="19.90" data-gtm-titulo="No te veré morir" id="book_978-84-322-4232-8">
#  <div class="col-12 col-sm-12 col-md-9 book-content">
#  <div class="row">
#  <div class="book-image col-4 col-sm-3 col-md-3 col-lg-3">
#  <a href="https://www.todostuslibros.com/libros/no-te-vere-morir_978-84-322-4232-8">
#  <img alt="No te veré morir" height="150" src="https://static.cegal.es/imagenes/marcadas/9788432/978843224232.gif" title="No te veré morir" width="100"/>
#  <span> 9 </span>
#  </a>
#  <!-- Solo Vista grid y móvil -->
#  <a class="btn bookshelves-link" data-book-isbn="978-84-322-4232-8" data-book-title="No te veré morir" href="https://www.todostuslibros.com/login?_next=https://www.todostuslibros.com/libros/no-te-vere-morir_978-84-322-4232-8" title="Añadir a estantería">
#  <i class="far fa-heart"></i>
#  </a>
#  <!-- //Solo  Vista grid y móvil -->
#  </div>
#  <div class="book-details col-8 col-sm-9 col-md-9 col-lg-9 mb-2">
#  <h2 class="title">
#  <a href="https://www.todostuslibros.com/libros/no-te-vere-morir_978-84-322-4232-8">
#                          No te veré morir
#                          </a>
#  </h2>
#  <h3 class="subtitle"><a href="https://www.todostuslibros.com/libros/no-te-vere-morir_978-84-322-4232-8"></a></h3>
#  <h3 class="author">
#  <a href="https://www.todostuslibros.com/autor/munoz-molina-antonio">Muñoz Molina, Antonio</a>
#  </h3>
#  <div class="data_isbn d-none d-md-block">978-84-322-4232-8 </div>
#  <div class="ratings list-view mb-3">
#  </div>
#  <p class="synopsis d-none d-md-block d-lg-block d-xl-block">Durante su juventud, Gabriel Aristu y Adriana Zuber protagonizaron una apasionada historia de amor que parecía destinada a durar para siempre. El futuro, sin embargo, tenía otros planes para ellos. Separados durante cincuenta años por un océano de incomunicación, ella atrapada en la España de la dic...</p>
#  <!--<p class="synopsis">Durante su juventud, Gabriel Aristu y Adriana Zuber protagonizaron una apasionada historia de amor q...</p>-->
#  <!-- <p class="data">Seix Barral </p>-->
#  <!-- Solo en móvil -->
#  <div class="d-block d-block d-md-none">
#  <div class="book-action__content--top d-flex d-md-none">
#  <div class="book-price d-block d-md-none">
#  <strong>
#                                                                  19.90€
#                              </strong>
#                              (19.13€ sin IVA)
#                                                      </div>
#  </div>
#  </div>
#  <!-- Solo en móvil -->
#  </div>
#  </div>
#  </div>
#  <div class="col-12 col-sm-12 col-md-3 book-action">
#  <div class="book-action__top d-felx justify-content-end">
#  <a class="btn bookshelves-link" href="https://www.todostuslibros.com/login?_next=https://www.todostuslibros.com/libros/no-te-vere-morir_978-84-322-4232-8" title="Añadir a estantería">
#  <i class="far fa-heart"></i>
#  </a>
#  </div>
#  <div class="d-flex book-action__content">
#  <div class="book-action__content--top d-none d-md-flex">
#  <!-- Solo en desktop -->
#  <div class="book-price">
#  <strong>
#                                                          19.90€
#                          </strong>
#                          (19.13€ sin IVA)
#                                              </div>
#  <div class="ratings grid-view">
#  </div>
#  <!-- //Solo en desktop -->
#  </div>
#  <div class="book-location">
#  <form action="https://www.todostuslibros.com/b2c_add_to_cart" id="addToCart" method="POST">
#  <input name="_token" type="hidden" value="v8ddx2xGXLupIiGdP5Eig9Tl59YhtDLwoUW1ILnd"/> <input name="isbn" type="hidden" value="978-84-322-4232-8"/>
#  <button class="btn btn-add-to-cart b2c btn-block mb-2" type="submit">
#  <!--<i class="fas fa-shopping-cart"></i> -->
#                  Añadir a la cesta
#                  </button>
#  </form>
#  <div class="availability-bookshops-pickup" data-allowres="1" data-isbn="978-84-322-4232-8">
#  </div>
#  </div>
#  <div class="bookstores">
#  <div class="availability-bookshops" data-allowres="1" data-isbn="978-84-322-4232-8"></div>
#  <span class="availability availability-high">
#  <i class="fas fa-check"></i> Disponibilidad alta
#      </span>
#  </div>
#  </div>
#  </div>
#  </li>,
#  <li class="book row" data-gtm-disponibilidad="" data-gtm-editorial="ALFAGUARA" data-gtm-index="10" data-gtm-isbn="978-84-204-6143-4" data-gtm-precio="18.90" data-gtm-titulo="Mirafiori" id="book_978-84-204-6143-4">
#  <div class="col-12 col-sm-12 col-md-9 book-content">
#  <div class="row">
#  <div class="book-image col-4 col-sm-3 col-md-3 col-lg-3">
#  <a href="https://www.todostuslibros.com/libros/mirafiori_978-84-204-6143-4">
#  <img alt="Mirafiori" height="150" src="https://static.cegal.es/imagenes/marcadas/9788420/978842046143.gif" title="Mirafiori" width="100"/>
#  <span> 10 </span>
#  </a>
#  <!-- Solo Vista grid y móvil -->
#  <a class="btn bookshelves-link" data-book-isbn="978-84-204-6143-4" data-book-title="Mirafiori" href="https://www.todostuslibros.com/login?_next=https://www.todostuslibros.com/libros/mirafiori_978-84-204-6143-4" title="Añadir a estantería">
#  <i class="far fa-heart"></i>
#  </a>
#  <!-- //Solo  Vista grid y móvil -->
#  </div>
#  <div class="book-details col-8 col-sm-9 col-md-9 col-lg-9 mb-2">
#  <h2 class="title">
#  <a href="https://www.todostuslibros.com/libros/mirafiori_978-84-204-6143-4">
#                          Mirafiori
#                          </a>
#  </h2>
#  <h3 class="subtitle"><a href="https://www.todostuslibros.com/libros/mirafiori_978-84-204-6143-4"></a></h3>
#  <h3 class="author">
#  <a href="https://www.todostuslibros.com/autor/jabois-manuel">Jabois, Manuel</a>
#  </h3>
#  <div class="data_isbn d-none d-md-block">978-84-204-6143-4 </div>
#  <div class="ratings list-view mb-3">
#  </div>
#  <p class="synopsis d-none d-md-block d-lg-block d-xl-block">VUELVE EL MEJOR JABOIS CON UNA HISTORIA DE AMOR  Una novela sobre la belleza de todo aquello que no tiene explicación  «Jabois escribe en estado de gracia».Laura Barrachina, El Ojo Crítico «Si uno está enamorado de verdad, hasta en las almas más libres y salvajes y modernas, más seguras de sí mismas...</p>
#  <!--<p class="synopsis">VUELVE EL MEJOR JABOIS CON UNA HISTORIA DE AMOR  Una novela sobre la belleza de todo aquello que no...</p>-->
#  <!-- <p class="data">ALFAGUARA </p>-->
#  <!-- Solo en móvil -->
#  <div class="d-block d-block d-md-none">
#  <div class="book-action__content--top d-flex d-md-none">
#  <div class="book-price d-block d-md-none">
#  <strong>
#                                                                  18.90€
#                              </strong>
#                              (18.17€ sin IVA)
#                                                      </div>
#  </div>
#  </div>
#  <!-- Solo en móvil -->
#  </div>
#  </div>
#  </div>
#  <div class="col-12 col-sm-12 col-md-3 book-action">
#  <div class="book-action__top d-felx justify-content-end">
#  <a class="btn bookshelves-link" href="https://www.todostuslibros.com/login?_next=https://www.todostuslibros.com/libros/mirafiori_978-84-204-6143-4" title="Añadir a estantería">
#  <i class="far fa-heart"></i>
#  </a>
#  </div>
#  <div class="d-flex book-action__content">
#  <div class="book-action__content--top d-none d-md-flex">
#  <!-- Solo en desktop -->
#  <div class="book-price">
#  <strong>
#                                                          18.90€
#                          </strong>
#                          (18.17€ sin IVA)
#                                              </div>
#  <div class="ratings grid-view">
#  </div>
#  <!-- //Solo en desktop -->
#  </div>
#  <div class="book-location">
#  <form action="https://www.todostuslibros.com/b2c_add_to_cart" id="addToCart" method="POST">
#  <input name="_token" type="hidden" value="v8ddx2xGXLupIiGdP5Eig9Tl59YhtDLwoUW1ILnd"/> <input name="isbn" type="hidden" value="978-84-204-6143-4"/>
#  <button class="btn btn-add-to-cart b2c btn-block mb-2" type="submit">
#  <!--<i class="fas fa-shopping-cart"></i> -->
#                  Añadir a la cesta
#                  </button>
#  </form>
#  <div class="availability-bookshops-pickup" data-allowres="1" data-isbn="978-84-204-6143-4">
#  </div>
#  </div>
#  <div class="bookstores">
#  <div class="availability-bookshops" data-allowres="1" data-isbn="978-84-204-6143-4"></div>
#  <span class="availability availability-high">
#  <i class="fas fa-check"></i> Disponibilidad alta
#      </span>
#  </div>
#  </div>
#  </div>
#  </li>,
#  <li class="book row" data-gtm-disponibilidad="" data-gtm-editorial="Editorial Funambulista" data-gtm-index="11" data-gtm-isbn="978-84-126587-9-8" data-gtm-precio="24.90" data-gtm-titulo="Dios - La ciencia - Las pruebas" id="book_978-84-126587-9-8">
#  <div class="col-12 col-sm-12 col-md-9 book-content">
#  <div class="row">
#  <div class="book-image col-4 col-sm-3 col-md-3 col-lg-3">
#  <a href="https://www.todostuslibros.com/libros/dios-la-ciencia-las-pruebas_978-84-126587-9-8">
#  <img alt="Dios - La ciencia - Las pruebas" height="150" src="https://static.cegal.es/imagenes/marcadas/9788412/978841265879.gif" title="Dios - La ciencia - Las pruebas" width="100"/>
#  <span> 11 </span>
#  </a>
#  <!-- Solo Vista grid y móvil -->
#  <a class="btn bookshelves-link" data-book-isbn="978-84-126587-9-8" data-book-title="Dios - La ciencia - Las pruebas" href="https://www.todostuslibros.com/login?_next=https://www.todostuslibros.com/libros/dios-la-ciencia-las-pruebas_978-84-126587-9-8" title="Añadir a estantería">
#  <i class="far fa-heart"></i>
#  </a>
#  <!-- //Solo  Vista grid y móvil -->
#  </div>
#  <div class="book-details col-8 col-sm-9 col-md-9 col-lg-9 mb-2">
#  <h2 class="title">
#  <a href="https://www.todostuslibros.com/libros/dios-la-ciencia-las-pruebas_978-84-126587-9-8">
#                          Dios - La ciencia - Las pruebas
#                          </a>
#  </h2>
#  <h3 class="subtitle"><a href="https://www.todostuslibros.com/libros/dios-la-ciencia-las-pruebas_978-84-126587-9-8">El albor de una revolución</a></h3>
#  <h3 class="author">
#  <a href="https://www.todostuslibros.com/autor/bollore-michel-yves-bonnassies-olivier">Bolloré, Michel-Yves / Bonnassies, Olivier</a>
#  </h3>
#  <div class="data_isbn d-none d-md-block">978-84-126587-9-8 </div>
#  <div class="ratings list-view mb-3">
#  </div>
#  <p class="synopsis d-none d-md-block d-lg-block d-xl-block">En este libro se revelan, al cabo de tres años de trabajo en colaboración con unos veinte científicos y especialistas de alto nivel, las pruebas modernas de la existencia de Dios. Durante cerca de cuatro siglos, de Copérnico a Freud, pasando por Galileo y Darwin, los descubrimientos científicos se a...</p>
#  <!--<p class="synopsis">En este libro se revelan, al cabo de tres años de trabajo en colaboración con unos veinte científico...</p>-->
#  <!-- <p class="data">Editorial Funambulista </p>-->
#  <!-- Solo en móvil -->
#  <div class="d-block d-block d-md-none">
#  <div class="book-action__content--top d-flex d-md-none">
#  <div class="book-price d-block d-md-none">
#  <strong>
#                                                                  24.90€
#                              </strong>
#                              (23.94€ sin IVA)
#                                                      </div>
#  </div>
#  </div>
#  <!-- Solo en móvil -->
#  </div>
#  </div>
#  </div>
#  <div class="col-12 col-sm-12 col-md-3 book-action">
#  <div class="book-action__top d-felx justify-content-end">
#  <a class="btn bookshelves-link" href="https://www.todostuslibros.com/login?_next=https://www.todostuslibros.com/libros/dios-la-ciencia-las-pruebas_978-84-126587-9-8" title="Añadir a estantería">
#  <i class="far fa-heart"></i>
#  </a>
#  </div>
#  <div class="d-flex book-action__content">
#  <div class="book-action__content--top d-none d-md-flex">
#  <!-- Solo en desktop -->
#  <div class="book-price">
#  <strong>
#                                                          24.90€
#                          </strong>
#                          (23.94€ sin IVA)
#                                              </div>
#  <div class="ratings grid-view">
#  </div>
#  <!-- //Solo en desktop -->
#  </div>
#  <div class="book-location">
#  <form action="https://www.todostuslibros.com/b2c_add_to_cart" id="addToCart" method="POST">
#  <input name="_token" type="hidden" value="v8ddx2xGXLupIiGdP5Eig9Tl59YhtDLwoUW1ILnd"/> <input name="isbn" type="hidden" value="978-84-126587-9-8"/>
#  <button class="btn btn-add-to-cart b2c btn-block mb-2" type="submit">
#  <!--<i class="fas fa-shopping-cart"></i> -->
#                  Añadir a la cesta
#                  </button>
#  </form>
#  <div class="availability-bookshops-pickup" data-allowres="1" data-isbn="978-84-126587-9-8">
#  </div>
#  </div>
#  <div class="bookstores">
#  <div class="availability-bookshops" data-allowres="1" data-isbn="978-84-126587-9-8"></div>
#  <span class="availability availability-high">
#  <i class="fas fa-check"></i> Disponibilidad alta
#      </span>
#  </div>
#  </div>
#  </div>
#  </li>,
#  <li class="book row" data-gtm-disponibilidad="" data-gtm-editorial="EDIBESA" data-gtm-index="12" data-gtm-isbn="978-84-19640-01-7" data-gtm-precio="4.60" data-gtm-titulo="EVANGELIO 2024 LETRA GRANDE" id="book_978-84-19640-01-7">
#  <div class="col-12 col-sm-12 col-md-9 book-content">
#  <div class="row">
#  <div class="book-image col-4 col-sm-3 col-md-3 col-lg-3">
#  <a href="https://www.todostuslibros.com/libros/evangelio-2024-letra-grande_978-84-19640-01-7">
#  <img alt="EVANGELIO 2024 LETRA GRANDE" height="150" src="https://static.cegal.es/imagenes/marcadas/9788419/978841964001.gif" title="EVANGELIO 2024 LETRA GRANDE" width="100"/>
#  <span> 12 </span>
#  </a>
#  <!-- Solo Vista grid y móvil -->
#  <a class="btn bookshelves-link" data-book-isbn="978-84-19640-01-7" data-book-title="EVANGELIO 2024 LETRA GRANDE" href="https://www.todostuslibros.com/login?_next=https://www.todostuslibros.com/libros/evangelio-2024-letra-grande_978-84-19640-01-7" title="Añadir a estantería">
#  <i class="far fa-heart"></i>
#  </a>
#  <!-- //Solo  Vista grid y móvil -->
#  </div>
#  <div class="book-details col-8 col-sm-9 col-md-9 col-lg-9 mb-2">
#  <h2 class="title">
#  <a href="https://www.todostuslibros.com/libros/evangelio-2024-letra-grande_978-84-19640-01-7">
#                          EVANGELIO 2024 LETRA GRANDE
#                          </a>
#  </h2>
#  <h3 class="subtitle"><a href="https://www.todostuslibros.com/libros/evangelio-2024-letra-grande_978-84-19640-01-7"></a></h3>
#  <h3 class="author">
#  <a href="https://www.todostuslibros.com/autor/martinez-puche-alvarez-luis-del-cerro">MARTINEZ PUCHE/ ALVAREZ,LUIS/ DEL CERRO</a>
#  </h3>
#  <div class="data_isbn d-none d-md-block">978-84-19640-01-7 </div>
#  <div class="ratings list-view mb-3">
#  </div>
#  <p class="synopsis d-none d-md-block d-lg-block d-xl-block">Evangelio con el Papa Francisco. Ciclo B.  Una página por día.  Cada día una reflexión del papa  Francisco sobre el Evangelio.  Incluye: imágenes de santos, calendario litúrgico, santoral, oraciones y vida cristiana.</p>
#  <!--<p class="synopsis">Evangelio con el Papa Francisco. Ciclo B.  Una página por día.  Cada día una reflexión del papa  Fra...</p>-->
#  <!-- <p class="data">EDIBESA </p>-->
#  <!-- Solo en móvil -->
#  <div class="d-block d-block d-md-none">
#  <div class="book-action__content--top d-flex d-md-none">
#  <div class="book-price d-block d-md-none">
#  <strong>
#                                                                  4.60€
#                              </strong>
#                              (4.42€ sin IVA)
#                                                      </div>
#  </div>
#  </div>
#  <!-- Solo en móvil -->
#  </div>
#  </div>
#  </div>
#  <div class="col-12 col-sm-12 col-md-3 book-action">
#  <div class="book-action__top d-felx justify-content-end">
#  <a class="btn bookshelves-link" href="https://www.todostuslibros.com/login?_next=https://www.todostuslibros.com/libros/evangelio-2024-letra-grande_978-84-19640-01-7" title="Añadir a estantería">
#  <i class="far fa-heart"></i>
#  </a>
#  </div>
#  <div class="d-flex book-action__content">
#  <div class="book-action__content--top d-none d-md-flex">
#  <!-- Solo en desktop -->
#  <div class="book-price">
#  <strong>
#                                                          4.60€
#                          </strong>
#                          (4.42€ sin IVA)
#                                              </div>
#  <div class="ratings grid-view">
#  </div>
#  <!-- //Solo en desktop -->
#  </div>
#  <div class="book-location">
#  <form action="https://www.todostuslibros.com/b2c_add_to_cart" id="addToCart" method="POST">
#  <input name="_token" type="hidden" value="v8ddx2xGXLupIiGdP5Eig9Tl59YhtDLwoUW1ILnd"/> <input name="isbn" type="hidden" value="978-84-19640-01-7"/>
#  <button class="btn btn-add-to-cart b2c btn-block mb-2" type="submit">
#  <!--<i class="fas fa-shopping-cart"></i> -->
#                  Añadir a la cesta
#                  </button>
#  </form>
#  <div class="availability-bookshops-pickup" data-allowres="1" data-isbn="978-84-19640-01-7">
#  </div>
#  </div>
#  <div class="bookstores">
#  <div class="availability-bookshops" data-allowres="1" data-isbn="978-84-19640-01-7"></div>
#  <span class="availability availability-medium">
#  <i class="fas fa-check"></i> Disponibilidad media
#      </span>
#  </div>
#  </div>
#  </div>
#  </li>]

# %%
authors = [authors_info[i].find_all("h3", {"class":"author"})[0].getText().strip() for i in range(len(authors_info))]

# %% [markdown]
# ## Get secondary links to obtain other data

# %%
link_info = body.find_all("div", {"class": "book-image col-4 col-sm-3 col-md-3 col-lg-3"})
link_info
# Out:
# [<div class="book-image col-4 col-sm-3 col-md-3 col-lg-3">
#  <a href="https://www.todostuslibros.com/libros/todo-vuelve-todo-arde-2_978-84-666-7568-0">
#  <img alt="Todo vuelve (Todo arde 2)" height="150" src="https://static.cegal.es/imagenes/marcadas/9788466/978846667568.gif" title="Todo vuelve (Todo arde 2)" width="100"/>
#  <span> 1 </span>
#  </a>
#  <!-- Solo Vista grid y móvil -->
#  <a class="btn bookshelves-link" data-book-isbn="978-84-666-7568-0" data-book-title="Todo vuelve (Todo arde 2)" href="https://www.todostuslibros.com/login?_next=https://www.todostuslibros.com/libros/todo-vuelve-todo-arde-2_978-84-666-7568-0" title="Añadir a estantería">
#  <i class="far fa-heart"></i>
#  </a>
#  <!-- //Solo  Vista grid y móvil -->
#  </div>,
#  <div class="book-image col-4 col-sm-3 col-md-3 col-lg-3">
#  <a href="https://www.todostuslibros.com/libros/el-infierno_978-84-08-27758-3">
#  <img alt="El Infierno" height="150" src="https://static.cegal.es/imagenes/marcadas/9788408/978840827758.gif" title="El Infierno" width="100"/>
#  <span> 2 </span>
#  </a>
#  <!-- Solo Vista grid y móvil -->
#  <a class="btn bookshelves-link" data-book-isbn="978-84-08-27758-3" data-book-title="El Infierno" href="https://www.todostuslibros.com/login?_next=https://www.todostuslibros.com/libros/el-infierno_978-84-08-27758-3" title="Añadir a estantería">
#  <i class="far fa-heart"></i>
#  </a>
#  <!-- //Solo  Vista grid y móvil -->
#  </div>,
#  <div class="book-image col-4 col-sm-3 col-md-3 col-lg-3">
#  <a href="https://www.todostuslibros.com/libros/la-armadura-de-la-luz-saga-los-pilares-de-la-tierra-4_978-84-01-03013-0">
#  <img alt="La armadura de la luz (Saga Los pilares de la Tierra 4)" height="150" src="https://static.cegal.es/imagenes/marcadas/9788401/978840103013.gif" title="La armadura de la luz (Saga Los pilares de la Tierra 4)" width="100"/>
#  <span> 3 </span>
#  </a>
#  <!-- Solo Vista grid y móvil -->
#  <a class="btn bookshelves-link" data-book-isbn="978-84-01-03013-0" data-book-title="La armadura de la luz (Saga Los pilares de la Tierra 4)" href="https://www.todostuslibros.com/login?_next=https://www.todostuslibros.com/libros/la-armadura-de-la-luz-saga-los-pilares-de-la-tierra-4_978-84-01-03013-0" title="Añadir a estantería">
#  <i class="far fa-heart"></i>
#  </a>
#  <!-- //Solo  Vista grid y móvil -->
#  </div>,
#  <div class="book-image col-4 col-sm-3 col-md-3 col-lg-3">
#  <a href="https://www.todostuslibros.com/libros/la-chica-del-verano_978-84-480-3897-7">
#  <img alt="La chica del verano" height="150" src="https://static.cegal.es/imagenes/marcadas/9788448/978844803897.gif" title="La chica del verano" width="100"/>
#  <span> 4 </span>
#  </a>
#  <!-- Solo Vista grid y móvil -->
#  <a class="btn bookshelves-link" data-book-isbn="978-84-480-3897-7" data-book-title="La chica del verano" href="https://www.todostuslibros.com/login?_next=https://www.todostuslibros.com/libros/la-chica-del-verano_978-84-480-3897-7" title="Añadir a estantería">
#  <i class="far fa-heart"></i>
#  </a>
#  <!-- //Solo  Vista grid y móvil -->
#  </div>,
#  <div class="book-image col-4 col-sm-3 col-md-3 col-lg-3">
#  <a href="https://www.todostuslibros.com/libros/el-lirio-blanco_978-84-696-4040-1">
#  <img alt="El Lirio Blanco" height="150" src="https://static.cegal.es/imagenes/marcadas/9788469/978846964040.gif" title="El Lirio Blanco" width="100"/>
#  <span> 5 </span>
#  </a>
#  <!-- Solo Vista grid y móvil -->
#  <a class="btn bookshelves-link" data-book-isbn="978-84-696-4040-1" data-book-title="El Lirio Blanco" href="https://www.todostuslibros.com/login?_next=https://www.todostuslibros.com/libros/el-lirio-blanco_978-84-696-4040-1" title="Añadir a estantería">
#  <i class="far fa-heart"></i>
#  </a>
#  <!-- //Solo  Vista grid y móvil -->
#  </div>,
#  <div class="book-image col-4 col-sm-3 col-md-3 col-lg-3">
#  <a href="https://www.todostuslibros.com/libros/evangelio-2024-letra-pequena-bolsillo_978-84-19640-00-0">
#  <img alt="EVANGELIO 2024 LETRA PEQUEÑA BOLSILLO" height="150" src="https://static.cegal.es/imagenes/marcadas/9788419/978841964000.gif" title="EVANGELIO 2024 LETRA PEQUEÑA BOLSILLO" width="100"/>
#  <span> 6 </span>
#  </a>
#  <!-- Solo Vista grid y móvil -->
#  <a class="btn bookshelves-link" data-book-isbn="978-84-19640-00-0" data-book-title="EVANGELIO 2024 LETRA PEQUEÑA BOLSILLO" href="https://www.todostuslibros.com/login?_next=https://www.todostuslibros.com/libros/evangelio-2024-letra-pequena-bolsillo_978-84-19640-00-0" title="Añadir a estantería">
#  <i class="far fa-heart"></i>
#  </a>
#  <!-- //Solo  Vista grid y móvil -->
#  </div>,
#  <div class="book-image col-4 col-sm-3 col-md-3 col-lg-3">
#  <a href="https://www.todostuslibros.com/libros/el-problema-final_978-84-204-7636-0">
#  <img alt="El problema final" height="150" src="https://static.cegal.es/imagenes/marcadas/9788420/978842047636.gif" title="El problema final" width="100"/>
#  <span> 7 </span>
#  </a>
#  <!-- Solo Vista grid y móvil -->
#  <a class="btn bookshelves-link" data-book-isbn="978-84-204-7636-0" data-book-title="El problema final" href="https://www.todostuslibros.com/login?_next=https://www.todostuslibros.com/libros/el-problema-final_978-84-204-7636-0" title="Añadir a estantería">
#  <i class="far fa-heart"></i>
#  </a>
#  <!-- //Solo  Vista grid y móvil -->
#  </div>,
#  <div class="book-image col-4 col-sm-3 col-md-3 col-lg-3">
#  <a href="https://www.todostuslibros.com/libros/habitos-atomicos_978-84-18118-03-6">
#  <img alt="Hábitos atómicos" height="150" src="https://static.cegal.es/imagenes/marcadas/9788418/978841811803.gif" title="Hábitos atómicos" width="100"/>
#  <span> 8 </span>
#  </a>
#  <!-- Solo Vista grid y móvil -->
#  <a class="btn bookshelves-link" data-book-isbn="978-84-18118-03-6" data-book-title="Hábitos atómicos" href="https://www.todostuslibros.com/login?_next=https://www.todostuslibros.com/libros/habitos-atomicos_978-84-18118-03-6" title="Añadir a estantería">
#  <i class="far fa-heart"></i>
#  </a>
#  <!-- //Solo  Vista grid y móvil -->
#  </div>,
#  <div class="book-image col-4 col-sm-3 col-md-3 col-lg-3">
#  <a href="https://www.todostuslibros.com/libros/no-te-vere-morir_978-84-322-4232-8">
#  <img alt="No te veré morir" height="150" src="https://static.cegal.es/imagenes/marcadas/9788432/978843224232.gif" title="No te veré morir" width="100"/>
#  <span> 9 </span>
#  </a>
#  <!-- Solo Vista grid y móvil -->
#  <a class="btn bookshelves-link" data-book-isbn="978-84-322-4232-8" data-book-title="No te veré morir" href="https://www.todostuslibros.com/login?_next=https://www.todostuslibros.com/libros/no-te-vere-morir_978-84-322-4232-8" title="Añadir a estantería">
#  <i class="far fa-heart"></i>
#  </a>
#  <!-- //Solo  Vista grid y móvil -->
#  </div>,
#  <div class="book-image col-4 col-sm-3 col-md-3 col-lg-3">
#  <a href="https://www.todostuslibros.com/libros/mirafiori_978-84-204-6143-4">
#  <img alt="Mirafiori" height="150" src="https://static.cegal.es/imagenes/marcadas/9788420/978842046143.gif" title="Mirafiori" width="100"/>
#  <span> 10 </span>
#  </a>
#  <!-- Solo Vista grid y móvil -->
#  <a class="btn bookshelves-link" data-book-isbn="978-84-204-6143-4" data-book-title="Mirafiori" href="https://www.todostuslibros.com/login?_next=https://www.todostuslibros.com/libros/mirafiori_978-84-204-6143-4" title="Añadir a estantería">
#  <i class="far fa-heart"></i>
#  </a>
#  <!-- //Solo  Vista grid y móvil -->
#  </div>,
#  <div class="book-image col-4 col-sm-3 col-md-3 col-lg-3">
#  <a href="https://www.todostuslibros.com/libros/dios-la-ciencia-las-pruebas_978-84-126587-9-8">
#  <img alt="Dios - La ciencia - Las pruebas" height="150" src="https://static.cegal.es/imagenes/marcadas/9788412/978841265879.gif" title="Dios - La ciencia - Las pruebas" width="100"/>
#  <span> 11 </span>
#  </a>
#  <!-- Solo Vista grid y móvil -->
#  <a class="btn bookshelves-link" data-book-isbn="978-84-126587-9-8" data-book-title="Dios - La ciencia - Las pruebas" href="https://www.todostuslibros.com/login?_next=https://www.todostuslibros.com/libros/dios-la-ciencia-las-pruebas_978-84-126587-9-8" title="Añadir a estantería">
#  <i class="far fa-heart"></i>
#  </a>
#  <!-- //Solo  Vista grid y móvil -->
#  </div>,
#  <div class="book-image col-4 col-sm-3 col-md-3 col-lg-3">
#  <a href="https://www.todostuslibros.com/libros/evangelio-2024-letra-grande_978-84-19640-01-7">
#  <img alt="EVANGELIO 2024 LETRA GRANDE" height="150" src="https://static.cegal.es/imagenes/marcadas/9788419/978841964001.gif" title="EVANGELIO 2024 LETRA GRANDE" width="100"/>
#  <span> 12 </span>
#  </a>
#  <!-- Solo Vista grid y móvil -->
#  <a class="btn bookshelves-link" data-book-isbn="978-84-19640-01-7" data-book-title="EVANGELIO 2024 LETRA GRANDE" href="https://www.todostuslibros.com/login?_next=https://www.todostuslibros.com/libros/evangelio-2024-letra-grande_978-84-19640-01-7" title="Añadir a estantería">
#  <i class="far fa-heart"></i>
#  </a>
#  <!-- //Solo  Vista grid y móvil -->
#  </div>]

# %%
link_unpross = [link_info[i].find_all("a") for i in range(len(link_info))]
links = [link_unpross[i][0].get("href") for i in range(len(link_info))]

# %% [markdown]
# ## Get genres

# %%
genres = []
for i in links:
    url = i
    res = requests.get(url)
    html = res.content
    soup = BeautifulSoup(html, 'html.parser')
    genres_unpross = soup.find_all("dl", {"class":"materias"})[0].getText().strip().split("\n")[1:]
    genre_for_each_title = [i.strip() for i in genres_unpross if "|" not in i][1:]
    genres.append(genre_for_each_title)

# %% [markdown]
# ## Get editorial

# %%
editorials = []
for i in links:
    url = i
    res = requests.get(url)
    html = res.content
    soup = BeautifulSoup(html, 'html.parser')
    editorials_unpross = soup.find_all("div", {"id":"collapseFic"})[0].find("a").getText()
    editorials.append(editorials_unpross)
editorials
# Out:
# ['B',
#  'Editorial Planeta',
#  'PLAZA & JANES',
#  'Libros Cúpula',
#  'Editorial Bruño',
#  'EDIBESA',
#  'ALFAGUARA',
#  'Diana Editorial',
#  'Seix Barral',
#  'ALFAGUARA',
#  'Editorial Funambulista',
#  'EDIBESA']

# %% [markdown]
# ## Get country

# %%
countries = []
for i in links:
    url = i
    res = requests.get(url)
    html = res.content
    soup = BeautifulSoup(html, 'html.parser')
    countries_unpross = soup.find_all("div", {"id":"collapseFic"})[0].find_all("dd")[-8].getText()
    countries.append(countries_unpross)
countries
# Out:
# ['España',
#  'España',
#  'España',
#  'España',
#  'Castellano',
#  'España',
#  'España',
#  'España',
#  'España',
#  'España',
#  'España',
#  'España']

# %% [markdown]
# ## Get language

# %%
languages = []
for i in links:
    url = i
    res = requests.get(url)
    html = res.content
    soup = BeautifulSoup(html, 'html.parser')
    languages_unpross = soup.find_all("div", {"id":"collapseFic"})[0].find_all("dd")[-7].getText()
    languages.append(languages_unpross)
languages
# Out:
# ['Castellano',
#  'Castellano',
#  'Castellano',
#  'Castellano',
#  'Francés',
#  'Castellano',
#  'Castellano',
#  'Castellano',
#  'Castellano',
#  'Castellano',
#  'Castellano',
#  'Castellano']

# %% [markdown]
# ## Get original language

# %%
orig_language = []
for i in links:
    url = i
    res = requests.get(url)
    html = res.content
    soup = BeautifulSoup(html, 'html.parser')
    orig_language_unpross = soup.find_all("div", {"id":"collapseFic"})[0].find_all("dd")[-6].getText()
    orig_language.append(orig_language_unpross)
orig_language
# Out:
# ['Castellano',
#  'Castellano',
#  'Inglés',
#  'Castellano',
#  '                                         295\n                                         x                                         225\n                                     mm.',
#  'Castellano',
#  'Castellano',
#  'Inglés',
#  'Castellano',
#  'Castellano',
#  'Francés',
#  'Castellano']

# %% [markdown]
# ## Get pages

# %%
pages = []
for i in links:
    url = i
    res = requests.get(url)
    html = res.content
    soup = BeautifulSoup(html, 'html.parser')
    pages_unpross = soup.find_all("div", {"id":"collapseFic"})[0].find_all("dd")[-3].getText()
    pages.append(pages_unpross)
pages
# Out:
# ['608',
#  '480',
#  '832',
#  '424',
#  '48',
#  '512',
#  '328',
#  '336',
#  '240',
#  '208',
#  '584',
#  '512']

# %% [markdown]
# ## Get dates

# %%
dates = []
for i in links:
    url = i
    res = requests.get(url)
    html = res.content
    soup = BeautifulSoup(html, 'html.parser')
    dates_unpross = soup.find_all("div", {"id":"collapseFic"})[0].find_all("dd")[-2].getText()
    dates.append(dates_unpross)
dates
# Out:
# ['24-10-2023',
#  '04-10-2023',
#  '26-09-2023',
#  '18-10-2023',
#  '26-10-2023',
#  '01-06-2023',
#  '05-09-2023',
#  '08-09-2020',
#  '30-08-2023',
#  '05-10-2023',
#  '04-10-2023',
#  '01-06-2023']

# %% [markdown]
# ## Get prices

# %%
prices_info = body.find_all("div", {"class":"book-price d-block d-md-none"})
prices = [prices_info[i].find("strong").getText().strip() for i in range(len(prices_info))]
prices
# Out:
# ['22.90€',
#  '22.90€',
#  '24.90€',
#  '19.90€',
#  '10.50€',
#  '2.65€',
#  '21.90€',
#  '19.90€',
#  '19.90€',
#  '18.90€',
#  '24.90€',
#  '4.60€']

# %% [markdown]
# ## Web scrapping functions

# %%
def getBodies(url):
    res = requests.get(url)
    html = res.content
    soup = BeautifulSoup(html, 'html.parser')
    body = soup.find("main", {"class": "main"})
    return body
body = getBodies("https://www.todostuslibros.com/mas_vendidos")

# %%
def getTitles(body):
    titles_info = body.find_all("li", {"class":"book row"})
    titles = [titles_info[i].get("data-gtm-titulo") for i in range(len(titles_info))]
    return titles
titles = getTitles(body)

# %%
def getAuthors(body):
    authors_info = body.find_all("li", {"class":"book row"})
    authors = [authors_info[i].find_all("h3", {"class":"author"})[0].getText().strip() for i in range(len(authors_info))]
    return authors
authors = getAuthors(body)

# %%
def getLinks(body):
    link_info = body.find_all("div", {"class": "book-image col-4 col-sm-3 col-md-3 col-lg-3"})
    link_unpross = [link_info[i].find_all("a") for i in range(len(link_info))]
    links = [link_unpross[i][0].get("href") for i in range(len(link_info))]
    return links
links = getLinks(body)

# %%
def getGenres(links):
    genres = []
    for i in links:
        url = i
        res = requests.get(url)
        html = res.content
        soup = BeautifulSoup(html, 'html.parser')
        genres_unpross = soup.find_all("dl", {"class":"materias"})[0].getText().strip().split("\n")[1:]
        genre_for_each_title = [i.strip() for i in genres_unpross if "|" not in i][1:]
        genres.append(genre_for_each_title)
    return genres
genres = getGenres(links)

# %%
def getEditorials(links):
    editorials = []
    for i in links:
        url = i
        res = requests.get(url)
        html = res.content
        soup = BeautifulSoup(html, 'html.parser')
        editorials_unpross = soup.find_all("div", {"id":"collapseFic"})[0].find("a").getText()
        editorials.append(editorials_unpross)
    return editorials
editorials = getEditorials(links)

# %%
def getCountries(links):
    countries = []
    for i in links:
        url = i
        res = requests.get(url)
        html = res.content
        soup = BeautifulSoup(html, 'html.parser')
        countries_unpross = soup.find_all("div", {"id":"collapseFic"})[0].find_all("dd")[-8].getText()
        countries.append(countries_unpross)
    return countries
countries = getCountries(links)

# %%
def getLanguages(links):
    languages = []
    for i in links:
        url = i
        res = requests.get(url)
        html = res.content
        soup = BeautifulSoup(html, 'html.parser')
        languages_unpross = soup.find_all("div", {"id":"collapseFic"})[0].find_all("dd")[-7].getText()
        languages.append(languages_unpross)
    return languages
languages = getLanguages(links)

# %%
def getLang_orig(links):
    orig_language = []
    for i in links:
        url = i
        res = requests.get(url)
        html = res.content
        soup = BeautifulSoup(html, 'html.parser')
        orig_language_unpross = soup.find_all("div", {"id":"collapseFic"})[0].find_all("dd")[-6].getText()
        orig_language.append(orig_language_unpross)
    return orig_language
orig_language = getLang_orig(links)

# %%
def getPages(links):
    pages = []
    for i in links:
        url = i
        res = requests.get(url)
        html = res.content
        soup = BeautifulSoup(html, 'html.parser')
        pages_unpross = soup.find_all("div", {"id":"collapseFic"})[0].find_all("dd")[-3].getText()
        pages.append(pages_unpross)
    return pages
pages = getPages(links)

# %%
def getDates(links):
    fechas = []
    for i in links:
        url = i
        res = requests.get(url)
        html = res.content
        soup = BeautifulSoup(html, 'html.parser')
        fechas_unpross = soup.find_all("div", {"id":"collapseFic"})[0].find_all("dd")[-2].getText()
        fechas.append(fechas_unpross)
    return fechas
dates = getDates(links)

# %%
def getPrices(body):
    prices_info = body.find_all("div", {"class":"book-price d-block d-md-none"})
    prices = [prices_info[i].find("strong").getText().strip() for i in range(len(prices_info))]
    return prices
prices = getPrices(body)

# %%
url_basal = "https://www.todostuslibros.com/mas_vendidos"

def getUrls():
    urls = [(url_basal + "?page=" + str(i)) for i in range(1, 11)]
    return urls
urls = getUrls()

# %% [markdown]
# ## Looping through 10 pages

# %%
bodies = [getBodies(i) for i in urls]

# %%
links_secondary = [getLinks(i) for i in bodies]

# %%
titles_100 = []
for i in bodies:
    titles = getTitles(i)
    titles_100.extend(titles)

# %%
authors_100 = []
for i in bodies:
    authors = getAuthors(i)
    authors_100.extend(authors)

# %%
genres_100 = []
for i in links_secondary:
    genres = getGenres(i)
    genres_100.extend(genres)

# %%
editorials_100 = []
for i in links_secondary:
    editorials = getEditorials(i)
    editorials_100.extend(editorials)

# %%
countries_100 = []
for i in links_secondary:
    countries = getCountries(i)
    countries_100.extend(countries)

# %%
languages_100 = []
for i in links_secondary:
    languages = getLanguages(i)
    languages_100.extend(languages)

# %%
orig_lang_100 = []
for i in links_secondary:
    orig_lang = getLang_orig(i)
    orig_lang_100.extend(orig_lang)

# %%
pages_100 = []
for i in links_secondary:
    pages = getPages(i)
    pages_100.extend(pages)

# %%
dates_100 = []
for i in links_secondary:
    dates = getDates(i)
    dates_100.extend(dates)

# %%
prices_100 = []

for i in bodies:
    prices = getPrices(i)
    prices_100.extend(prices)

# %%
dictionary = {
    "titles":titles_100,
    "authors":authors_100,
    "genres": genres_100,
    "editorial":editorials_100,
    "countries":countries_100,
    "languages":languages_100,
    "orig_language": orig_lang_100,
    "pages":pages_100,
    "dates":dates_100
}

# %%
pd.DataFrame(dictionary)
# Out:
#                                                titles  \
# 0                           Todo vuelve (Todo arde 2)
# 1                                         El Infierno
# 2   La armadura de la luz (Saga Los pilares de la ...
# 3                                 La chica del verano
# 4                                     El Lirio Blanco
# ..                                                ...
# 95  Las reglas del ratoncito Pérez (Cuentos para c...
# 96  Las garras del águila: una novela de Lisbeth S...
# 97                     Cómo vender una casa encantada
# 98                             Biografía del silencio
# 99                                       Lunario 2024
#
#                      authors  \
# 0         Gómez-Jurado, Juan
# 1               Mola, Carmen
# 2               Follett, Ken
# 3            La Vecina Rubia
# 4   Goscinny, René / Fabcaro
# ..                       ...
# 95              Moreno, Eloy
# 96           Smirnoff, Karin
# 97            Hendrix, Grady
# 98              d'Ors, Pablo
# 99              Gros, Michel
#
#                                                genres  \
# 0   [Género policíaco y misterio, Obra de espionaj...
# 1   [Ficción histórica, Obra de misterio y suspens...
# 2   [Ficción de las guerras napoleónicas, Ficción ...
# 3                   [Ficción moderna y contemporanea]
# 4   [HUMOR, Edad de interés: a partir de 10 años, ...
# ..                                                ...
# 95  [Edad de interés: a partir de 6 años, Cuentos ...
# 96  [Obra de misterio y suspense, Género policíaco...
# 97  [Ficción moderna y contemporanea, Ficción y te...
# 98                  [Ficción moderna y contemporanea]
# 99  [Astrología, Jardinería, Agricultura orgánica,...
#
#                                  editorial   countries   languages  \
# 0                                        B      España  Castellano
# 1                        Editorial Planeta      España  Castellano
# 2                            PLAZA & JANES      España  Castellano
# 3                            Libros Cúpula      España  Castellano
# 4                          Editorial Bruño  Castellano     Francés
# ..                                     ...         ...         ...
# 95                           Nube de Tinta      España  Castellano
# 96                       Ediciones Destino      España  Castellano
# 97                               Minotauro      España  Castellano
# 98                       Galaxia Gutenberg      España  Castellano
# 99  Artús Porta Manresa - Calendario Lunar      España  Castellano
#
#                                         orig_language pages       dates
# 0                                          Castellano   608  24-10-2023
# 1                                          Castellano   480  04-10-2023
# 2                                              Inglés   832  26-09-2023
# 3                                          Castellano   424  18-10-2023
# 4                                            295\n...    48  26-10-2023
# ..                                                ...   ...         ...
# 95                                         Castellano    48  07-09-2023
# 96                                              Sueco   592  30-08-2023
# 97                                             Inglés   440  18-10-2023
# 98                                         Castellano   112  12-02-2020
# 99                                            Francés   130  20-07-2023
#
# [100 rows x 9 columns]

# %% [markdown]
# ### Functions to gather the data and create the df

# %%
bodies = [getBodies(i) for i in urls]
links_secondary = [getLinks(i) for i in bodies]

def getTitles_df(bodies):
    titles_100 = []
    for i in bodies:
        titles = getTitles(i)
        titles_100.extend(titles)
    return titles_100

def getAuthors_df(bodies):
    authors_100 = []
    for i in bodies:
        authors = getAuthors(i)
        authors_100.extend(authors)
    return authors_100

def getGenres_df(links_secondary):
    genres_100 = []
    for i in links_secondary:
        genres = getGenres(i)
        genres_100.extend(genres)
    return genres_100

def getEditorials_df(links_secondary):
    editorials_100 = []
    for i in links_secondary:
        editorials = getEditorials(i)
        editorials_100.extend(editorials)
    return editorials_100

def getCountries_df(links_secondary):
    countries_100 = []
    for i in links_secondary:
        countries = getCountries(i)
        countries_100.extend(countries)
    return countries_100

def getLanguages_df(links_secondary):
    languages_100 = []
    for i in links_secondary:
        languages = getLanguages(i)
        languages_100.extend(languages)
    return languages_100

def getOrigLang_df(links_secondary):
    orig_lang_100 = []
    for i in links_secondary:
        orig_lang = getLang_orig(i)
        orig_lang_100.extend(orig_lang)
    return orig_lang_100

def getPages_df(links_secondary):
    pages_100 = []
    for i in links_secondary:
        pages = getPages(i)
        pages_100.extend(pages)
    return pages_100

def getDates_df(links_secondary):
    dates_100 = []
    for i in links_secondary:
        dates = getDates(i)
        dates_100.extend(dates)
    return dates_100

def getPrices_df(bodies):
    prices_100 = []
    for i in bodies:
        prices = getPrices(i)
        prices_100.extend(prices)
    return prices_100

# %%
def build_df(titl, auth, genr, edit, countr, lang, orig_lang, pag, date, price):
    dictionary = {
        "title":titl,
        "author":auth,
        "genre": genr,
        "editorial":edit,
        "country":countr,
        "language":lang,
        "orig_language": orig_lang,
        "pages":pag,
        "date":date,
        "price": price
    }
    library_csv = pd.DataFrame(dictionary)
    library_csv.to_csv("../data/web_projectII.csv", index=False)

# %%
titles_df = getTitles_df(bodies)
authors_df = getAuthors_df(bodies)
genres_df = getGenres_df(links_secondary)
editorials_df = getEditorials_df(links_secondary)
countries_df = getCountries_df(links_secondary)
languages_df = getLanguages_df(links_secondary)
orig_lang_df = getOrigLang_df(links_secondary)
pages_df = getPages_df(links_secondary)
dates_df = getDates_df(links_secondary)
prices_df = getPrices_df(bodies)

build_df(titles_df, authors_df, genres_df, editorials_df, countries_df, languages_df, orig_lang_df, pages_df, dates_df, prices_df)
